# %%
# %%writefile ../pyproject.toml
# [build-system]
# requires = ["setuptools>=70"]
# build-backend = "setuptools.build_meta"
#
# [project]
# name = "data_science"
# version = "0.0.1"
# description = "General data science/ML environment"
# authors = [{ name = "Geoffrey Hadfield" }]
# requires-python = ">=3.10,<3.12"
#
# # Main runtime deps only. Dev tools moved to extras.
# dependencies = [
#   "numpy",
#   "pandas",
#   "scikit-learn",
#   "joblib",
#   "matplotlib",
#   "seaborn",
#   "jupyter",
#   "jupyterlab",
#   "ipykernel",
#   "dash",
#   "dash-bootstrap-components",
#   "plotly",
#   "opencv-python-headless",
#   "pillow",
#   "tqdm",
#   "statsmodels",
#   "nba_api",
#   "requests",
#   "streamlit",
#   "xgboost",
#   "lightgbm",
#
#   # ---- numba/llvmlite pair (keep in sync). Relax pins unless you must fix.
#   # "numba==0.60.*",
#   # "llvmlite==0.43.*",
#   "shap>=0.46.0",
#   "numba>=0.57.1",        # keep if you've tested; otherwise prefer matching pair above
#   "llvmlite>=0.41",       # idem
#
#   "beautifulsoup4",
#   # CPI lib: use latest to avoid resolution failures on some platforms.
#   "cpi>=2.0.0",
#   "lxml",
#   "IPython",
#   "tabulate",
#   "pyarrow",
#   "requests-cache",
#   "diskcache",
#   "unidecode",
# ]
#
# [project.optional-dependencies]
# spark = [
#   "pyspark",
#   "install-jdk>=1.1.0",
# ]
# dev = [
#   "pytest",
#   "black",
#   "flake8",
#   "mypy",
# ]
#
# [tool.black]
# line-length = 88
# target-version = ["py310"]
#
# [tool.flake8]
# max-line-length = 88
# extend-ignore = ["E203"]
#
# [tool.mypy]
# python_version = "3.10"
# ignore_missing_imports = true
# strict_optional = true
#
# [tool.pytest.ini_options]
# addopts = "-ra -q"
# testpaths = ["tests"]
#
# # Optional: uv-specific config (pin index, etc.)
# [tool.uv]
# # Example: index-url = "https://pypi.org/simple"
# Out:
# Overwriting ../pyproject.toml

# %%
# %%writefile ../src/salary_nba_data_pull/settings.py
# src/salary_nba_data_pull/settings.py
from pathlib import Path
import os
import typing as _t

# 🗂️  Central data directory (override via env if needed)
DATA_PROCESSED_DIR = Path(
    (Path(__file__).resolve().parent.parent.parent)  # project root
    / "data"
    / "new_processed"
)

# optional: allow `DATA_PROCESSED_DIR=/tmp/demo python main.py …`
ENV_OVERRIDE: _t.Optional[str] = os.getenv("DATA_PROCESSED_DIR")
if ENV_OVERRIDE:
    DATA_PROCESSED_DIR = Path(ENV_OVERRIDE).expanduser().resolve()

# Legacy path for backward compatibility
LEGACY_DATA_PROCESSED_DIR = Path(
    (Path(__file__).resolve().parent.parent.parent)  # project root
    / "data"
    / "processed"
)
# Out:
# Overwriting ../src/salary_nba_data_pull/settings.py

# %%
# %%writefile ../src/salary_nba_data_pull/fetch_utils.py
import threading
import time
import random
import logging
from concurrent.futures import ThreadPoolExecutor
from functools import lru_cache
from nba_api.stats.endpoints import commonallplayers, commonplayerinfo, playercareerstats, leaguestandings
from requests.exceptions import RequestException
from json.decoder import JSONDecodeError
from joblib import Memory
import os
from unidecode import unidecode

REQUESTS_PER_MIN = 20            # public guidance for nba_api
_SEM = threading.BoundedSemaphore(REQUESTS_PER_MIN)

# Set up joblib memory for caching API responses
cache_dir = os.path.join(os.path.dirname(__file__), '../../data/cache/nba_api')
memory = Memory(cache_dir, verbose=0)

def _throttle():
    """Acquire semaphore, release again after 60/REQUESTS_PER_MIN seconds."""
    _SEM.acquire()
    time.sleep(60 / REQUESTS_PER_MIN)
    _SEM.release()

@memory.cache
def fetch_with_retry(endpoint, max_retries=4, timeout=120, debug=False, **kwargs):
    """Thread‑safe, rate‑limited wrapper around nba_api endpoints with caching."""
    for attempt in range(1, max_retries + 1):
        start = time.time()
        try:
            _throttle()
            resp = endpoint(timeout=timeout, **kwargs)
            df = resp.get_data_frames()[0]
            if debug:
                logging.debug("%s OK in %.2fs kwargs=%s", endpoint.__name__,
                              time.time()-start, kwargs)
            return df
        except (RequestException, JSONDecodeError, KeyError) as e:
            if debug:
                logging.debug("%s attempt %d failed: %s",
                              endpoint.__name__, attempt, e)
            if attempt == max_retries:
                return None
            time.sleep(2 ** attempt + random.random())

@memory.cache
def fetch_all_players(season: str, debug: bool = False) -> dict[str, dict]:
    """Return {clean_name: {'player_id':…, 'team_id':…}} for *active* roster."""
    roster_df = fetch_with_retry(
        commonallplayers.CommonAllPlayers,
        season=season,
        is_only_current_season=1,        # <‑‑ key fix
        league_id="00",
        debug=debug,
    )
    players: dict[str, dict] = {}
    if roster_df is not None:
        for _, row in roster_df.iterrows():
            clean = unidecode(row["DISPLAY_FIRST_LAST"]).strip().lower()
            players[clean] = {
                "player_id": int(row["PERSON_ID"]),
                "team_id": int(row["TEAM_ID"]),
            }
    if debug:
        print(f"[fetch_all_players] {len(players)} active players for {season}")
    return players

@lru_cache(maxsize=None)
def fetch_season_players(season: str, debug: bool = False) -> dict[str, dict]:
    """
    Return {clean_name: {'player_id':…, 'team_id':…}} for *everyone who was
    on a roster at any time during the given season*.
    """
    # call once for the whole database (not "current‑season only")
    df = fetch_with_retry(
        commonallplayers.CommonAllPlayers,
        season=season,
        is_only_current_season=0,         # <-- key change
        league_id="00",
        debug=debug,
    )
    players: dict[str, dict] = {}
    if df is not None:
        yr = int(season[:4])
        # keep rows whose career window encloses this season
        df = df[(df.FROM_YEAR.astype(int) <= yr) & (df.TO_YEAR.astype(int) >= yr)]
        for _, row in df.iterrows():
            clean = unidecode(row["DISPLAY_FIRST_LAST"]).strip().lower()
            players[clean] = {
                "player_id": int(row["PERSON_ID"]),
                "team_id": int(row["TEAM_ID"]),
            }

    if debug:
        print(f"[fetch_season_players] {len(players)} players for {season}")
    return players

@memory.cache
def fetch_player_info(player_id, debug=False):
    return fetch_with_retry(commonplayerinfo.CommonPlayerInfo, player_id=player_id, debug=debug)

@memory.cache
def fetch_career_stats(player_id, debug=False):
    return fetch_with_retry(playercareerstats.PlayerCareerStats, player_id=player_id, debug=debug)

@memory.cache
def fetch_league_standings(season, debug=False):
    return fetch_with_retry(leaguestandings.LeagueStandings, season=season, debug=debug)

def clear_cache():
    """Clear the joblib memory cache."""
    memory.clear()

if __name__ == "__main__":
    # Example usage
    debug = True
    season = "2022-23"
    sample_player_name = "LeBron James"

    # Fetch all players
    all_players = fetch_all_players(season, debug=debug)
    print(f"Total players fetched: {len(all_players)}")

    # Fetch player info for a sample player
    if sample_player_name.lower() in all_players:
        sample_player_id = all_players[sample_player_name.lower()]['player_id']
        player_info = fetch_player_info(sample_player_id, debug=debug)
        print(f"Sample player info for {sample_player_name}:")
        print(player_info)

        # Fetch career stats for the sample player
        career_stats = fetch_career_stats(sample_player_id, debug=debug)
        print(f"Sample player career stats for {sample_player_name}:")
        print(career_stats)
    else:
        print(f"Player {sample_player_name} not found in the {season} season data.")

    # Fetch league standings
    standings = fetch_league_standings(season, debug=debug)
    print("League standings:")
    print(standings)
# Out:
# Overwriting ../src/salary_nba_data_pull/fetch_utils.py

# %%
# %%writefile ../src/salary_nba_data_pull/scrape_utils.py
import pandas as pd
import requests
import time
import random
import re
from bs4 import BeautifulSoup
from io import StringIO
from typing import Optional
import os
import requests_cache
from unidecode import unidecode
from pathlib import Path
from salary_nba_data_pull.settings import DATA_PROCESSED_DIR

# Install cache for all requests
requests_cache.install_cache('nba_scraping', expire_after=86400)  # 24 hours

def scrape_salary_cap_history(debug=False):
    url = "https://basketball.realgm.com/nba/info/salary_cap"
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find("table", class_=["basketball", "compact", "tablesaw"])

        if not table:
            if debug:
                print("Could not find the salary cap table on the page.")
            return None

        data = []
        headers = [th.text.strip() for th in table.find('thead').find_all('th')]
        for row in table.find('tbody').find_all('tr'):
            cols = row.find_all('td')
            if cols:
                row_data = [col.text.strip() for col in cols]
                data.append(row_data)

        df = pd.DataFrame(data, columns=headers)

        # Clean up the data
        df['Season'] = df['Season'].str.extract(r'(\d{4}-\d{4})')
        df['Salary Cap'] = df['Salary Cap'].str.replace('$', '').str.replace(',', '').astype(float)

        # Convert other columns to float, handling non-numeric values
        for col in df.columns:
            if col not in ['Season', 'Salary Cap']:
                df[col] = pd.to_numeric(df[col].str.replace('$', '').str.replace(',', ''), errors='coerce')

        if debug:
            print("Salary cap data scraped successfully")
            print(df.head())
        return df
    except Exception as e:
        if debug:
            print(f"Error scraping salary cap history: {str(e)}")
        return None

# User-Agent header to avoid Cloudflare blocks
UA = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/126.0.0.0 Safari/537.36"
    )
}
DELAY_BETWEEN_REQUESTS = 3  # seconds

# Define column templates to guarantee DataFrame structure
PLAYER_COLS = ["Player", "Salary", "Season"]
TEAM_COLS = ["Team", "Team_Salary", "Season"]

# Salary parsing pattern
_salary_pat = re.compile(r"\$?\d[\d,]*")

def _clean_salary(text: str) -> int | None:
    """Return salary as int or None when text has no digits."""
    m = _salary_pat.search(text)
    return int(m.group(0).replace(",", "").replace("$", "")) if m else None

# Name normalization pattern with unidecode
def _normalise_name(raw: str) -> str:
    """ASCII‑fold, trim, lower."""
    return unidecode(raw).split(",")[0].split("(")[0].strip().lower()


# ------- INTERNAL HELPER --------
def _get_hoopshype_soup(url: str, debug: bool = False) -> Optional[BeautifulSoup]:
    """
    Hit HoopsHype once with a realistic UA.  
    Return BeautifulSoup if the page looks OK, else None.
    """
    for attempt in range(2):
        try:
            if debug:
                print(f"[fetch] {url} (attempt {attempt+1})")
            resp = requests.get(url, headers=UA, timeout=30)
            if resp.status_code != 200:
                if debug:
                    print(f"  -> HTTP {resp.status_code}, skipping.")
                return None
            html = resp.text
            # crude Cloudflare challenge check
            if ("Access denied" in html) or ("cf-chl" in html):
                if debug:
                    print("  -> Cloudflare challenge detected; giving up.")
                return None
            return BeautifulSoup(html, "html.parser")
        except requests.RequestException as e:
            if debug:
                print(f"  -> network error {e}, retrying…")
            time.sleep(2 ** attempt + random.random())
    return None
# --------------------------------------------------------------------------


def _scrape_espn_player_salaries(season_start: int, debug: bool = False) -> list[dict]:
    """ESPN fallback: return list of dicts with clean player names."""
    rows, year = [], season_start + 1
    for page in range(1, 30):
        url = f"https://www.espn.com/nba/salaries/_/year/{year}/page/{page}"
        soup = _get_hoopshype_soup(url, debug)
        if soup is None:
            break
        tbl = soup.find("table")
        if not tbl or len(tbl.find_all("tr")) < 3:
            break
        for tr in tbl.find_all("tr")[1:]:
            tds = tr.find_all("td")
            if len(tds) < 4:
                continue
            salary_int = _clean_salary(tds[3].get_text(strip=True))
            if salary_int is None:           # header row ('SALARY', etc.)
                continue
            raw_name = tds[1].get_text(strip=True)
            rows.append({
                "Player":  _normalise_name(raw_name).title(),   # keep display case
                "Salary":  salary_int,
                "Season":  f"{season_start}-{str(season_start+1)[-2:]}"
            })
        time.sleep(0.5)
    return rows


def scrape_player_salary_data(start_season: int, end_season: int,
                              player_filter: str | None = None,
                              debug: bool = False) -> pd.DataFrame:
    """
    Pull player salaries – HoopsHype first, ESPN fallback.
    Player names are normalised so they match nba_api keys.
    """
    out: list[dict] = []

    for yr in range(start_season, end_season + 1):
        canon = f"{yr}-{str(yr+1)[-2:]}"
        for slug in [canon, f"{yr}-{yr+1}"]:          # HH dual slugs
            url = f"https://hoopshype.com/salaries/players/{slug}/"
            soup = _get_hoopshype_soup(url, debug)
            if soup is None:
                continue

            table = soup.find("table", class_="hh-salaries-ranking-table")
            if not table:
                if debug:
                    print(f"  -> salary table not found for {slug}")
                continue

            for row in table.find_all("tr")[1:]:
                tds = row.find_all("td")
                if len(tds) < 3:
                    continue
                raw_name = tds[1].get_text(strip=True)
                clean_name = _normalise_name(raw_name)
                if player_filter and player_filter.lower() != "all" \
                   and clean_name != _normalise_name(player_filter):
                    continue
                salary_int = _clean_salary(tds[2].get_text(strip=True)) or 0
                out.append({"Player": clean_name.title(),
                            "Salary": salary_int,
                            "Season": canon})
            if any(r["Season"] == canon for r in out):
                break  # success for this season

        if not any(r["Season"] == canon for r in out):
            espn_rows = _scrape_espn_player_salaries(yr, debug)
            if debug and espn_rows:
                print(f"  -> ESPN fallback added {len(espn_rows)} rows")
            out.extend(espn_rows)

        if debug:
            got = sum(r['Season'] == canon for r in out)
            print(f"  -> scraped {got} rows for {canon}")
        time.sleep(DELAY_BETWEEN_REQUESTS)

    return pd.DataFrame(out, columns=PLAYER_COLS)
# --------------------------------------------------------------------------


def _scrape_espn_team_salaries(season: str, debug: bool = False) -> list[dict]:
    """Parse ESPN team‑salary table; skip ranking column (#)."""
    rows, year = [], int(season[:4]) + 1
    url = f"https://www.espn.com/nba/salaries/_/type/team/year/{year}"
    soup = _get_hoopshype_soup(url, debug)
    if not soup:
        return rows

    tbl = soup.find("table")
    for tr in tbl.find_all("tr")[1:]:
        tds = tr.find_all("td")
        if len(tds) < 4:          # rank | team | conf | salary
            continue
        team_name = tds[1].get_text(strip=True)   # <‑‑ skip rank col
        salary_int = _clean_salary(tds[3].get_text(strip=True))
        if salary_int is not None:
            rows.append(
                {"Team": team_name, "Team_Salary": salary_int, "Season": season}
            )
    return rows


def scrape_team_salary_data(season: str, debug: bool = False) -> pd.DataFrame:
    """
    Team payrolls for a single season (YYYY-YY or YYYY-YYYY slug resilient).
    """
    records = []
    for slug in [season, f"{season[:4]}-{int(season[:4])+1}"]:
        url = f"https://hoopshype.com/salaries/{slug}/"
        soup = _get_hoopshype_soup(url, debug)
        if soup is None:
            continue

        table = soup.find("table", class_="hh-salaries-ranking-table")
        if not table:
            if debug:
                print(f"  -> team salary table missing for {slug}")
            continue

        for row in table.find_all("tr")[1:]:
            cols = row.find_all("td")
            if len(cols) < 3:
                continue
            team = cols[1].get_text(strip=True)
            salary = int(cols[2].get_text(strip=True).replace("$", "").replace(",", ""))
            records.append({"Team": team, "Team_Salary": salary, "Season": season})
        break  # stop after first hit

    # Fallback if no records found
    if not records:
        espn_rows = _scrape_espn_team_salaries(season, debug)
        if debug and espn_rows:
            print(f"  -> ESPN team salary fallback added {len(espn_rows)} rows")
        records.extend(espn_rows)

    df = pd.DataFrame(records, columns=TEAM_COLS)  # <- guarantees columns
    if debug and not df.empty:
        print(df.head())
    return df

def scrape_advanced_metrics(player_name, season, debug=False, max_retries=3, retry_delay=60):
    def make_request(url):
        response = requests.get(url)
        if response.status_code == 429:
            if debug:
                print(f"Rate limit hit. Waiting for {retry_delay} seconds before retrying.")
            time.sleep(retry_delay)
            return None
        return response

    for attempt in range(max_retries):
        try:
            search_url = f"https://www.basketball-reference.com/search/search.fcgi?search={player_name.replace(' ', '+')}"
            response = make_request(search_url)
            if response is None:
                continue

            soup = BeautifulSoup(response.content, 'html.parser')
            search_results = soup.find('div', {'class': 'search-results'})

            if search_results:
                for item in search_results.find_all('div', {'class': 'search-item'}):
                    link = item.find('a')
                    if link and 'players' in link['href']:
                        player_url = f"https://www.basketball-reference.com{link['href']}"
                        break
                else:
                    if debug:
                        print(f"No player URL found for {player_name}")
                    return {}
            else:
                if debug:
                    print(f"No search results found for {player_name}")
                return {}

            time.sleep(2)  # Wait 2 seconds between requests

            response = make_request(player_url)
            if response is None:
                continue

            soup = BeautifulSoup(response.content, 'html.parser')
            table = soup.find('table', {'id': 'advanced'})
            if table:
                df = pd.read_html(StringIO(str(table)))[0]
                if isinstance(df.columns, pd.MultiIndex):
                    df.columns = df.columns.droplevel()
                df['Season'] = df['Season'].astype(str)
                df = df[df['Season'].str.contains(season.split('-')[0], na=False)]
                if not df.empty:
                    row = df.iloc[0]
                    metrics = ['PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']
                    result = {col: row[col] for col in metrics if col in row.index}
                    if debug:
                        print(f"Scraped advanced metrics for {player_name} in season {season}: {result}")
                    return result
                else:
                    if debug:
                        print(f"No advanced metrics found for {player_name} in season {season}")
            else:
                if debug:
                    print(f"No advanced stats table found for {player_name}")

        except Exception as e:
            if debug:
                print(f"Error scraping advanced metrics for {player_name}: {e}")

        if attempt < max_retries - 1:
            if debug:
                print(f"Retrying in {retry_delay} seconds...")
            time.sleep(retry_delay)

    if debug:
        print(f"Failed to scrape advanced metrics for {player_name} after {max_retries} attempts")
    return {}

def load_injury_data(
    file_path: str | Path | None = None,
    *,
    base_dir: str | Path | None = None,
    debug: bool = False,
):
    """
    Load the historical injury CSV. By default we look inside the *new*
    processed folder; pass ``file_path`` to override a specific file,
    or ``base_dir`` to point at a different processed directory.
    """
    root = Path(base_dir) if base_dir else DATA_PROCESSED_DIR
    if file_path is None:
        file_path = root / "NBA Player Injury Stats(1951 - 2023).csv"
    file_path = Path(file_path).expanduser().resolve()

    try:
        injury = (
            pd.read_csv(file_path)
            .assign(Date=lambda d: pd.to_datetime(d["Date"]))
        )
        injury["Season"] = injury["Date"].apply(
            lambda x: (
                f"{x.year}-{str(x.year + 1)[-2:]}"
                if x.month >= 10
                else f"{x.year - 1}-{str(x.year)[-2:]}"
            )
        )
        if debug:
            print(f"[load_injury_data] loaded {len(injury):,} rows from {file_path}")
        return injury
    except FileNotFoundError:
        if debug:
            print(f"[load_injury_data] ✖ no injury file at {file_path}")
        return None

def merge_injury_data(player_data, injury_data):
    if injury_data is None:
        return player_data

    all_players_df = player_data.copy()
    all_players_df['Injured'] = False
    all_players_df['Injury_Periods'] = ''
    all_players_df['Total_Days_Injured'] = 0
    all_players_df['Injury_Risk'] = 'Low Risk'

    for index, row in all_players_df.iterrows():
        player_injuries = injury_data[
            (injury_data['Season'] == row['Season']) & 
            (injury_data['Relinquished'].str.contains(row['Player'], case=False, na=False))
        ]
        if not player_injuries.empty:
            periods = []
            total_days = 0
            for _, injury in player_injuries.iterrows():
                start_date = injury['Date']
                acquired_matches = injury_data[
                    (injury_data['Date'] > start_date) & 
                    (injury_data['Acquired'].str.contains(row['Player'], case=False, na=False))
                ]
                if not acquired_matches.empty:
                    end_date = acquired_matches.iloc[0]['Date']
                else:
                    # Assuming injuries last until the end of the season if no acquired date is found
                    end_year = int(row['Season'].split('-')[1])
                    end_date = pd.Timestamp(f"{end_year}-06-30")

                period_days = (end_date - start_date).days
                total_days += period_days
                periods.append(f"{start_date.strftime('%Y-%m-%d')} - {end_date.strftime('%Y-%m-%d')}")

            all_players_df.at[index, 'Injured'] = True
            all_players_df.at[index, 'Injury_Periods'] = '; '.join(periods)
            all_players_df.at[index, 'Total_Days_Injured'] = total_days

            # Categorize injury risk based on total days
            if total_days < 10:
                risk = 'Low Risk'
            elif 10 <= total_days <= 20:
                risk = 'Moderate Risk'
            else:
                risk = 'High Risk'
            all_players_df.at[index, 'Injury_Risk'] = risk

    return all_players_df

if __name__ == "__main__":
    # Example usage and testing of all functions
    debug = True
    start_season = 2022
    end_season = 2023
    sample_player = "Ja Morant"  # Example player

    print("1. Testing scrape_salary_cap_history:")
    salary_cap_history = scrape_salary_cap_history(debug=debug)

    print("\n2. Testing scrape_player_salary_data:")
    player_salary_data = scrape_player_salary_data(start_season, end_season, player_filter=sample_player, debug=debug)

    print("\n3. Testing scrape_team_salary_data:")
    team_salary_data = scrape_team_salary_data(f"{start_season}-{str(start_season+1)[-2:]}", debug=debug)

    print("\n4. Testing scrape_advanced_metrics:")
    advanced_metrics = scrape_advanced_metrics(sample_player, f"{start_season}-{str(start_season+1)[-2:]}", debug=debug)
    print(f"Advanced Metrics for {sample_player}:")
    print(advanced_metrics)

    print("\n5. Testing load_injury_data and merge_injury_data:")
    injury_data = load_injury_data()
    if injury_data is not None:
        print(injury_data.head())
    else:
        print("No injury data loaded.")
    if not player_salary_data.empty and injury_data is not None:
        merged_data = merge_injury_data(player_salary_data, injury_data)
        print("Merged data with injury info:")
        columns_to_display = ['Player', 'Season', 'Salary']
        if 'Injured' in merged_data.columns:
            columns_to_display.append('Injured')
        if 'Injury_Periods' in merged_data.columns:
            columns_to_display.append('Injury_Periods')
        if 'Total_Days_Injured' in merged_data.columns:
            columns_to_display.append('Total_Days_Injured')
        if 'Injury_Risk' in merged_data.columns:
            columns_to_display.append('Injury_Risk')
        print(merged_data[columns_to_display].head())

    if not player_salary_data.empty:
        avg_salary = player_salary_data['Salary'].mean()
        print(f"Average salary for {sample_player} from {start_season} to {end_season}: ${avg_salary:,.2f}")

    if not team_salary_data.empty:
        highest_team_salary = team_salary_data.loc[team_salary_data['Team_Salary'].idxmax()]
        print(f"Team with highest salary in {start_season}-{end_season}: {highest_team_salary['Team']} (${highest_team_salary['Team_Salary']:,.2f})")

    if not injury_data.empty:
        injury_count = injury_data['Relinquished'].str.contains(sample_player, case=False).sum()
        print(f"Number of injuries/illnesses for {sample_player} from {start_season} to {end_season}: {injury_count}")

    print("\nAll tests completed.")
# Out:
# Overwriting ../src/salary_nba_data_pull/scrape_utils.py

# %%
# %%writefile ../src/salary_nba_data_pull/process_utils.py
import pandas as pd
import numpy as np
import logging
import sqlite3
from datetime import datetime
from functools import lru_cache
from salary_nba_data_pull.fetch_utils import fetch_all_players, fetch_career_stats

# --- CPI lazy‑loader --------------------------------------------------
_CPI_AVAILABLE = False  # toggled at runtime

@lru_cache(maxsize=1)
def _ensure_cpi_ready(debug: bool = False) -> bool:
    """
    Import `cpi` lazily and guarantee its internal SQLite DB is usable.
    Returns True when inflation data are available, False otherwise.
    """
    global _CPI_AVAILABLE
    try:
        import importlib
        cpi = importlib.import_module("cpi")        # late import
        try:
            _ = cpi.models.Series.get_by_id("0000")  # 1‑row sanity query
            _CPI_AVAILABLE = True
            return True
        except sqlite3.OperationalError:
            if debug:
                logging.warning("[CPI] DB invalid – rebuilding from BLS…")
            cpi.update(rebuild=True)                # expensive network call
            _CPI_AVAILABLE = True
            return True
    except ModuleNotFoundError:
        if debug:
            logging.warning("[CPI] package not installed")
    except Exception as e:
        if debug:
            logging.error("[CPI] unexpected CPI failure: %s", e)
    return False
# ---------------------------------------------------------------------

def inflate_value(value: float, year_str: str,
                  *, debug: bool = False, skip_inflation: bool = False) -> float:
    """
    Inflate `value` from the dollars of `year_str` (YYYY or YYYY‑YY) to 2022 USD.
    If CPI data are unavailable or the user opts out, return the original value.
    """
    if skip_inflation or not _ensure_cpi_ready(debug):
        return value
    try:
        import cpi                                       # safe: DB ready
        year = int(year_str[:4])
        if year >= datetime.now().year:
            return value
        return float(cpi.inflate(value, year, to=2022))
    except Exception as e:
        if debug:
            logging.error("[CPI] inflate failed for %s: %s", year_str, e)
        return value
# ---------------------------------------------------------------------

def calculate_percentages(df, debug=False):
    """
    Calculate shooting percentages and other derived statistics.
    """
    if df.empty:
        return df
    
    # Calculate shooting percentages
    if 'FGA' in df.columns and 'FG' in df.columns:
        df['FG%'] = (df['FG'] / df['FGA'] * 100).round(2)
        df['FG%'] = df['FG%'].replace([np.inf, -np.inf], np.nan)
    
    if '3PA' in df.columns and '3P' in df.columns:
        df['3P%'] = (df['3P'] / df['3PA'] * 100).round(2)
        df['3P%'] = df['3P%'].replace([np.inf, -np.inf], np.nan)
    
    if 'FTA' in df.columns and 'FT' in df.columns:
        df['FT%'] = (df['FT'] / df['FTA'] * 100).round(2)
        df['FT%'] = df['FT%'].replace([np.inf, -np.inf], np.nan)
    
    # Calculate efficiency metrics
    if 'PTS' in df.columns and 'FGA' in df.columns and 'FTA' in df.columns:
        df['TS%'] = (df['PTS'] / (2 * (df['FGA'] + 0.44 * df['FTA'])) * 100).round(2)
        df['TS%'] = df['TS%'].replace([np.inf, -np.inf], np.nan)
    
    if 'PTS' in df.columns and 'MP' in df.columns:
        df['PTS_per_36'] = (df['PTS'] / df['MP'] * 36).round(2)
        df['PTS_per_36'] = df['PTS_per_36'].replace([np.inf, -np.inf], np.nan)
    
    if 'AST' in df.columns and 'MP' in df.columns:
        df['AST_per_36'] = (df['AST'] / df['MP'] * 36).round(2)
        df['AST_per_36'] = df['AST_per_36'].replace([np.inf, -np.inf], np.nan)
    
    if 'TRB' in df.columns and 'MP' in df.columns:
        df['TRB_per_36'] = (df['TRB'] / df['MP'] * 36).round(2)
        df['TRB_per_36'] = df['TRB_per_36'].replace([np.inf, -np.inf], np.nan)
    
    if debug:
        print("Percentage calculations completed")
    
    return df

def process_player_data(player_name, season, all_players, debug=False):
    """
    Process individual player data and return a dictionary with player statistics.
    """
    if not all_players:
        if debug:
            print(f"No players data available for {player_name}")
        return None
    
    # Normalize player name for lookup
    player_name_lower = player_name.lower().strip()
    
    # Check if player exists in all_players
    if player_name_lower not in all_players:
        if debug:
            print(f"Player {player_name} not found in all_players")
        return None
    
    player_info = all_players[player_name_lower]
    player_id = player_info['player_id']
    
    if debug:
        print(f"Processing {player_name} (ID: {player_id})")
    
    try:
        # Fetch player career stats
        career_stats = fetch_career_stats(player_id, debug=debug)
        
        if career_stats is None or career_stats.empty:
            if debug:
                print(f"No career stats found for {player_name}")
            return None
        
        # Filter for the specific season
        season_stats = career_stats[career_stats['SEASON_ID'] == season]
        
        if season_stats.empty:
            if debug:
                print(f"No stats found for {player_name} in season {season}")
            return None
        
        # Get the first (and should be only) row for this season
        stats_row = season_stats.iloc[0]
        
        # Create player data dictionary
        player_data = {
            'Player': player_name,
            'Season': season,
            'Age': stats_row.get('PLAYER_AGE', None),
            'GP': stats_row.get('GP', 0),
            'MP': stats_row.get('MIN', 0),
            'PTS': stats_row.get('PTS', 0),
            'TRB': stats_row.get('REB', 0),
            'AST': stats_row.get('AST', 0),
            'STL': stats_row.get('STL', 0),
            'BLK': stats_row.get('BLK', 0),
            'TOV': stats_row.get('TOV', 0),
            'FG': stats_row.get('FGM', 0),
            'FGA': stats_row.get('FGA', 0),
            '3P': stats_row.get('FG3M', 0),
            '3PA': stats_row.get('FG3A', 0),
            'FT': stats_row.get('FTM', 0),
            'FTA': stats_row.get('FTA', 0),
            'PER': stats_row.get('PER', None),
            'WS': stats_row.get('WS', None),
            'VORP': stats_row.get('VORP', None),
            'Team': stats_row.get('TEAM_ABBREVIATION', 'Unknown'),
            'Injured': False,  # Default value, will be updated by merge_injury_data
            'Injury_Periods': '',
            'Total_Days_Injured': 0,
            'Injury_Risk': 'Low Risk'
        }
        
        if debug:
            print(f"Successfully processed {player_name}: {len(player_data)} fields")
        
        return player_data
        
    except Exception as e:
        if debug:
            print(f"Error processing {player_name}: {str(e)}")
        return None

def merge_injury_data(player_data, injury_data):
    """
    Merge injury data with player data.
    """
    if injury_data is None or player_data.empty:
        return player_data
    
    # Create a copy to avoid modifying the original
    merged_data = player_data.copy()
    
    # Initialize injury columns if they don't exist
    if 'Injured' not in merged_data.columns:
        merged_data['Injured'] = False
    if 'Injury_Periods' not in merged_data.columns:
        merged_data['Injury_Periods'] = ''
    if 'Total_Days_Injured' not in merged_data.columns:
        merged_data['Total_Days_Injured'] = 0
    if 'Injury_Risk' not in merged_data.columns:
        merged_data['Injury_Risk'] = 'Low Risk'
    
    # Process each player
    for index, row in merged_data.iterrows():
        player_name = row['Player']
        season = row['Season']
        
        # Find injuries for this player in this season
        player_injuries = injury_data[
            (injury_data['Season'] == season) & 
            (injury_data['Relinquished'].str.contains(player_name, case=False, na=False))
        ]
        
        if not player_injuries.empty:
            periods = []
            total_days = 0
            
            for _, injury in player_injuries.iterrows():
                start_date = injury['Date']
                
                # Find when player was acquired back
                acquired_matches = injury_data[
                    (injury_data['Date'] > start_date) & 
                    (injury_data['Acquired'].str.contains(player_name, case=False, na=False))
                ]
                
                if not acquired_matches.empty:
                    end_date = acquired_matches.iloc[0]['Date']
                else:
                    # Assume injury lasts until end of season if no acquired date
                    end_year = int(season.split('-')[1])
                    end_date = pd.Timestamp(f"{end_year}-06-30")
                
                period_days = (end_date - start_date).days
                total_days += period_days
                periods.append(f"{start_date.strftime('%Y-%m-%d')} - {end_date.strftime('%Y-%m-%d')}")
            
            # Update injury data
            merged_data.at[index, 'Injured'] = True
            merged_data.at[index, 'Injury_Periods'] = '; '.join(periods)
            merged_data.at[index, 'Total_Days_Injured'] = total_days
            
            # Categorize injury risk
            if total_days < 10:
                risk = 'Low Risk'
            elif 10 <= total_days <= 20:
                risk = 'Moderate Risk'
            else:
                risk = 'High Risk'
            merged_data.at[index, 'Injury_Risk'] = risk
    
    return merged_data
# Out:
# Overwriting ../src/salary_nba_data_pull/process_utils.py

# %%
# %%writefile ../src/salary_nba_data_pull/data_utils.py

import pandas as pd
import numpy as np
from salary_nba_data_pull.process_utils import (
    inflate_value
)
from salary_nba_data_pull.quality import (
    ExpectedSchema, audit_dataframe, write_audit_reports
)
from salary_nba_data_pull.settings import DATA_PROCESSED_DIR

def clean_dataframe(df):
    # Remove unnamed columns
    df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

    # Remove duplicate columns
    df = df.loc[:, ~df.columns.duplicated()]

    # Remove columns with all NaN values
    df = df.dropna(axis=1, how='all')

    # Remove rows with all NaN values
    df = df.dropna(axis=0, how='all')

    # Ensure only one 'Season' column exists
    season_columns = [col for col in df.columns if 'Season' in col]
    if len(season_columns) > 1:
        df = df.rename(columns={season_columns[0]: 'Season'})
        for col in season_columns[1:]:
            df = df.drop(columns=[col])

    # Remove '3PAr' and 'FTr' columns
    columns_to_remove = ['3PAr', 'FTr']
    df = df.drop(columns=columns_to_remove, errors='ignore')

    # Round numeric columns to 2 decimal places
    numeric_columns = df.select_dtypes(include=[np.number]).columns
    df[numeric_columns] = df[numeric_columns].round(2)

    return df

def merge_salary_cap_data(player_data, salary_cap_data):
    player_data['Season_Year'] = player_data['Season'].str[:4].astype(int)
    salary_cap_data['Season_Year'] = salary_cap_data['Season'].str[:4].astype(int)

    # Add inflation-adjusted salary cap
    salary_cap_data['Salary_Cap_Inflated'] = salary_cap_data.apply(
        lambda row: inflate_value(row['Salary Cap'], row['Season']),
        axis=1
    )

    # Merge salary cap data
    merged_data = pd.merge(player_data, salary_cap_data, on='Season_Year', how='left', suffixes=('', '_cap'))

    # Update salary cap columns
    cap_columns = ['Mid-Level Exception', 'Salary Cap', 'Luxury Tax', '1st Apron', '2nd Apron', 'BAE',
                   'Standard /Non-Taxpayer', 'Taxpayer', 'Team Room /Under Cap', 'Salary_Cap_Inflated']
    for col in cap_columns:
        if f'{col}_cap' in merged_data.columns:
            merged_data[col] = merged_data[col].fillna(merged_data[f'{col}_cap'])
            merged_data.drop(columns=[f'{col}_cap'], inplace=True)

    # Clean up temporary columns
    merged_data.drop(columns=['Season_Year'], inplace=True)

    # Clean the dataframe
    merged_data = clean_dataframe(merged_data)

    return merged_data

def validate_data(df: pd.DataFrame,
                  *,
                  name: str = "player_dataset",
                  save_reports: bool = True) -> pd.DataFrame:
    """
    Run a comprehensive audit and optionally persist CSV reports.
    Returns the original df untouched.
    """
    schema = ExpectedSchema(
        expected_cols=df.columns,           # you can narrow this if you have a canonical list
        required_cols=[
            "Season", "Player", "Salary", "Team"
        ],
        dtypes={
            "Season": "object",
            "Player": "object",
            "Salary": "float64",
        },
        non_negative_cols=["Salary", "GP", "MP", "PTS", "TRB", "AST", "Team_Salary"],
        non_constant_cols=["Salary", "PTS", "Team_Salary"],
        unique_key=["Season", "Player"]
    )

    reports = audit_dataframe(df, schema, name=name)

    if save_reports:
        out_dir = DATA_PROCESSED_DIR / "audits"
        write_audit_reports(reports, out_dir, prefix=name)

    # Print a one-liner summary (optional)
    missing_req = reports["cols_overview"].query("missing_required == True")
    if not missing_req.empty:
        print(f"[validate_data] Missing required columns: {missing_req['column'].tolist()}")

    return df
# Out:
# Overwriting ../src/salary_nba_data_pull/data_utils.py

# %%
# %%writefile ../src/salary_nba_data_pull/quality.py
# src/salary_nba_data_pull/quality.py
from __future__ import annotations
from dataclasses import dataclass, field
from pathlib import Path
from typing import Iterable, Mapping, Any
import pandas as pd
import numpy as np

@dataclass
class ExpectedSchema:
    """Describe what we *intended* to have in a dataframe."""
    # All columns we care about (order doesn't matter)
    expected_cols: Iterable[str]

    # Subset that must be present
    required_cols: Iterable[str] = field(default_factory=list)

    # Expected pandas dtypes (string form, e.g. 'float64', 'object')
    dtypes: Mapping[str, str] = field(default_factory=dict)

    # Columns that must be >= 0
    non_negative_cols: Iterable[str] = field(default_factory=list)

    # Columns that should not be all zeros / all NaN
    non_constant_cols: Iterable[str] = field(default_factory=list)

    # Unique key columns (together must be unique)
    unique_key: Iterable[str] = field(default_factory=list)

    # Allowed value sets (enums)
    allowed_values: Mapping[str, Iterable[Any]] = field(default_factory=dict)

def _series_is_constant(s: pd.Series) -> bool:
    return s.nunique(dropna=True) <= 1

def audit_dataframe(df: pd.DataFrame,
                    schema: ExpectedSchema,
                    *,
                    name: str = "dataset") -> dict[str, pd.DataFrame]:
    """
    Return a dict of small DataFrames summarising quality checks.
    Nothing is printed; caller decides how to persist/log.
    """
    exp = set(schema.expected_cols)
    req = set(schema.required_cols)

    present = set(df.columns)
    missing = sorted(list(exp - present))
    extra   = sorted(list(present - exp))

    # --- Column overview
    cols_overview = pd.DataFrame({
        "column": sorted(list(exp | present)),
        "expected": [c in exp for c in sorted(list(exp | present))],
        "present":  [c in present for c in sorted(list(exp | present))],
        "required": [c in req for c in sorted(list(exp | present))]
    })
    cols_overview["missing_required"] = cols_overview.apply(
        lambda r: r["required"] and not r["present"], axis=1
    )

    # --- Null report
    null_report = (df.isna().sum().to_frame("null_count")
                     .assign(total_rows=len(df))
                     .assign(null_pct=lambda d: 100 * d["null_count"] / d["total_rows"])
                     .reset_index()
                     .rename(columns={"index": "column"}))

    # --- Dtype report
    type_rows = []
    for col in df.columns:
        exp_type = schema.dtypes.get(col)
        type_rows.append({
            "column": col,
            "expected_dtype": exp_type,
            "actual_dtype": str(df[col].dtype),
            "matches": (exp_type is None) or (str(df[col].dtype) == exp_type)
        })
    type_report = pd.DataFrame(type_rows)

    # --- Value checks
    value_rows = []
    for col in df.select_dtypes(include=[np.number]).columns:
        series = df[col]
        row = {
            "column": col,
            "min": series.min(skipna=True),
            "max": series.max(skipna=True),
            "negatives": int((series < 0).sum()),
            "zeros": int((series == 0).sum()),
            "non_zero_pct": 100 * (series != 0).sum() / len(series),
        }
        row["should_be_non_negative"] = col in schema.non_negative_cols
        row["violates_non_negative"] = row["negatives"] > 0 and row["should_be_non_negative"]
        value_rows.append(row)
    value_report = pd.DataFrame(value_rows)

    # Constant columns
    constant_rows = []
    for col in df.columns:
        constant_rows.append({
            "column": col,
            "is_constant": _series_is_constant(df[col]),
            "should_not_be_constant": col in schema.non_constant_cols
        })
    constant_report = pd.DataFrame(constant_rows).assign(
        violates=lambda d: d["is_constant"] & d["should_not_be_constant"]
    )

    # Allowed values
    enum_rows = []
    for col, allowed in schema.allowed_values.items():
        if col not in df.columns:
            continue
        bad = ~df[col].isin(allowed) & df[col].notna()
        enum_rows.append({
            "column": col,
            "bad_count": int(bad.sum()),
            "sample_bad": df.loc[bad, col].drop_duplicates().head(5).tolist()
        })
    enum_report = pd.DataFrame(enum_rows)

    # Unique key
    uniq_report = pd.DataFrame()
    if schema.unique_key:
        dup_mask = df.duplicated(subset=list(schema.unique_key), keep=False)
        uniq_report = pd.DataFrame({
            "duplicate_rows": [int(dup_mask.sum())],
            "subset": [list(schema.unique_key)]
        })

    return {
        "cols_overview": cols_overview,
        "null_report": null_report,
        "type_report": type_report,
        "value_report": value_report,
        "constant_report": constant_report,
        "enum_report": enum_report,
        "unique_report": uniq_report
    }

def assert_dataframe_ok(df: pd.DataFrame,
                        schema: ExpectedSchema,
                        *, name: str = "dataset") -> None:
    """
    Raise AssertionError with a concise message if critical checks fail.
    Designed for pytest or CI.
    """
    rep = audit_dataframe(df, schema, name=name)
    bad_missing = rep["cols_overview"].query("missing_required == True")
    bad_types = rep["type_report"].query("matches == False")
    bad_nonneg = rep["value_report"].query("violates_non_negative == True")
    bad_constant = rep["constant_report"].query("violates == True")
    dupes = rep["unique_report"]["duplicate_rows"].iloc[0] if not rep["unique_report"].empty else 0

    msgs = []
    if not bad_missing.empty:
        msgs.append(f"Missing required cols: {bad_missing['column'].tolist()}")
    if not bad_types.empty:
        msgs.append(f"Dtype mismatches: {bad_types[['column','expected_dtype','actual_dtype']].to_dict('records')}")
    if not bad_nonneg.empty:
        msgs.append(f"Negative values in non-negative cols: {bad_nonneg['column'].tolist()}")
    if not bad_constant.empty:
        msgs.append(f"Constant-but-shouldn't cols: {bad_constant['column'].tolist()}")
    if dupes:
        msgs.append(f"Duplicate key rows: {dupes}")

    if msgs:
        raise AssertionError(f"[{name}] data quality failures:\n" + "\n".join(msgs))

def write_audit_reports(reports: Mapping[str, pd.DataFrame],
                        out_dir: Path,
                        prefix: str) -> None:
    """
    Save each report DataFrame as CSV for later inspection.
    """
    out_dir.mkdir(parents=True, exist_ok=True)
    for key, df in reports.items():
        df.to_csv(out_dir / f"{prefix}_{key}.csv", index=False)
# Out:
# Overwriting ../src/salary_nba_data_pull/quality.py

# %%
# %%writefile ../src/salary_nba_data_pull/main.py
import argparse
import pandas as pd
import logging
import time
import glob
import os
import hashlib
from pathlib import Path
import pyarrow.parquet as pq
from datetime import datetime, timedelta
from concurrent.futures import ThreadPoolExecutor, as_completed
from tqdm.auto import tqdm
import requests_cache
from salary_nba_data_pull.fetch_utils import fetch_all_players, fetch_season_players
from salary_nba_data_pull.process_utils import (
    process_player_data,
    inflate_value,
    calculate_percentages,
    _ensure_cpi_ready,
)
from salary_nba_data_pull.scrape_utils import (
    scrape_salary_cap_history,
    merge_injury_data,
    scrape_player_salary_data,
    scrape_team_salary_data,
    load_injury_data,
)
from salary_nba_data_pull.data_utils import (
    clean_dataframe,
    merge_salary_cap_data,
    validate_data,
)
from salary_nba_data_pull.settings import DATA_PROCESSED_DIR

# Enable requests-cache for all HTTP traffic
requests_cache.install_cache("nba_pull", backend="sqlite", allowable_codes=(200,))

# CPI self-test - logs a warning once per run if CPI is unavailable
_ensure_cpi_ready(debug=False)

# Default number of worker threads
DEFAULT_WORKERS = 8                # tweak ≤ CPU cores

def _file_md5(path: str, chunk: int = 1 << 20) -> str:
    """Return md5 hexdigest for *path* streaming in 1 MiB chunks."""
    h = hashlib.md5()
    with open(path, "rb") as f:
        for blk in iter(lambda: f.read(chunk), b""):
            h.update(blk)
    return h.hexdigest()

def _season_partition_identical(season: str, base_dir: str, new_df: pd.DataFrame) -> bool:
    """True when an on‑disk parquet for *season* has same schema & md5 as *new_df*."""
    ckpt = Path(base_dir) / f"season={season}" / "part.parquet"
    md5_file = ckpt.with_suffix(".md5")
    if not ckpt.exists():
        return False

    # ---------- 1. schema check (fast) ----------
    stored_schema = pq.read_schema(ckpt)
    if set(stored_schema.names) != set(new_df.columns):
        return False

    # ---------- 2. content hash ----------
    if not md5_file.exists():
        return False                       # force re‑write → hash will be created
    stored_hash = md5_file.read_text().strip()
    new_hash = hashlib.md5(new_df.to_parquet(index=False)).hexdigest()
    return stored_hash == new_hash

def _season_partition_exists(season, base_dir):
    """Check if a season partition already exists in Parquet format."""
    return os.path.exists(os.path.join(base_dir, f"season={season}"))

def _player_task(args):
    """Wrapper so we can map in ThreadPoolExecutor."""
    (player_name, season, salary, all_players, debug) = args
    stats = process_player_data(player_name, season, all_players, debug)
    if stats:
        stats['Salary'] = salary
    return stats

# ----------------------------------------------------------------------
def update_data(existing_data,
                start_year: int,
                end_year: int,
                *,
                player_filter: str = "all",
                min_avg_minutes: float | None = None,
                debug: bool = False,
                max_workers: int = 8,
                output_base: str | Path = DATA_PROCESSED_DIR,
                overwrite: bool = False) -> pd.DataFrame:
    """
    Pull the seasons in [start_year, end_year] and write everything under
    `output_base` (parquet partitions + per‑season artifacts).
    Skips a season when an identical parquet + md5 already exist.
    """
    output_base = Path(output_base)
    output_base.mkdir(parents=True, exist_ok=True)

    injury = load_injury_data()
    salary_df = scrape_player_salary_data(start_year, end_year,
                                          player_filter, debug)

    out_frames: list[pd.DataFrame] = []

    for y in tqdm(range(start_year, end_year + 1), desc="Seasons"):
        season = f"{y}-{str(y+1)[-2:]}"
        ckpt_dir = output_base / f"season={season}"
        ckpt_dir.mkdir(parents=True, exist_ok=True)        # <‑‑ FIX

        if (not overwrite
            and (ckpt_dir / "part.parquet").exists()
            and _season_partition_identical(season, output_base, salary_df.query("Season == @season"))):
            if debug:
                print(f"✓  {season} unchanged – skipping")
            continue
        elif debug and (ckpt_dir / "part.parquet").exists():
            print(f"↻  {season} differs – re‑scraping")

        # -------- scrape per‑season data ---------------------------------
        team_payroll = scrape_team_salary_data(season, debug)
        if team_payroll.empty:
            team_payroll = pd.DataFrame(columns=["Team", "Team_Salary", "Season"])

        players_this_season = fetch_season_players(season, debug)
        rows = salary_df.query("Season == @season")

        args = [(row.Player, season, row.Salary, players_this_season, debug)
                for _, row in rows.iterrows()]

        with ThreadPoolExecutor(max_workers=max_workers or DEFAULT_WORKERS) as pool:
            results = [r for r in
                       tqdm(pool.map(_player_task, args), total=len(args), leave=False, desc=season)
                       if r]

        # -------- handle roster gaps -------------------------------------
        missing = rows.loc[~rows.Player.str.lower()
                           .isin(players_this_season.keys()), "Player"].unique()
        if missing.size and debug:
            print(f"⚠️  {len(missing)} players not in roster for {season}")
        (ckpt_dir / "missing_players.txt").write_text("\n".join(missing))

        df_season = pd.DataFrame(results)
        if df_season.empty:
            continue

        merged = (pd.merge(df_season, team_payroll, on=["Team", "Season"], how="left")
                    .pipe(lambda d: d.query("MP >= @min_avg_minutes") if min_avg_minutes else d)
                    .pipe(merge_injury_data, injury_data=injury)
                    .pipe(calculate_percentages, debug=debug)
                    .pipe(clean_dataframe))

        # -------- write parquet + md5 ------------------------------------
        parquet_path = ckpt_dir / "part.parquet"
        merged.to_parquet(parquet_path, index=False)
        (ckpt_dir / "part.md5").write_text(_file_md5(parquet_path))

        out_frames.append(merged)
        logging.info("wrote %s", ckpt_dir)

    return pd.concat(out_frames, ignore_index=True) if out_frames else pd.DataFrame()

def get_timestamp():
    """Return a filesystem-safe timestamp string."""
    return datetime.now().strftime("%Y-%m-%d_%H-%M-%S")

def remove_old_logs(log_dir, days_to_keep=7):
    current_time = datetime.now()
    for log_file in glob.glob(os.path.join(log_dir, 'stat_pull_log_*.txt')):
        file_modified_time = datetime.fromtimestamp(os.path.getmtime(log_file))
        if current_time - file_modified_time > timedelta(days=days_to_keep):
            os.remove(log_file)

def main(start_year: int,
         end_year: int,
         player_filter: str = "all",
         min_avg_minutes: float = 15,
         debug: bool = False,
         workers: int = 8,
         overwrite: bool = False,
         output_base: str | Path = DATA_PROCESSED_DIR) -> None:
    """
    CLI / notebook entry point.
    All artefacts go under `output_base`; log files remain in stat_pull_output.
    """
    t0 = time.time()
    output_base = Path(output_base)
    output_base.mkdir(parents=True, exist_ok=True)

    log_dir = output_base.parent / "stat_pull_output"
    log_dir.mkdir(parents=True, exist_ok=True)
    remove_old_logs(log_dir)

    log_file = log_dir / f"stat_pull_log_{get_timestamp()}.txt"
    logging.basicConfig(filename=log_file,
                        level=logging.DEBUG if debug else logging.INFO,
                        format="%(asctime)s - %(levelname)s - %(message)s")

    updated = update_data(None, start_year, end_year,
                          player_filter=player_filter,
                          min_avg_minutes=min_avg_minutes,
                          debug=debug,
                          max_workers=workers,
                          output_base=str(output_base),
                          overwrite=overwrite)

    print(f"✔ Completed pull: {len(updated):,} rows added")

    if not updated.empty:
        salary_cap = scrape_salary_cap_history(debug=debug)
        if salary_cap is not None:
            cap_csv = output_base / "salary_cap_history_inflated.csv"
            salary_cap.to_csv(cap_csv, index=False)
            updated = merge_salary_cap_data(updated, salary_cap)

        # Run comprehensive data audit
        from salary_nba_data_pull.data_utils import validate_data
        updated = validate_data(updated, name="player_dataset", save_reports=True)

        final_csv = output_base / "nba_player_data_final_inflated.csv"
        updated.to_csv(final_csv, index=False, float_format="%.2f")
        if debug:
            print(f"Updated flat‑file saved to {final_csv}")

    print(f"Process finished in {time.time() - t0:.1f} s — log: {log_file}")
# ----------------------------------------------------------------------

# argparse snippet (bottom of file – keep imports above):
if __name__ == "__main__":
    cur = datetime.now().year
    p = argparse.ArgumentParser()
    p.add_argument("--start_year", type=int, default=cur-1)
    p.add_argument("--end_year",   type=int, default=cur)
    p.add_argument("--player_filter", default="all")
    p.add_argument("--min_avg_minutes", type=float, default=15)
    p.add_argument("--debug", action="store_true")
    p.add_argument("--workers", type=int, default=8)
    p.add_argument("--overwrite", action="store_true")
    p.add_argument("--output_base",
                   default=str(DATA_PROCESSED_DIR),
                   help="Destination root for parquet + csv outputs")
    args = p.parse_args()
    main(**vars(args))
# Out:
# Overwriting ../src/salary_nba_data_pull/main.py

# %%
# %%writefile ../src/salary_nba_data_pull/notebook_helper.py
"""
Notebook/REPL helper utilities for salary_nba_data_pull.

Goals
-----
• Work no matter where the notebook is opened (absolute paths).
• Avoid NameError on __file__.
• Keep hot‑reload for iterative dev.
• Forward arbitrary args to main() so we can test all scenarios.

Use:
>>> import salary_nba_data_pull.notebook_helper as nb
>>> nb.quick_pull(2024, workers=12, debug=True)
"""

from __future__ import annotations

import sys
import importlib
import inspect
from pathlib import Path
from typing import Iterable
from salary_nba_data_pull.settings import DATA_PROCESSED_DIR

# ----------  PATH / ROOT DISCOVERY  ---------------------------------
def find_repo_root(start: Path | None = None) -> Path:
    """Walk upward until we find pyproject.toml or .git."""
    markers = {"pyproject.toml", ".git"}
    here = (start or Path.cwd()).resolve()
    for p in [here] + list(here.parents):
        if any((p / m).exists() for m in markers):
            return p
    return here

try:
    # __file__ is undefined in Jupyter; this will raise NameError there.
    _MODULE_PATH = Path(__file__).resolve()
except NameError:
    _MODULE_PATH = Path.cwd()

ROOT = find_repo_root(_MODULE_PATH)

if str(ROOT) not in sys.path:
    # Put project root at the *front* so local package wins over installed ones.
    sys.path.insert(0, str(ROOT))
    print(f"[notebook_helper] Added ROOT to sys.path: {ROOT}")

# ----------  IMPORT PACKAGE MAIN (ABSOLUTE)  ------------------------
from salary_nba_data_pull import main as nba_main  # noqa: E402  (import after sys.path tweak)

def _reload():
    """Reload the main module so code edits are picked up."""
    importlib.reload(nba_main)

# ----------  USER-FACING WRAPPERS  ----------------------------------
def quick_pull(season: int, **kwargs):
    """
    Pull a single season.
    All kwargs are passed straight into nba_main.main()
    so you can test: debug, workers, overwrite, player_filter, etc.
    """
    _reload()
    print(f"[quick_pull] season={season}, kwargs={kwargs}")
    nba_main.main(start_year=season, end_year=season, **kwargs)

def historical_pull(start_year: int, end_year: int, **kwargs):
    """Pull an inclusive range of seasons."""
    _reload()
    print(f"[historical_pull] {start_year}-{end_year}, kwargs={kwargs}")
    nba_main.main(start_year=start_year, end_year=end_year, **kwargs)

def check_existing_data(base: Path | str | None = None) -> list[str]:
    """Return the list of partitioned seasons already present."""
    base = Path(base) if base else DATA_PROCESSED_DIR
    seasons = sorted(
        d.name.split("=", 1)[-1] for d in base.glob("season=*") if d.is_dir()
    )
    print(f"[check_existing_data] found {len(seasons)} seasons in {base}")
    return seasons

def load_parquet_data(
    season: str | None = None, *,
    base: Path | str | None = None
) -> pd.DataFrame:
    """
    Load parquet partitions into a DataFrame.
    If `season` is None, load all partitions.
    """
    import pandas as pd
    base = Path(base) if base else DATA_PROCESSED_DIR
    if season:
        files = list(base.glob(f"season={season}/part.parquet"))
    else:
        files = list(base.glob("season=*/part.parquet"))

    if not files:
        print("[load_parquet_data] No parquet files found.")
        return pd.DataFrame()

    print(f"[load_parquet_data] loading {len(files)} files from {base}")
    return pd.concat((pd.read_parquet(f) for f in files), ignore_index=True)

def clear_all_caches():
    """Clear requests-cache and joblib memory caches."""
    import requests_cache
    from salary_nba_data_pull.fetch_utils import clear_cache as _cc
    requests_cache.clear()
    _cc()
    print("✅ caches cleared")

def print_args():
    """
    Show every argument accepted by nba_main.main() with its default value.
    Handy for quick tests in notebooks.
    """
    sig = inspect.signature(nba_main.main)
    for name, param in sig.parameters.items():
        print(f"{name:<15} default={param.default!r}  kind={param.kind}")

# ----------  CLI-ish entry point for quick manual test --------------
if __name__ == "__main__":
    print_args()           # <-- shows the table
    quick_pull(2023, workers=4, debug=True)



    historical_pull(2019, 2024,        # multi‑season
                    workers=6,
                    min_avg_minutes=10,
                    overwrite=False,
                    debug=True)
    check_existing_data()              # see which seasons are cached
    df = load_parquet_data("2023-24")  # inspect a single season
# Out:
# [notebook_helper] Added ROOT to sys.path: C:\docker_projects\coach_analysis
# start_year      default=<class 'inspect._empty'>  kind=POSITIONAL_OR_KEYWORD
# end_year        default=<class 'inspect._empty'>  kind=POSITIONAL_OR_KEYWORD
# player_filter   default='all'  kind=POSITIONAL_OR_KEYWORD
# min_avg_minutes default=15  kind=POSITIONAL_OR_KEYWORD
# debug           default=False  kind=POSITIONAL_OR_KEYWORD
# workers         default=8  kind=POSITIONAL_OR_KEYWORD
# overwrite       default=False  kind=POSITIONAL_OR_KEYWORD
# output_base     default=WindowsPath('C:/docker_projects/coach_analysis/data/new_processed')  kind=POSITIONAL_OR_KEYWORD
# [quick_pull] season=2023, kwargs={'workers': 4, 'debug': True}
# [fetch] https://hoopshype.com/salaries/players/2023-24/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://hoopshype.com/salaries/players/2023-2024/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/1 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/2 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/3 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/4 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/5 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/6 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/7 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/8 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/9 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/10 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/11 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/12 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2024/page/13 (attempt 1)
#   -> ESPN fallback added 475 rows
#   -> scraped 475 rows for 2023-24
# Seasons:   0%|          | 0/1 [00:00<?, ?it/s]
# ↻  2023-24 differs – re‑scraping
# [fetch] https://hoopshype.com/salaries/2023-24/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://hoopshype.com/salaries/2023-2024/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://www.espn.com/nba/salaries/_/type/team/year/2024 (attempt 1)
#   -> ESPN team salary fallback added 40 rows
#                 Team  Team_Salary   Season
# 0  Stephen Curry, PG     51915615  2023-24
# 1   Kevin Durant, PF     47649433  2023-24
# 2   LeBron James, SF     47607350  2023-24
# 3    Nikola Jokic, C     47607350  2023-24
# 4     Joel Embiid, C     46900000  2023-24
# [fetch_season_players] 596 players for 2023-24
# Processing Stephen Curry (ID: 201939)
# Processing Kevin Durant (ID: 201142)
# Processing Lebron James (ID: 2544)
# Processing Nikola Jokic (ID: 203999)
# Successfully processed Kevin Durant: 25 fields
# Processing Joel Embiid (ID: 203954)
# Successfully processed Stephen Curry: 25 fields
# Processing Bradley Beal (ID: 203078)
# Successfully processed Nikola Jokic: 25 fields
# Processing Giannis Antetokounmpo (ID: 203507)
# Successfully processed Lebron James: 25 fields
# Processing Damian Lillard (ID: 203081)
# Successfully processed Joel Embiid: 25 fields
# Processing Kawhi Leonard (ID: 202695)
# Successfully processed Giannis Antetokounmpo: 25 fields
# Processing Paul George (ID: 202331)
# Successfully processed Bradley Beal: 25 fields
# Processing Jimmy Butler Iii (ID: 202710)
# 2023-24:   0%|          | 0/475 [00:00<?, ?it/s]
# Successfully processed Damian Lillard: 25 fields
# Processing Klay Thompson (ID: 202691)
# Successfully processed Kawhi Leonard: 25 fields
# Processing Rudy Gobert (ID: 203497)
# Successfully processed Jimmy Butler Iii: 25 fields
# Processing Fred Vanvleet (ID: 1627832)
# Successfully processed Paul George: 25 fields
# Processing Anthony Davis (ID: 203076)
# Successfully processed Klay Thompson: 25 fields
# Processing Luka Doncic (ID: 1629029)
# Successfully processed Fred Vanvleet: 25 fields
# Processing Zach Lavine (ID: 203897)
# Successfully processed Rudy Gobert: 25 fields
# Processing Trae Young (ID: 1629027)
# Successfully processed Anthony Davis: 25 fields
# Processing Tobias Harris (ID: 202699)
# Successfully processed Luka Doncic: 25 fields
# Processing Ben Simmons (ID: 1627732)
# Successfully processed Trae Young: 25 fields
# Processing Pascal Siakam (ID: 1627783)
# Successfully processed Zach Lavine: 25 fields
# Processing Kyrie Irving (ID: 202681)
# Successfully processed Tobias Harris: 25 fields
# Processing Jrue Holiday (ID: 201950)
# Successfully processed Pascal Siakam: 25 fields
# Processing Devin Booker (ID: 1626164)
# Successfully processed Ben Simmons: 25 fields
# Processing Karl-Anthony Towns (ID: 1626157)
# Successfully processed Kyrie Irving: 25 fields
# Processing Kristaps Porzingis (ID: 204001)
# Successfully processed Devin Booker: 25 fields
# Processing Cj Mccollum (ID: 203468)
# Successfully processed Jrue Holiday: 25 fields
# Processing James Harden (ID: 201935)
# Successfully processed Kristaps Porzingis: 25 fields
# Processing Ja Morant (ID: 1629630)
# Successfully processed Karl-Anthony Towns: 25 fields
# Processing Darius Garland (ID: 1629636)
# Successfully processed Cj Mccollum: 25 fields
# Processing Zion Williamson (ID: 1629627)
# Successfully processed James Harden: 25 fields
# Processing Jamal Murray (ID: 1627750)
# Successfully processed Darius Garland: 25 fields
# Processing Brandon Ingram (ID: 1627742)
# Successfully processed Ja Morant: 25 fields
# Processing Shai Gilgeous-Alexander (ID: 1628983)
# Successfully processed Zion Williamson: 25 fields
# Processing Michael Porter Jr. (ID: 1629008)
# Successfully processed Jamal Murray: 25 fields
# Processing Donovan Mitchell (ID: 1628378)
# Successfully processed Brandon Ingram: 25 fields
# Processing De'Aaron Fox (ID: 1628368)
# Successfully processed Shai Gilgeous-Alexander: 25 fields
# Processing Bam Adebayo (ID: 1628389)
# Successfully processed Michael Porter Jr.: 25 fields
# Processing Jayson Tatum (ID: 1628369)
# Successfully processed Donovan Mitchell: 25 fields
# Processing Deandre Ayton (ID: 1629028)
# Successfully processed De'Aaron Fox: 25 fields
# Processing Jaylen Brown (ID: 1627759)
# Successfully processed Bam Adebayo: 25 fields
# Processing Gordon Hayward (ID: 202330)
# Successfully processed Deandre Ayton: 25 fields
# Processing Chris Paul (ID: 101108)
# Successfully processed Jayson Tatum: 25 fields
# Processing Domantas Sabonis (ID: 1627734)
# Successfully processed Jaylen Brown: 25 fields
# Processing Khris Middleton (ID: 203114)
# Successfully processed Gordon Hayward: 25 fields
# Processing Demar Derozan (ID: 201942)
# Successfully processed Chris Paul: 25 fields
# Processing Julius Randle (ID: 203944)
# Successfully processed Domantas Sabonis: 25 fields
# Processing Jordan Poole (ID: 1629673)
# Successfully processed Demar Derozan: 25 fields
# Processing Jerami Grant (ID: 203924)
# Successfully processed Julius Randle: 25 fields
# Processing Jaren Jackson Jr. (ID: 1628991)
# Successfully processed Jordan Poole: 25 fields
# Processing Tyler Herro (ID: 1629639)
# Successfully processed Khris Middleton: 25 fields
# Processing Jalen Brunson (ID: 1628973)
# Successfully processed Jerami Grant: 25 fields
# Processing Cameron Johnson (ID: 1629661)
# Successfully processed Jaren Jackson Jr.: 25 fields
# Processing Kyle Kuzma (ID: 1628398)
# Successfully processed Jalen Brunson: 25 fields
# Processing John Collins (ID: 1628381)
# Successfully processed Tyler Herro: 25 fields
# Processing Brook Lopez (ID: 201572)
# Successfully processed Cameron Johnson: 25 fields
# Processing Mike Conley (ID: 201144)
# Successfully processed Kyle Kuzma: 25 fields
# Processing Andrew Wiggins (ID: 203952)
# Successfully processed John Collins: 25 fields
# Processing Anfernee Simons (ID: 1629014)
# Successfully processed Brook Lopez: 25 fields
# Processing Rj Barrett (ID: 1629628)
# Successfully processed Mike Conley: 25 fields
# Processing Jordan Clarkson (ID: 203903)
# Successfully processed Anfernee Simons: 25 fields
# Processing Dillon Brooks (ID: 1628415)
# Successfully processed Andrew Wiggins: 25 fields
# Processing Malcolm Brogdon (ID: 1627763)
# Successfully processed Rj Barrett: 25 fields
# Processing Draymond Green (ID: 203110)
# Successfully processed Jordan Clarkson: 25 fields
# Processing Aaron Gordon (ID: 203932)
# Successfully processed Dillon Brooks: 25 fields
# Processing Terry Rozier (ID: 1626179)
# Successfully processed Malcolm Brogdon: 25 fields
# Processing Bruce Brown (ID: 1628971)
# Successfully processed Draymond Green: 25 fields
# Processing Mikal Bridges (ID: 1628969)
# Successfully processed Aaron Gordon: 25 fields
# Processing Myles Turner (ID: 1626167)
# Successfully processed Terry Rozier: 25 fields
# Processing Clint Capela (ID: 203991)
# Successfully processed Bruce Brown: 25 fields
# Processing Lonzo Ball (ID: 1628366)
# Successfully processed Mikal Bridges: 25 fields
# Processing De'Andre Hunter (ID: 1629631)
# Successfully processed Myles Turner: 25 fields
# Processing Keldon Johnson (ID: 1629640)
# No stats found for Lonzo Ball in season 2023-24
# Processing Bojan Bogdanovic (ID: 202711)
# Successfully processed Clint Capela: 25 fields
# Processing Jarrett Allen (ID: 1628386)
# Successfully processed De'Andre Hunter: 25 fields
# Processing Joe Harris (ID: 203925)
# Successfully processed Keldon Johnson: 25 fields
# Processing Jakob Poeltl (ID: 1627751)
# Successfully processed Jarrett Allen: 25 fields
# Processing Buddy Hield (ID: 1627741)
# Successfully processed Joe Harris: 25 fields
# Processing Evan Fournier (ID: 203095)
# Successfully processed Bojan Bogdanovic: 25 fields
# Processing Marcus Smart (ID: 203935)
# Successfully processed Buddy Hield: 25 fields
# Processing Bogdan Bogdanovic (ID: 203992)
# Successfully processed Jakob Poeltl: 25 fields
# Processing Og Anunoby (ID: 1628384)
# Successfully processed Evan Fournier: 25 fields
# Processing Gary Trent Jr. (ID: 1629018)
# Successfully processed Marcus Smart: 25 fields
# Processing Nikola Vucevic (ID: 202696)
# Successfully processed Bogdan Bogdanovic: 25 fields
# Processing Derrick White (ID: 1628401)
# Successfully processed Og Anunoby: 25 fields
# Processing Dejounte Murray (ID: 1627749)
# Successfully processed Nikola Vucevic: 25 fields
# Processing Duncan Robinson (ID: 1629130)
# Successfully processed Gary Trent Jr.: 25 fields
# Processing Norman Powell (ID: 1626181)
# Successfully processed Derrick White: 25 fields
# Processing Tim Hardaway Jr. (ID: 203501)
# Successfully processed Dejounte Murray: 25 fields
# Processing Jonathan Isaac (ID: 1628371)
# Successfully processed Norman Powell: 25 fields
# Processing Collin Sexton (ID: 1629012)
# Successfully processed Duncan Robinson: 25 fields
# Processing D'Angelo Russell (ID: 1626156)
# Successfully processed Jonathan Isaac: 25 fields
# Processing Lauri Markkanen (ID: 1628374)
# Successfully processed Collin Sexton: 25 fields
# Processing Marcus Morris Sr. (ID: 202694)
# Successfully processed D'Angelo Russell: 25 fields
# Processing Davis Bertans (ID: 202722)
# Successfully processed Tim Hardaway Jr.: 25 fields
# Processing Harrison Barnes (ID: 203084)
# Successfully processed Davis Bertans: 25 fields
# Processing Markelle Fultz (ID: 1628365)
# Successfully processed Lauri Markkanen: 25 fields
# Processing Jusuf Nurkic (ID: 203994)
# Successfully processed Harrison Barnes: 25 fields
# Processing P.J. Washington (ID: 1629023)
# Successfully processed Marcus Morris Sr.: 25 fields
# Processing Kevin Porter Jr. (ID: 1629645)
# Successfully processed Jusuf Nurkic: 25 fields
# Processing Rui Hachimura (ID: 1629060)
# Successfully processed Markelle Fultz: 25 fields
# Processing Mitchell Robinson (ID: 1629011)
# Successfully processed P.J. Washington: 25 fields
# Processing Kevin Huerter (ID: 1628989)
# No stats found for Kevin Porter Jr. in season 2023-24
# Processing Jonas Valanciunas (ID: 202685)
# Successfully processed Mitchell Robinson: 25 fields
# Processing Luke Kennard (ID: 1628379)
# Successfully processed Rui Hachimura: 25 fields
# Processing Caris Levert (ID: 1627747)
# Successfully processed Kevin Huerter: 25 fields
# Processing Luguentz Dort (ID: 1629652)
# Successfully processed Jonas Valanciunas: 25 fields
# Processing Kentavious Caldwell-Pope (ID: 203484)
# Successfully processed Luke Kennard: 25 fields
# Processing Max Strus (ID: 1629622)
# Successfully processed Caris Levert: 25 fields
# Processing Tyus Jones (ID: 1626145)
# Successfully processed Luguentz Dort: 25 fields
# Processing Dorian Finney-Smith (ID: 1627827)
# Successfully processed Kentavious Caldwell-Pope: 25 fields
# Processing Doug Mcdermott (ID: 203926)
# Successfully processed Max Strus: 25 fields
# Processing Wendell Carter Jr. (ID: 1628976)
# Successfully processed Tyus Jones: 25 fields
# Processing Gary Harris (ID: 203914)
# Successfully processed Dorian Finney-Smith: 25 fields
# Processing Josh Hart (ID: 1628404)
# Successfully processed Doug Mcdermott: 25 fields
# Processing Naz Reid (ID: 1629675)
# Successfully processed Wendell Carter Jr.: 25 fields
# Processing Steven Adams (ID: 203500)
# Successfully processed Gary Harris: 25 fields
# Processing Brandon Clarke (ID: 1629634)
# Successfully processed Josh Hart: 25 fields
# Processing Marvin Bagley Iii (ID: 1628963)
# Successfully processed Naz Reid: 25 fields
# Processing Dennis Schroder (ID: 203471)
# No stats found for Steven Adams in season 2023-24
# Processing Daniel Gafford (ID: 1629655)
# Successfully processed Brandon Clarke: 25 fields
# Processing Grant Williams (ID: 1629684)
# Successfully processed Marvin Bagley Iii: 25 fields
# Processing Kelly Olynyk (ID: 203482)
# Successfully processed Dennis Schroder: 25 fields
# Processing Victor Wembanyama (ID: 1641705)
# Successfully processed Daniel Gafford: 25 fields
# Processing James Wiseman (ID: 1630164)
# Successfully processed Grant Williams: 25 fields
# Processing Devonte' Graham (ID: 1628984)
# Successfully processed Kelly Olynyk: 25 fields
# Processing Richaun Holmes (ID: 1626158)
# Successfully processed Victor Wembanyama: 25 fields
# Processing Austin Reaves (ID: 1630559)
# Successfully processed James Wiseman: 25 fields
# Processing Herbert Jones (ID: 1630529)
# Successfully processed Devonte' Graham: 25 fields
# Processing Chris Boucher (ID: 1628449)
# Successfully processed Richaun Holmes: 25 fields
# Processing Nicolas Batum (ID: 201587)
# Successfully processed Austin Reaves: 25 fields
# Processing Bobby Portis (ID: 1626171)
# Successfully processed Nicolas Batum: 25 fields
# Processing Robert Covington (ID: 203496)
# Successfully processed Herbert Jones: 25 fields
# Processing Paolo Banchero (ID: 1631094)
# Successfully processed Chris Boucher: 25 fields
# Processing Robert Williams Iii (ID: 1629057)
# Successfully processed Bobby Portis: 25 fields
# Processing Coby White (ID: 1629632)
# Successfully processed Robert Williams Iii: 25 fields
# Processing Cade Cunningham (ID: 1630595)
# Successfully processed Paolo Banchero: 25 fields
# Processing Talen Horton-Tucker (ID: 1629659)
# Successfully processed Robert Covington: 25 fields
# Processing P.J. Tucker (ID: 200782)
# Successfully processed Coby White: 25 fields
# Processing Joe Ingles (ID: 204060)
# Successfully processed Cade Cunningham: 25 fields
# Processing Maxi Kleber (ID: 1628467)
# Successfully processed P.J. Tucker: 25 fields
# Processing Donte Divincenzo (ID: 1628978)
# Successfully processed Joe Ingles: 25 fields
# Processing Ivica Zubac (ID: 1627826)
# Successfully processed Talen Horton-Tucker: 25 fields
# Processing Lamelo Ball (ID: 1630163)
# Successfully processed Maxi Kleber: 25 fields
# Processing Brandon Miller (ID: 1641706)
# Successfully processed Ivica Zubac: 25 fields
# Processing Terance Mann (ID: 1629611)
# Successfully processed Donte Divincenzo: 25 fields
# Processing Matisse Thybulle (ID: 1629680)
# Successfully processed Lamelo Ball: 25 fields
# Processing Gabe Vincent (ID: 1629216)
# Successfully processed Brandon Miller: 25 fields
# Processing Alec Burks (ID: 202692)
# Successfully processed Terance Mann: 25 fields
# Processing Chet Holmgren (ID: 1631096)
# Successfully processed Gabe Vincent: 25 fields
# Processing Larry Nance Jr. (ID: 1626204)
# Successfully processed Matisse Thybulle: 25 fields
# Processing Landry Shamet (ID: 1629013)
# Successfully processed Larry Nance Jr.: 25 fields
# Processing Al Horford (ID: 201143)
# Successfully processed Landry Shamet: 25 fields
# Processing Malik Monk (ID: 1628370)
# Successfully processed Alec Burks: 25 fields
# Processing Tre Jones (ID: 1630200)
# Successfully processed Chet Holmgren: 25 fields
# Processing Jalen Green (ID: 1630224)
# Successfully processed Malik Monk: 25 fields
# Processing Patrick Williams (ID: 1630172)
# Successfully processed Jalen Green: 25 fields
# Processing Monte Morris (ID: 1628420)
# Successfully processed Tre Jones: 25 fields
# Processing Scoot Henderson (ID: 1630703)
# Successfully processed Al Horford: 25 fields
# Processing Nic Claxton (ID: 1629651)
# Successfully processed Patrick Williams: 25 fields
# Processing Jeff Green (ID: 201145)
# Successfully processed Monte Morris: 25 fields
# Processing Royce O'Neale (ID: 1626220)
# Successfully processed Scoot Henderson: 25 fields
# Processing Alex Caruso (ID: 1627936)
# Successfully processed Nic Claxton: 25 fields
# Player Victor Oladipo not found in all_players
# Processing Pat Connaughton (ID: 1626192)
# Successfully processed Jeff Green: 25 fields
# Processing Jabari Smith Jr. (ID: 1631095)
# Successfully processed Alex Caruso: 25 fields
# Processing Isaiah Hartenstein (ID: 1628392)
# Successfully processed Pat Connaughton: 25 fields
# Processing Anthony Edwards (ID: 1630162)
# Successfully processed Royce O'Neale: 25 fields
# Processing Kyle Anderson (ID: 203937)
# Successfully processed Jabari Smith Jr.: 25 fields
# Processing Grayson Allen (ID: 1628960)
# Successfully processed Isaiah Hartenstein: 25 fields
# Processing Isaac Okoro (ID: 1630171)
# Successfully processed Anthony Edwards: 25 fields
# Processing Evan Mobley (ID: 1630596)
# Successfully processed Kyle Anderson: 25 fields
# Processing Amen Thompson (ID: 1641708)
# Successfully processed Isaac Okoro: 25 fields
# Processing Georges Niang (ID: 1627777)
# Successfully processed Evan Mobley: 25 fields
# Processing Gary Payton Ii (ID: 1627780)
# Successfully processed Grayson Allen: 25 fields
# Processing T.J. Mcconnell (ID: 204456)
# Successfully processed Amen Thompson: 25 fields
# Processing Keegan Murray (ID: 1631099)
# Successfully processed T.J. Mcconnell: 25 fields
# Processing Onyeka Okongwu (ID: 1630168)
# Successfully processed Georges Niang: 25 fields
# Processing Scottie Barnes (ID: 1630567)
# Successfully processed Gary Payton Ii: 25 fields
# Processing Trey Lyles (ID: 1626168)
# Successfully processed Keegan Murray: 25 fields
# Processing De'Anthony Melton (ID: 1629001)
# Successfully processed Onyeka Okongwu: 25 fields
# Processing Moritz Wagner (ID: 1629021)
# Successfully processed Scottie Barnes: 25 fields
# Processing Jock Landale (ID: 1629111)
# Successfully processed Trey Lyles: 25 fields
# Processing Ausar Thompson (ID: 1641709)
# Successfully processed De'Anthony Melton: 25 fields
# Processing Miles Bridges (ID: 1628970)
# Successfully processed Moritz Wagner: 25 fields
# Processing Vasilije Micic (ID: 203995)
# Successfully processed Jock Landale: 25 fields
# Processing Paul Reed (ID: 1630194)
# Successfully processed Ausar Thompson: 25 fields
# Processing Zach Collins (ID: 1628380)
# Successfully processed Miles Bridges: 25 fields
# Processing Jaden Ivey (ID: 1631093)
# Successfully processed Vasilije Micic: 25 fields
# Processing Cody Martin (ID: 1628998)
# Successfully processed Paul Reed: 25 fields
# Processing Kevon Looney (ID: 1626172)
# Successfully processed Zach Collins: 25 fields
# Processing Taurean Prince (ID: 1627752)
# Successfully processed Cody Martin: 25 fields
# Processing Killian Hayes (ID: 1630165)
# Successfully processed Jaden Ivey: 25 fields
# Processing Jalen Suggs (ID: 1630591)
# Successfully processed Kevon Looney: 25 fields
# Processing Anthony Black (ID: 1641710)
# Successfully processed Taurean Prince: 25 fields
# Player Khem Birch not found in all_players
# Processing Bennedict Mathurin (ID: 1631097)
# Successfully processed Jalen Suggs: 25 fields
# Processing Obi Toppin (ID: 1630167)
# Successfully processed Anthony Black: 25 fields
# Processing Caleb Martin (ID: 1628997)
# Successfully processed Killian Hayes: 25 fields
# Processing Cedi Osman (ID: 1626224)
# Successfully processed Bennedict Mathurin: 25 fields
# Processing Bilal Coulibaly (ID: 1641731)
# Successfully processed Obi Toppin: 25 fields
# Processing Josh Giddey (ID: 1630581)
# Successfully processed Cedi Osman: 25 fields
# Processing Cameron Payne (ID: 1626166)
# Successfully processed Bilal Coulibaly: 25 fields
# Processing Jae'Sean Tate (ID: 1630256)
# Successfully processed Caleb Martin: 25 fields
# Processing Ayo Dosunmu (ID: 1630245)
# Successfully processed Josh Giddey: 25 fields
# Player Rudy Gay not found in all_players
# Processing Sasha Vezenkov (ID: 1628426)
# Successfully processed Cameron Payne: 25 fields
# Processing Shaedon Sharpe (ID: 1631101)
# Successfully processed Jae'Sean Tate: 25 fields
# Processing Otto Porter Jr. (ID: 203490)
# Successfully processed Ayo Dosunmu: 25 fields
# Processing Deni Avdija (ID: 1630166)
# Successfully processed Sasha Vezenkov: 25 fieldsSuccessfully processed Shaedon Sharpe: 25 fields
# Processing Nassir Little (ID: 1629642)
#
# Processing Jevon Carter (ID: 1628975)
# Successfully processed Deni Avdija: 25 fields
# Processing Kenrich Williams (ID: 1629026)
# Successfully processed Otto Porter Jr.: 25 fields
# Player Ricky Rubio not found in all_players
# Processing Jarace Walker (ID: 1641716)
# Successfully processed Jevon Carter: 25 fields
# Processing Jonathan Kuminga (ID: 1630228)
# Successfully processed Nassir Little: 25 fields
# Processing Devin Vassell (ID: 1630170)
# Successfully processed Jarace Walker: 25 fields
# Processing Tyrese Haliburton (ID: 1630169)
# Successfully processed Kenrich Williams: 25 fields
# Processing Dyson Daniels (ID: 1630700)
# Successfully processed Devin Vassell: 25 fields
# Processing Kira Lewis Jr. (ID: 1630184)
# Successfully processed Jonathan Kuminga: 25 fields
# Processing Dean Wade (ID: 1629731)
# Successfully processed Tyrese Haliburton: 25 fields
# Processing Aaron Nesmith (ID: 1630174)
# Successfully processed Dyson Daniels: 25 fields
# Processing Jalen Smith (ID: 1630188)
# Successfully processed Aaron Nesmith: 25 fields
# Processing Taylor Hendricks (ID: 1641707)
# Successfully processed Kira Lewis Jr.: 25 fields
# Processing Cole Anthony (ID: 1630175)
# Successfully processed Dean Wade: 25 fields
# Processing Franz Wagner (ID: 1630532)
# Successfully processed Jalen Smith: 25 fields
# Processing Garrett Temple (ID: 202066)
# Successfully processed Taylor Hendricks: 25 fields
# Processing Furkan Korkmaz (ID: 1627788)
# Successfully processed Franz Wagner: 25 fields
# Processing Jeremy Sochan (ID: 1631110)
# Successfully processed Cole Anthony: 25 fields
# Processing Cason Wallace (ID: 1641717)
# Successfully processed Garrett Temple: 25 fields
# Processing Chuma Okeke (ID: 1629643)
# Successfully processed Jeremy Sochan: 25 fields
# Processing Isaiah Stewart (ID: 1630191)
# Successfully processed Furkan Korkmaz: 25 fields
# Processing Davion Mitchell (ID: 1630558)
# Successfully processed Chuma Okeke: 25 fields
# Processing Johnny Davis (ID: 1631098)
# Successfully processed Cason Wallace: 25 fields
# Processing Jett Howard (ID: 1641724)
# Successfully processed Isaiah Stewart: 25 fields
# Processing Nick Richards (ID: 1630208)
# Successfully processed Davion Mitchell: 25 fields
# Processing Reggie Jackson (ID: 202704)
# Successfully processed Jett Howard: 25 fields
# Processing Mason Plumlee (ID: 203486)
# Successfully processed Johnny Davis: 25 fields
# Processing Ziaire Williams (ID: 1630533)
# Successfully processed Nick Richards: 25 fields
# Processing Ousmane Dieng (ID: 1631172)
# Successfully processed Reggie Jackson: 25 fields
# Processing Dereck Lively Ii (ID: 1641726)
# Successfully processed Mason Plumlee: 25 fields
# Processing Josh Green (ID: 1630182)
# Successfully processed Ziaire Williams: 25 fields
# Processing Jarred Vanderbilt (ID: 1629020)
# Successfully processed Ousmane Dieng: 25 fields
# Processing Nickeil Alexander-Walker (ID: 1629638)
# Successfully processed Dereck Lively Ii: 25 fields
# Processing James Bouknight (ID: 1630547)
# Successfully processed Josh Green: 25 fields
# Processing Jalen Williams (ID: 1631114)
# Successfully processed Jarred Vanderbilt: 25 fields
# Processing Saddiq Bey (ID: 1630180)
# Successfully processed Nickeil Alexander-Walker: 25 fields
# Processing Gradey Dick (ID: 1641711)
# Successfully processed James Bouknight: 25 fields
# Processing Jalen Mcdaniels (ID: 1629667)
# Successfully processed Jalen Williams: 25 fields
# Processing Precious Achiuwa (ID: 1630173)
# Successfully processed Gradey Dick: 25 fields
# Processing Tyrese Maxey (ID: 1630178)
# Successfully processed Saddiq Bey: 25 fields
# Processing Jalen Duren (ID: 1631105)
# Successfully processed Jalen Mcdaniels: 25 fields
# Processing Danuel House Jr. (ID: 1627863)
# Successfully processed Precious Achiuwa: 25 fields
# Processing Jordan Hawkins (ID: 1641722)
# Successfully processed Jalen Duren: 25 fields
# Processing Zeke Nnaji (ID: 1630192)
# Successfully processed Tyrese Maxey: 25 fields
# Processing Immanuel Quickley (ID: 1630193)
# Successfully processed Danuel House Jr.: 25 fields
# Processing Chris Duarte (ID: 1630537)
# Successfully processed Jordan Hawkins: 25 fields
# Processing Ochai Agbaji (ID: 1630534)
# Successfully processed Immanuel Quickley: 25 fields
# Processing Kobe Bufkin (ID: 1641723)
# Successfully processed Zeke Nnaji: 25 fields
# Processing Payton Pritchard (ID: 1630202)
# Successfully processed Chris Duarte: 25 fields
# Processing Seth Curry (ID: 203552)
# Successfully processed Ochai Agbaji: 25 fields
# Processing Troy Brown Jr. (ID: 1628972)
# Successfully processed Payton Pritchard: 25 fields
# Processing Dwight Powell (ID: 203939)
# Successfully processed Kobe Bufkin: 25 fields
# Processing Moses Moody (ID: 1630541)
# Successfully processed Seth Curry: 25 fields
# Processing Mark Williams (ID: 1631109)
# Successfully processed Troy Brown Jr.: 25 fields
# Processing Jaden Mcdaniels (ID: 1630183)
# Successfully processed Dwight Powell: 25 fields
# Processing Keyonte George (ID: 1641718)
# Successfully processed Moses Moody: 25 fields
# Processing Malachi Flynn (ID: 1630201)
# Successfully processed Mark Williams: 25 fields
# Processing Desmond Bane (ID: 1630217)
# Successfully processed Jaden Mcdaniels: 25 fields
# Processing Kevin Love (ID: 201567)
# Successfully processed Keyonte George: 25 fields
# Processing Russell Westbrook (ID: 201566)
# Successfully processed Malachi Flynn: 25 fields
# Processing Corey Kispert (ID: 1630557)
# Successfully processed Kevin Love: 25 fields
# Processing Aj Griffin (ID: 1631100)
# Successfully processed Desmond Bane: 25 fields
# Processing Jalen Hood-Schifino (ID: 1641720)
# Successfully processed Russell Westbrook: 25 fields
# Processing Amir Coffey (ID: 1629599)
# Successfully processed Corey Kispert: 25 fields
# Processing Alperen Sengun (ID: 1630578)
# Successfully processed Aj Griffin: 25 fields
# Processing Tari Eason (ID: 1631106)
# Successfully processed Jalen Hood-Schifino: 25 fields
# Processing Jaime Jaquez Jr. (ID: 1631170)
# Successfully processed Amir Coffey: 25 fields
# Processing Mike Muscala (ID: 203488)
# Successfully processed Alperen Sengun: 25 fields
# Processing Andre Drummond (ID: 203083)
# Successfully processed Tari Eason: 25 fields
# Processing Trey Murphy Iii (ID: 1630530)
# Successfully processed Jaime Jaquez Jr.: 25 fields
# Processing Brandin Podziemski (ID: 1641764)
# Successfully processed Mike Muscala: 25 fields
# Processing Dalen Terry (ID: 1631207)
# Successfully processed Andre Drummond: 25 fields
# Processing Cam Whitmore (ID: 1641715)
# Successfully processed Trey Murphy Iii: 25 fields
# Processing Jake Laravia (ID: 1631222)
# Successfully processed Brandin Podziemski: 25 fields
# Processing Derrick Rose (ID: 201565)
# Successfully processed Dalen Terry: 25 fields
# Processing Eric Gordon (ID: 201569)
# Successfully processed Cam Whitmore: 25 fields
# Processing Tre Mann (ID: 1630544)
# Successfully processed Derrick Rose: 25 fields
# Processing Noah Clowney (ID: 1641730)
# Successfully processed Jake Laravia: 25 fields
# Processing Malaki Branham (ID: 1631103)
# Successfully processed Eric Gordon: 25 fields
# Processing Simone Fontecchio (ID: 1631323)
# Successfully processed Tre Mann: 25 fields
# Processing Jordan Nwora (ID: 1629670)
# Successfully processed Noah Clowney: 25 fields
# Processing Julian Champagnie (ID: 1630577)
# Successfully processed Malaki Branham: 25 fields
# Processing Dante Exum (ID: 203957)
# Successfully processed Simone Fontecchio: 25 fields
# Processing Dariq Whitehead (ID: 1641727)
# Successfully processed Jordan Nwora: 25 fields
# Processing Christian Braun (ID: 1631128)
# Successfully processed Dante Exum: 25 fields
# Processing Jalen Johnson (ID: 1630552)
# Successfully processed Julian Champagnie: 25 fields
# Processing Josh Richardson (ID: 1626196)
# Successfully processed Dariq Whitehead: 25 fields
# Processing Kris Murray (ID: 1631200)
# Successfully processed Christian Braun: 25 fields
# Processing Walker Kessler (ID: 1631117)
# Successfully processed Josh Richardson: 25 fields
# Processing Josh Okogie (ID: 1629006)
# Successfully processed Jalen Johnson: 25 fields
# Processing Keon Johnson (ID: 1630553)
# Successfully processed Walker Kessler: 25 fields
# Processing Omer Yurtseven (ID: 1630209)
# Successfully processed Kris Murray: 25 fields
# Processing Kyle Lowry (ID: 200768)
# Successfully processed Josh Okogie: 25 fields
# Processing Olivier-Maxence Prosper (ID: 1641765)
# Successfully processed Keon Johnson: 25 fields
# Processing David Roddy (ID: 1631223)
# Successfully processed Kyle Lowry: 25 fields
# Processing Christian Wood (ID: 1626174)
# Successfully processed Omer Yurtseven: 25 fields
# Processing Isaiah Jackson (ID: 1630543)
# Successfully processed David Roddy: 25 fields
# Processing Marcus Sasser (ID: 1631204)
# Successfully processed Olivier-Maxence Prosper: 25 fields
# Processing Marjon Beauchamp (ID: 1630699)
# Successfully processed Isaiah Jackson: 25 fields
# Processing Charles Bassey (ID: 1629646)
# Successfully processed Christian Wood: 25 fields
# Processing Kris Dunn (ID: 1627739)
# Successfully processed Marcus Sasser: 25 fields
# Processing Damian Jones (ID: 1627745)
# Successfully processed Marjon Beauchamp: 25 fields
# Processing Bruno Fernando (ID: 1628981)
# Successfully processed Charles Bassey: 25 fields
# Player Willy Hernangomez not found in all_players
# Processing Ben Sheppard (ID: 1641767)
# Successfully processed Kris Dunn: 25 fields
# Processing Damion Lee (ID: 1627814)
# Successfully processed Damian Jones: 25 fields
# Processing Thomas Bryant (ID: 1628418)
# Successfully processed Bruno Fernando: 25 fields
# Processing Torrey Craig (ID: 1628470)
# Successfully processed Ben Sheppard: 25 fields
# Processing Blake Wesley (ID: 1631104)
# No stats found for Damion Lee in season 2023-24
# Processing Josh Christopher (ID: 1630528)
# Successfully processed Thomas Bryant: 25 fields
# Processing Nick Smith Jr. (ID: 1641733)
# Successfully processed Torrey Craig: 25 fields
# Processing Brice Sensabaugh (ID: 1641729)
# Successfully processed Blake Wesley: 25 fields
# Processing Ty Jerome (ID: 1629660)
# Successfully processed Nick Smith Jr.: 25 fields
# Processing Julian Strawther (ID: 1631124)
# No stats found for Josh Christopher in season 2023-24
# Processing Wendell Moore Jr. (ID: 1631111)
# Successfully processed Brice Sensabaugh: 25 fields
# Processing Kobe Brown (ID: 1641738)
# Successfully processed Ty Jerome: 25 fields
# Processing Pj Dozier (ID: 1628408)
# Successfully processed Julian Strawther: 25 fields
# Processing Luke Kornet (ID: 1628436)
# Successfully processed Wendell Moore Jr.: 25 fields
# Processing John Konchar (ID: 1629723)
# Successfully processed Kobe Brown: 25 fields
# Processing Quentin Grimes (ID: 1629656)
# No stats found for Pj Dozier in season 2023-24
# Processing Keita Bates-Diop (ID: 1628966)
# Successfully processed Luke Kornet: 25 fields
# Processing Nikola Jovic (ID: 1631107)
# Successfully processed John Konchar: 25 fields
# Processing Yuta Watanabe (ID: 1629139)
# Successfully processed Quentin Grimes: 25 fields
# Processing Drew Eubanks (ID: 1629234)
# Successfully processed Keita Bates-Diop: 25 fields
# Processing Patrick Baldwin Jr. (ID: 1631116)
# Successfully processed Yuta Watanabe: 25 fields
# Processing Jordan Mclaughlin (ID: 1629162)
# Successfully processed Nikola Jovic: 25 fields
# Processing Bones Hyland (ID: 1630538)
# Successfully processed Drew Eubanks: 25 fields
# Processing Peyton Watson (ID: 1631212)
# Successfully processed Patrick Baldwin Jr.: 25 fields
# Processing Cam Thomas (ID: 1630560)
# Successfully processed Peyton Watson: 25 fields
# Processing Vlatko Cancar (ID: 1628427)
# Successfully processed Bones Hyland: 25 fields
# Processing Vince Williams Jr. (ID: 1631246)
# Successfully processed Jordan Mclaughlin: 25 fields
# Processing Jaden Springer (ID: 1630531)
# Successfully processed Cam Thomas: 25 fields
# Processing Day'Ron Sharpe (ID: 1630549)
# Successfully processed Vince Williams Jr.: 25 fields
# Processing Jeremiah Robinson-Earl (ID: 1630526)
# Successfully processed Jaden Springer: 25 fields
# Processing Santi Aldama (ID: 1630583)
# No stats found for Vlatko Cancar in season 2023-24
# Processing Jaxson Hayes (ID: 1629637)
# Successfully processed Day'Ron Sharpe: 25 fields
# Processing Cam Reddish (ID: 1629629)
# Successfully processed Jeremiah Robinson-Earl: 25 fields
# Processing Oshae Brissett (ID: 1629052)
# Successfully processed Jaxson Hayes: 25 fields
# Processing Andrew Nembhard (ID: 1629614)
# Successfully processed Santi Aldama: 25 fields
# Processing Kobi Simmons (ID: 1628424)
# Successfully processed Andrew Nembhard: 25 fields
# Processing Luka Samanic (ID: 1629677)
# Successfully processed Cam Reddish: 25 fields
# Player Isaiah Roby not found in all_players
# Processing Goga Bitadze (ID: 1629048)
# Successfully processed Kobi Simmons: 25 fields
# Processing Tristan Thompson (ID: 202684)
# Successfully processed Oshae Brissett: 25 fields
# Processing Sandro Mamukelashvili (ID: 1630572)
# Successfully processed Goga Bitadze: 25 fields
# Processing Alex Len (ID: 203458)
# Successfully processed Luka Samanic: 25 fields
# Player Montrezl Harrell not found in all_players
# Processing Malik Beasley (ID: 1627736)
# Successfully processed Tristan Thompson: 25 fields
# Processing Jae Crowder (ID: 203109)
# Successfully processed Sandro Mamukelashvili: 25 fields
# Processing Frank Ntilikina (ID: 1628373)
# Successfully processed Malik Beasley: 25 fields
# Processing Ish Smith (ID: 202397)
# Successfully processed Alex Len: 25 fields
# Processing Colby Jones (ID: 1641732)
# Successfully processed Jae Crowder: 25 fields
# Player Nerlens Noel not found in all_players
# Processing Javale Mcgee (ID: 201580)
# Successfully processed Frank Ntilikina: 25 fields
# Processing Robin Lopez (ID: 201577)
# Successfully processed Colby Jones: 25 fields
# Processing Dalano Banton (ID: 1630625)
# Successfully processed Ish Smith: 25 fields
# Processing Moses Brown (ID: 1629650)
# Successfully processed Javale Mcgee: 25 fields
# Processing Bol Bol (ID: 1629626)
# Successfully processed Robin Lopez: 25 fields
# Processing Mo Bamba (ID: 1628964)
# Successfully processed Dalano Banton: 25 fields
# Processing Kelly Oubre Jr. (ID: 1626162)
# Successfully processed Moses Brown: 25 fields
# Processing Danny Green (ID: 201980)
# Successfully processed Bol Bol: 25 fields
# Processing Trendon Watford (ID: 1630570)
# Successfully processed Mo Bamba: 25 fields
# Processing Lonnie Walker Iv (ID: 1629022)
# Successfully processed Kelly Oubre Jr.: 25 fields
# Processing Dennis Smith Jr. (ID: 1628372)
# Successfully processed Danny Green: 25 fields
# Processing Thanasis Antetokounmpo (ID: 203648)
# Successfully processed Trendon Watford: 25 fields
# Processing Patrick Beverley (ID: 201976)
# Successfully processed Lonnie Walker Iv: 25 fields
# Processing Cory Joseph (ID: 202709)
# Successfully processed Dennis Smith Jr.: 25 fields
# Processing Aaron Holiday (ID: 1628988)
# Successfully processed Thanasis Antetokounmpo: 25 fields
# Processing Reggie Bullock Jr. (ID: 203493)
# Successfully processed Cory Joseph: 25 fields
# Processing Boban Marjanovic (ID: 1626246)
# Successfully processed Patrick Beverley: 25 fields
# Processing Dario Saric (ID: 203967)
# Successfully processed Aaron Holiday: 25 fields
# Processing Chimezie Metu (ID: 1629002)
# Successfully processed Reggie Bullock Jr.: 25 fields
# Processing Ryan Arcidiacono (ID: 1627853)
# Successfully processed Boban Marjanovic: 25 fields
# Processing Jalen Pickett (ID: 1629618)
# Successfully processed Dario Saric: 25 fields
# Processing Justin Holiday (ID: 203200)
# Successfully processed Chimezie Metu: 25 fields
# Processing Deandre Jordan (ID: 201599)
# Successfully processed Ryan Arcidiacono: 25 fields
# Processing Derrick Jones Jr. (ID: 1627884)
# Successfully processed Jalen Pickett: 25 fields
# Processing Markieff Morris (ID: 202693)
# Successfully processed Deandre Jordan: 25 fields
# Processing Terry Taylor (ID: 1630678)
# Successfully processed Justin Holiday: 25 fields
# Processing Cody Zeller (ID: 203469)
# Successfully processed Derrick Jones Jr.: 25 fields
# Processing Svi Mykhailiuk (ID: 1629004)
# Successfully processed Terry Taylor: 25 fields
# Processing Wesley Matthews (ID: 202083)
# Successfully processed Cody Zeller: 25 fields
# Processing Jaylin Williams (ID: 1631119)
# Successfully processed Markieff Morris: 25 fields
# Processing Caleb Houstan (ID: 1631216)
# Successfully processed Svi Mykhailiuk: 25 fields
# Processing Garrison Mathews (ID: 1629726)
# Successfully processed Jaylin Williams: 25 fields
# Processing Anthony Gill (ID: 1630264)
# Successfully processed Wesley Matthews: 25 fields
# Processing R.J. Hampton (ID: 1630181)
# Successfully processed Garrison Mathews: 25 fields
# Processing Isaiah Joe (ID: 1630198)
# Successfully processed Caleb Houstan: 25 fields
# Processing Sam Merrill (ID: 1630241)
# Successfully processed Anthony Gill: 25 fields
# Processing Gg Jackson (ID: 1641713)
# Successfully processed Isaiah Joe: 25 fields
# Processing Duop Reath (ID: 1641871)
# Successfully processed Sam Merrill: 25 fields
# Processing Lamar Stevens (ID: 1630205)
# Successfully processed R.J. Hampton: 25 fields
# Processing Kj Martin (ID: 1630231)
# Successfully processed Lamar Stevens: 25 fields
# Processing Kj Martin (ID: 1630231)
# Successfully processed Duop Reath: 25 fields
# Processing Naji Marshall (ID: 1630230)
# Successfully processed Kj Martin: 25 fields
# Processing Xavier Tillman (ID: 1630214)
# Successfully processed Gg Jackson: 25 fields
# Processing Kessler Edwards (ID: 1630556)
# Successfully processed Naji Marshall: 25 fields
# Processing Jericho Sims (ID: 1630579)
# Successfully processed Kj Martin: 25 fields
# Player Joe Wieskamp not found in all_players
# Processing Sam Hauser (ID: 1630573)
# Successfully processed Xavier Tillman: 25 fields
# Player Carlik Jones not found in all_players
# Processing Haywood Highsmith (ID: 1629312)
# Successfully processed Kessler Edwards: 25 fields
# Processing Kevin Knox Ii (ID: 1628995)
# Successfully processed Sam Hauser: 25 fields
# Processing Jt Thor (ID: 1630550)
# Successfully processed Jericho Sims: 25 fields
# Player Isaiah Todd not found in all_players
# Processing Isaiah Livers (ID: 1630587)
# Successfully processed Haywood Highsmith: 25 fields
# Processing Aaron Wiggins (ID: 1630598)
# Successfully processed Kevin Knox Ii: 25 fields
# Processing Miles Mcbride (ID: 1630540)
# Successfully processed Jt Thor: 25 fields
# Processing Brandon Boston (ID: 1630527)
# Successfully processed Aaron Wiggins: 25 fields
# Player Marko Simonovic not found in all_players
# Processing Jose Alvarado (ID: 1630631)
# Successfully processed Miles Mcbride: 25 fields
# Processing Jack White (ID: 1631298)
# Successfully processed Isaiah Livers: 25 fields
# Processing Aj Green (ID: 1631260)
# Successfully processed Brandon Boston: 25 fields
# Processing Orlando Robinson (ID: 1631115)
# Successfully processed Jose Alvarado: 25 fields
# Processing Dru Smith (ID: 1630696)
# Successfully processed Jack White: 25 fields
# Processing E.J. Liddell (ID: 1630604)
# Successfully processed Orlando Robinson: 25 fields
# Processing Leonard Miller (ID: 1631159)
# Successfully processed Aj Green: 25 fields
# Processing Joshua Primo (ID: 1630563)
# Successfully processed Leonard Miller: 25 fields
# Processing Daniel Theis (ID: 1628464)
# Successfully processed Dru Smith: 25 fields
# Processing Bryce Mcgowens (ID: 1631121)
# Successfully processed E.J. Liddell: 25 fields
# Player Xavier Cooks not found in all_players
# Processing Jabari Walker (ID: 1631133)
# Successfully processed Joshua Primo: 25 fields
# Processing Josh Minott (ID: 1631169)
# Successfully processed Daniel Theis: 25 fields
# Processing Tyrese Martin (ID: 1631213)
# Successfully processed Jabari Walker: 25 fields
# Processing Max Christie (ID: 1631108)
# Successfully processed Bryce Mcgowens: 25 fields
# Processing Jaden Hardy (ID: 1630702)
# No stats found for Tyrese Martin in season 2023-24
# Processing Julian Phillips (ID: 1641763)
# Successfully processed Josh Minott: 25 fields
# Processing Spencer Dinwiddie (ID: 203915)
# Successfully processed Max Christie: 25 fields
# Processing Craig Porter Jr. (ID: 1641854)
# Successfully processed Jaden Hardy: 25 fields
# Processing Sidy Cissoko (ID: 1631321)
# Successfully processed Julian Phillips: 25 fields
# Processing Filip Petrusev (ID: 1630196)
# Successfully processed Craig Porter Jr.: 25 fields
# Processing Rayan Rupert (ID: 1641712)
# Successfully processed Spencer Dinwiddie: 25 fields
# Processing Toumani Camara (ID: 1641739)
# Successfully processed Sidy Cissoko: 25 fields
# Processing Chris Livingston (ID: 1641753)
# Successfully processed Toumani Camara: 25 fields
# Processing Andre Jackson Jr. (ID: 1641748)
# Successfully processed Rayan Rupert: 25 fields
# Processing Maxwell Lewis (ID: 1641721)
# Successfully processed Filip Petrusev: 25 fields
# Processing Trayce Jackson-Davis (ID: 1631218)
# Successfully processed Chris Livingston: 25 fields
# Processing Hunter Tyson (ID: 1641816)
# Successfully processed Maxwell Lewis: 25 fields
# Processing Jordan Walsh (ID: 1641775)
# Successfully processed Andre Jackson Jr.: 25 fields
# Processing Mouhamed Gueye (ID: 1631243)
# Successfully processed Trayce Jackson-Davis: 25 fields
# Processing Kendall Brown (ID: 1631112)
# Successfully processed Hunter Tyson: 25 fields
# Processing Gui Santos (ID: 1630611)
# Successfully processed Jordan Walsh: 25 fields
# Processing A.J. Lawson (ID: 1630639)
# Successfully processed Mouhamed Gueye: 25 fields
# Processing Eugene Omoruyi (ID: 1630647)
# Successfully processed Kendall Brown: 25 fields
# Processing Jalen Wilson (ID: 1630592)
# Successfully processed A.J. Lawson: 25 fields
# Processing James Johnson (ID: 201949)
# Successfully processed Gui Santos: 25 fields
# Processing Lindy Waters Iii (ID: 1630322)
# Successfully processed Eugene Omoruyi: 25 fields
# Processing Bismack Biyombo (ID: 202687)
# Successfully processed Jalen Wilson: 25 fields
# Processing Keon Ellis (ID: 1631165)
# Successfully processed James Johnson: 25 fields
# Processing Danilo Gallinari (ID: 201568)
# Successfully processed Lindy Waters Iii: 25 fields
# Processing Delon Wright (ID: 1626153)
# Successfully processed Bismack Biyombo: 25 fields
# Processing Thaddeus Young (ID: 201152)
# Successfully processed Keon Ellis: 25 fields
# Processing Aleksej Pokusevski (ID: 1630197)
# Successfully processed Delon Wright: 25 fields
# Processing Trent Forrest (ID: 1630235)
# Successfully processed Danilo Gallinari: 25 fields
# Processing Shake Milton (ID: 1629003)
# Successfully processed Thaddeus Young: 25 fields
# Processing Lester Quinones (ID: 1631311)
# Successfully processed Aleksej Pokusevski: 25 fields
# Processing Stanley Umude (ID: 1630649)
# Successfully processed Trent Forrest: 25 fields
# Processing Kenneth Lofton Jr. (ID: 1631254)
# Successfully processed Shake Milton: 25 fields
# Processing Darius Bazley (ID: 1629647)
# Successfully processed Stanley Umude: 25 fields
# Processing Patty Mills (ID: 201988)
# Successfully processed Lester Quinones: 25 fields
# Processing Dominick Barlow (ID: 1631230)
# Successfully processed Darius Bazley: 25 fields
# Processing Taj Gibson (ID: 201959)
# Successfully processed Kenneth Lofton Jr.: 25 fields
# Processing Onuralp Bitim (ID: 1641931)
# Successfully processed Dominick Barlow: 25 fields
# Processing Javon Freeman-Liberty (ID: 1631241)
# Successfully processed Patty Mills: 25 fields
# Successfully processed Taj Gibson: 25 fields
# Successfully processed Javon Freeman-Liberty: 25 fields
# Successfully processed Onuralp Bitim: 25 fields
# ⚠️  13 players not in roster for 2023-24
# Percentage calculations completed
# ✔ Completed pull: 450 rows added
# Could not find the salary cap table on the page.
# Updated flat‑file saved to C:\docker_projects\coach_analysis\data\new_processed\nba_player_data_final_inflated.csv
# Process finished in 12.0 s — log: C:\docker_projects\coach_analysis\data\stat_pull_output\stat_pull_log_2025-07-22_17-48-45.txt
# [historical_pull] 2019-2024, kwargs={'workers': 6, 'min_avg_minutes': 10, 'overwrite': False, 'debug': True}
# [fetch] https://hoopshype.com/salaries/players/2019-20/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://hoopshype.com/salaries/players/2019-2020/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/1 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/2 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/3 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/4 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/5 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/6 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/7 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/8 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/9 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/10 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/11 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/12 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/13 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2020/page/14 (attempt 1)
#   -> ESPN fallback added 520 rows
#   -> scraped 520 rows for 2019-20
# [fetch] https://hoopshype.com/salaries/players/2020-21/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://hoopshype.com/salaries/players/2020-2021/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/1 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/2 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/3 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/4 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/5 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/6 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/7 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/8 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/9 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/10 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/11 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/12 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/13 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/14 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2021/page/15 (attempt 1)
#   -> ESPN fallback added 556 rows
#   -> scraped 556 rows for 2020-21
# [fetch] https://hoopshype.com/salaries/players/2021-22/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://hoopshype.com/salaries/players/2021-2022/ (attempt 1)
#   -> HTTP 404, skipping.
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/1 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/2 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/3 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/4 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/5 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/6 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/7 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/8 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/9 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/10 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/11 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/12 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/13 (attempt 1)
# [fetch] https://www.espn.com/nba/salaries/_/year/2022/page/14 (attempt 1)
#   -> ESPN fallback added 497 rows
# ...
# Processing Olivier-Maxence Prosper (ID: 1641765)
# Successfully processed Ajay Mitchell: 25 fields
# Processing David Roddy (ID: 1631223)
# Successfully processed Julian Champagnie: 25 fields
# Processing Torrey Craig (ID: 1628470)
# Successfully processed Kris Murray: 25 fields
# Processing Kyshawn George (ID: 1642273)
# Successfully processed Walker Kessler: 25 fields
# Processing Aj Johnson (ID: 1642358)
# Successfully processed Shake Milton: 25 fields
# Processing Marcus Sasser (ID: 1631204)
# Successfully processed David Roddy: 25 fields
# Processing Marjon Beauchamp (ID: 1630699)
# Successfully processed Kyshawn George: 25 fields
# Processing Trendon Watford (ID: 1630570)
# Successfully processed Torrey Craig: 25 fields
# Processing Ben Sheppard (ID: 1641767)
# Successfully processed Olivier-Maxence Prosper: 25 fields
# Player Omer Yurtseven not found in all_players
# Player Keita Bates-Diop not found in all_players
# Processing Blake Wesley (ID: 1631104)
# Successfully processed Marcus Sasser: 25 fields
# Processing Dillon Jones (ID: 1641794)
# Successfully processed Aj Johnson: 25 fields
# Processing Nick Smith Jr. (ID: 1641733)
# Successfully processed Marjon Beauchamp: 25 fields
# Processing Brice Sensabaugh (ID: 1641729)
# Successfully processed Trendon Watford: 25 fields
# Processing Ty Jerome (ID: 1629660)
# Successfully processed Dillon Jones: 25 fields
# Processing Julian Strawther (ID: 1631124)
# Successfully processed Ben Sheppard: 25 fields
# Processing Terrence Shannon Jr. (ID: 1630545)
# Successfully processed Blake Wesley: 25 fields
# Processing Ryan Dunn (ID: 1642346)
# Successfully processed Nick Smith Jr.: 25 fields
# Processing Wendell Moore Jr. (ID: 1631111)
# Successfully processed Brice Sensabaugh: 25 fields
# Processing Kobe Brown (ID: 1641738)
# Successfully processed Julian Strawther: 25 fields
# Processing Isaiah Collier (ID: 1642268)
# Successfully processed Terrence Shannon Jr.: 25 fields
# Processing Baylor Scheierman (ID: 1631248)
# Successfully processed Ty Jerome: 25 fields
# Processing Nikola Jovic (ID: 1631107)
# Successfully processed Ryan Dunn: 25 fields
# Player Darius Bazley not found in all_players
# Processing Jaxson Hayes (ID: 1629637)
# Successfully processed Wendell Moore Jr.: 25 fields
# Processing Cam Reddish (ID: 1629629)
# Successfully processed Baylor Scheierman: 25 fields
# Processing Patrick Baldwin Jr. (ID: 1631116)
# Successfully processed Isaiah Collier: 25 fields
# Processing Daquan Jeffries (ID: 1629610)
# Successfully processed Nikola Jovic: 25 fields
# Processing Tristan Vukcevic (ID: 1641774)
# Successfully processed Kobe Brown: 25 fields
# Processing Peyton Watson (ID: 1631212)
# Successfully processed Jaxson Hayes: 25 fields
# Player Aleksej Pokusevski not found in all_players
# Player Mamadi Diakite not found in all_players
# Player Charlie Brown Jr. not found in all_players
# Processing James Wiseman (ID: 1630164)
# Successfully processed Cam Reddish: 25 fields
# Processing Anthony Gill (ID: 1630264)
# Successfully processed Patrick Baldwin Jr.: 25 fields
# Processing Kevin Porter Jr. (ID: 1629645)
# Successfully processed Daquan Jeffries: 25 fields
# Processing Xavier Tillman (ID: 1630214)
# Successfully processed Tristan Vukcevic: 25 fields
# Processing Garrison Mathews (ID: 1629726)
# Successfully processed Peyton Watson: 25 fields
# Player Eugene Omoruyi not found in all_players
# Processing Dalano Banton (ID: 1630625)
# Successfully processed James Wiseman: 25 fields
# Processing Jeff Dowtin Jr. (ID: 1630288)
# Successfully processed Kevin Porter Jr.: 25 fields
# Processing Lindy Waters Iii (ID: 1630322)
# Successfully processed Anthony Gill: 25 fields
# Processing Kai Jones (ID: 1630539)
# Successfully processed Xavier Tillman: 25 fields
# Processing Jeremiah Robinson-Earl (ID: 1630526)
# Successfully processed Garrison Mathews: 25 fields
# Processing Sam Merrill (ID: 1630241)
# Successfully processed Dalano Banton: 25 fields
# Player Duane Washington Jr. not found in all_players
# Processing Keon Johnson (ID: 1630553)
# Successfully processed Lindy Waters Iii: 25 fields
# Processing Luka Garza (ID: 1630568)
# Successfully processed Kai Jones: 25 fields
# Processing Neemias Queta (ID: 1629674)
# Successfully processed Jeff Dowtin Jr.: 25 fields
# Processing Vit Krejci (ID: 1630249)
# Successfully processed Jeremiah Robinson-Earl: 25 fields
# Processing Vince Williams Jr. (ID: 1631246)
# Successfully processed Luka Garza: 25 fields
# Processing A.J. Lawson (ID: 1630639)
# Successfully processed Sam Merrill: 25 fields
# Processing Colby Jones (ID: 1641732)
# Successfully processed Keon Johnson: 25 fields
# Processing Keon Ellis (ID: 1631165)
# Successfully processed Vit Krejci: 25 fields
# Player Kendall Brown not found in all_players
# Processing Aj Green (ID: 1631260)
# Successfully processed Neemias Queta: 25 fields
# Processing Stanley Umude (ID: 1630649)
# Successfully processed Vince Williams Jr.: 25 fields
# Processing E.J. Liddell (ID: 1630604)
# Successfully processed A.J. Lawson: 25 fields
# Processing Jericho Sims (ID: 1630579)
# Successfully processed Colby Jones: 25 fields
# Processing Sam Hauser (ID: 1630573)
# Successfully processed Stanley Umude: 25 fields
# Processing Jay Huff (ID: 1630643)
# Successfully processed Aj Green: 25 fields
# Processing Seth Curry (ID: 203552)
# Successfully processed Keon Ellis: 25 fields
# Processing Taj Gibson (ID: 201959)
# Successfully processed Jericho Sims: 25 fields
# Processing Scotty Pippen Jr. (ID: 1630590)
# Successfully processed E.J. Liddell: 25 fields
# Processing Bruno Fernando (ID: 1628981)
# Successfully processed Sam Hauser: 25 fields
# Processing Garrett Temple (ID: 202066)
# Successfully processed Seth Curry: 25 fields
# Processing Reggie Jackson (ID: 202704)
# Successfully processed Jay Huff: 25 fields
# Processing Daniel Theis (ID: 1628464)
# Successfully processed Taj Gibson: 25 fields
# Processing Charles Bassey (ID: 1629646)
# Successfully processed Scotty Pippen Jr.: 25 fields
# Processing Sandro Mamukelashvili (ID: 1630572)
# Successfully processed Bruno Fernando: 25 fields
# Processing Jordan Mclaughlin (ID: 1629162)
# Successfully processed Garrett Temple: 25 fields
# Processing Doug Mcdermott (ID: 203926)
# Successfully processed Reggie Jackson: 25 fields
# Processing Bol Bol (ID: 1629626)
# Successfully processed Daniel Theis: 25 fields
# Processing Tyus Jones (ID: 1626145)
# Successfully processed Sandro Mamukelashvili: 25 fields
# Processing Monte Morris (ID: 1628420)
# Successfully processed Charles Bassey: 25 fields
# Processing Damion Lee (ID: 1627814)
# Successfully processed Doug Mcdermott: 25 fields
# Processing Mason Plumlee (ID: 203486)
# Successfully processed Jordan Mclaughlin: 25 fields
# Processing Guerschon Yabusele (ID: 1627824)
# Successfully processed Bol Bol: 25 fields
# Processing Kyle Lowry (ID: 200768)
# Successfully processed Damion Lee: 25 fields
# Processing Tyler Kolek (ID: 1642278)
# Successfully processed Monte Morris: 25 fields
# Processing Delon Wright (ID: 1626153)
# Successfully processed Tyus Jones: 25 fields
# Processing Cameron Payne (ID: 1626166)
# Successfully processed Mason Plumlee: 25 fields
# Processing Pj Dozier (ID: 1628408)
# Successfully processed Kyle Lowry: 25 fields
# Processing Joe Ingles (ID: 204060)
# Successfully processed Tyler Kolek: 25 fields
# Processing Gary Trent Jr. (ID: 1629018)
# Successfully processed Guerschon Yabusele: 25 fields
# Processing Taurean Prince (ID: 1627752)
# Successfully processed Cameron Payne: 25 fieldsSuccessfully processed Delon Wright: 25 fields
# Processing Alec Burks (ID: 202692)
#
# Processing Markieff Morris (ID: 202693)
# Successfully processed Pj Dozier: 25 fields
# Processing Patty Mills (ID: 201988)
# Successfully processed Joe Ingles: 25 fields
# Processing Thomas Bryant (ID: 1628418)
# Successfully processed Gary Trent Jr.: 25 fields
# Processing James Johnson (ID: 201949)
# Successfully processed Taurean Prince: 25 fields
# Processing Vlatko Cancar (ID: 1628427)
# Successfully processed Markieff Morris: 25 fields
# Processing Deandre Jordan (ID: 201599)
# Successfully processed Alec Burks: 25 fields
# Processing Spencer Dinwiddie (ID: 203915)
# Successfully processed Patty Mills: 25 fields
# Processing Tristan Thompson (ID: 202684)
# Successfully processed Thomas Bryant: 25 fields
# Processing Talen Horton-Tucker (ID: 1629659)
# Successfully processed James Johnson: 25 fields
# Processing Mo Bamba (ID: 1628964)
# Successfully processed Vlatko Cancar: 25 fields
# Processing Luke Kornet (ID: 1628436)
# Successfully processed Deandre Jordan: 25 fields
# Processing Duop Reath (ID: 1641871)
# Successfully processed Talen Horton-Tucker: 25 fields
# Processing Jaylin Williams (ID: 1631119)
# Successfully processed Tristan Thompson: 25 fields
# Processing Bryce Mcgowens (ID: 1631121)
# Successfully processed Spencer Dinwiddie: 25 fields
# Processing Jabari Walker (ID: 1631133)
# Successfully processed Luke Kornet: 25 fields
# Processing Josh Minott (ID: 1631169)
# Successfully processed Duop Reath: 25 fields
# Processing Andrew Nembhard (ID: 1629614)
# Successfully processed Mo Bamba: 25 fields
# Processing Jaden Hardy (ID: 1630702)
# Successfully processed Jaylin Williams: 25 fields
# Processing Caleb Houstan (ID: 1631216)
# Successfully processed Bryce Mcgowens: 25 fields
# Processing Jt Thor (ID: 1630550)
# Successfully processed Josh Minott: 25 fields
# Processing Jose Alvarado (ID: 1630631)
# Successfully processed Jabari Walker: 25 fields
# Processing Matt Ryan (ID: 1630346)
# Successfully processed Andrew Nembhard: 25 fields
# Processing Mouhamed Gueye (ID: 1631243)
# Successfully processed Jaden Hardy: 25 fields
# Processing Gg Jackson (ID: 1641713)
# Successfully processed Caleb Houstan: 25 fields
# Player Javon Freeman-Liberty not found in all_players
# Processing Rayan Rupert (ID: 1641712)
# Successfully processed Jose Alvarado: 25 fields
# Processing Sidy Cissoko (ID: 1631321)
# Successfully processed Mouhamed Gueye: 25 fields
# Processing Toumani Camara (ID: 1641739)
# Successfully processed Jt Thor: 25 fields
# Processing Ricky Council Iv (ID: 1641741)
# Successfully processed Matt Ryan: 25 fields
# Processing Maxwell Lewis (ID: 1641721)
# Successfully processed Rayan Rupert: 25 fields
# Processing Jalen Wilson (ID: 1630592)
# Successfully processed Gg Jackson: 25 fields
# Processing Leonard Miller (ID: 1631159)
# Successfully processed Maxwell Lewis: 25 fields
# Processing Chris Livingston (ID: 1641753)
# Successfully processed Ricky Council Iv: 25 fields
# Processing Andre Jackson Jr. (ID: 1641748)
# Successfully processed Toumani Camara: 25 fields
# Processing Gui Santos (ID: 1630611)
# Successfully processed Sidy Cissoko: 25 fields
# Processing Trayce Jackson-Davis (ID: 1631218)
# Successfully processed Leonard Miller: 25 fields
# Processing Jalen Pickett (ID: 1629618)
# Successfully processed Jalen Wilson: 25 fields
# Processing Hunter Tyson (ID: 1641816)
# Successfully processed Chris Livingston: 25 fields
# Processing Craig Porter Jr. (ID: 1641854)
# Successfully processed Andre Jackson Jr.: 25 fields
# Processing Julian Phillips (ID: 1641763)
# Successfully processed Gui Santos: 25 fields
# Player Onuralp Bitim not found in all_players
# Processing Jordan Walsh (ID: 1641775)
# Successfully processed Jalen Pickett: 25 fields
# Processing Jonathan Mogbo (ID: 1642367)
# Successfully processed Hunter Tyson: 25 fields
# Processing Jamal Shead (ID: 1642347)
# Successfully processed Trayce Jackson-Davis: 25 fields
# Processing Johnny Furphy (ID: 1642277)
# Successfully processed Julian Phillips: 25 fields
# Processing Pacome Dadiet (ID: 1642359)
# Successfully processed Craig Porter Jr.: 25 fields
# Processing Justin Champagnie (ID: 1630551)
# Successfully processed Jordan Walsh: 25 fields
# Processing Jae Crowder (ID: 203109)
# Successfully processed Jonathan Mogbo: 25 fields
# Processing Paul Reed (ID: 1630194)
# Successfully processed Jamal Shead: 25 fields
# Processing Karlo Matkovic (ID: 1631255)
# Successfully processed Johnny Furphy: 25 fields
# Processing Landry Shamet (ID: 1629013)
# Successfully processed Pacome Dadiet: 25 fields
# Processing Bobi Klintman (ID: 1641752)
# Successfully processed Justin Champagnie: 25 fields
# Processing Jaylen Wells (ID: 1642377)
# Successfully processed Jae Crowder: 25 fields
# Processing Oso Ighodaro (ID: 1642345)
# Successfully processed Paul Reed: 25 fields
# Processing Adem Bona (ID: 1641737)
# Successfully processed Landry Shamet: 25 fields
# Processing Tyler Smith (ID: 1641890)
# Successfully processed Karlo Matkovic: 25 fields
# Processing Bronny James (ID: 1642355)
# Successfully processed Bobi Klintman: 25 fields
# Processing Cam Christie (ID: 1642353)
# Successfully processed Oso Ighodaro: 25 fields
# Processing Antonio Reeves (ID: 1641810)
# Successfully processed Adem Bona: 25 fields
# Processing Pelle Larsson (ID: 1641796)
# Successfully processed Jaylen Wells: 25 fields
# Processing Ariel Hukporti (ID: 1630574)
# Successfully processed Tyler Smith: 25 fields
# Processing Jordan Miller (ID: 1641757)
# Successfully processed Bronny James: 25 fields
# Processing Jamison Battle (ID: 1642419)
# Successfully processed Cam Christie: 25 fields
# Processing Branden Carlson (ID: 1642382)
# Successfully processed Antonio Reeves: 25 fields
# Processing Moussa Diabate (ID: 1631217)
# Successfully processed Pelle Larsson: 25 fields
# Processing Lonnie Walker Iv (ID: 1629022)
# Successfully processed Ariel Hukporti: 25 fields
# Processing Ben Simmons (ID: 1627732)
# Successfully processed Jamison Battle: 25 fields
# Processing Jared Butler (ID: 1630215)
# Successfully processed Jordan Miller: 25 fields
# Processing Alex Len (ID: 203458)
# Successfully processed Moussa Diabate: 25 fields
# Processing Markelle Fultz (ID: 1628365)
# Successfully processed Branden Carlson: 25 fields
# Processing Keshad Johnson (ID: 1642352)
# Successfully processed Lonnie Walker Iv: 25 fields
# Processing Tyrese Martin (ID: 1631213)
# Successfully processed Ben Simmons: 25 fields
# Processing Jaden Springer (ID: 1630531)
# Successfully processed Alex Len: 25 fields
# Processing Javonte Green (ID: 1629750)
# Successfully processed Jared Butler: 25 fields
# Processing Brandon Boston (ID: 1630527)
# Successfully processed Keshad Johnson: 25 fields
# Processing Nate Williams (ID: 1631466)
# Successfully processed Jaden Springer: 25 fields
# Processing Bismack Biyombo (ID: 202687)
# Successfully processed Markelle Fultz: 25 fields
# Processing Orlando Robinson (ID: 1631115)
# Successfully processed Tyrese Martin: 25 fields
# Processing Ryan Rollins (ID: 1631157)
# Successfully processed Brandon Boston: 25 fields
# Processing Dominick Barlow (ID: 1631230)
# Successfully processed Javonte Green: 25 fields
# Processing Quinten Post (ID: 1642366)
# Successfully processed Bismack Biyombo: 25 fields
# Processing Pat Spencer (ID: 1630311)
# Successfully processed Nate Williams: 25 fields
# Processing Jaylen Clark (ID: 1641740)
# Successfully processed Orlando Robinson: 25 fields
# Processing Justin Edwards (ID: 1642348)
# Successfully processed Ryan Rollins: 25 fields
# Processing Lamar Stevens (ID: 1630205)
# Successfully processed Dominick Barlow: 25 fields
# Processing Tony Bradley (ID: 1628396)
# Successfully processed Quinten Post: 25 fields
# Processing Kevin Knox Ii (ID: 1628995)
# Successfully processed Jaylen Clark: 25 fields
# Processing P.J. Tucker (ID: 200782)
# Successfully processed Justin Edwards: 25 fields
# Processing Jordan Goodwin (ID: 1630692)
# Successfully processed Tony Bradley: 25 fields
# Processing Isaac Jones (ID: 1642403)
# Successfully processed Lamar Stevens: 25 fields
# Processing Drew Timme (ID: 1631166)
# Successfully processed Kevin Knox Ii: 25 fields
# Successfully processed Pat Spencer: 25 fields
# Successfully processed P.J. Tucker: 25 fields
# Successfully processed Jordan Goodwin: 25 fields
# Successfully processed Drew Timme: 25 fields
# Successfully processed Isaac Jones: 25 fields
# ⚠️  20 players not in roster for 2024-25
# Percentage calculations completed
# ✔ Completed pull: 2,756 rows added
# Could not find the salary cap table on the page.
# Updated flat‑file saved to C:\docker_projects\coach_analysis\data\new_processed\nba_player_data_final_inflated.csv
# Process finished in 83.0 s — log: C:\docker_projects\coach_analysis\data\stat_pull_output\stat_pull_log_2025-07-22_17-48-57.txt
# [check_existing_data] found 6 seasons in C:\docker_projects\coach_analysis\data\new_processed
# [load_parquet_data] loading 1 files from C:\docker_projects\coach_analysis\data\new_processed

# %% [markdown]
# # Tests:
