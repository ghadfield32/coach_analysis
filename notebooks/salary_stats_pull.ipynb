# %%
# %%write_file ../src/fetch_utils.py
import time
from nba_api.stats.endpoints import commonallplayers, commonplayerinfo, playercareerstats, leaguestandings
from requests.exceptions import RequestException
from json.decoder import JSONDecodeError

MAX_REQUESTS_PER_MINUTE = 30
DELAY_BETWEEN_REQUESTS = 2

def fetch_with_retry(endpoint, max_retries=10, initial_delay=5, max_delay=60, timeout=60, debug=False, **kwargs):
    for attempt in range(max_retries):
        try:
            if debug:
                print(f"Fetching data using {endpoint.__name__} (Attempt {attempt + 1}) with parameters: {kwargs}")
            data = endpoint(**kwargs, timeout=timeout).get_data_frames()
            return data[0] if isinstance(data, list) else data
        except (RequestException, JSONDecodeError, KeyError) as e:
            if debug:
                print(f"Error occurred during fetching {endpoint.__name__}: {e}")
            if attempt == max_retries - 1:
                if debug:
                    print(f"Failed to fetch data from {endpoint.__name__} after {max_retries} attempts")
                return None
            delay = min(initial_delay * (2 ** attempt), max_delay)
            if debug:
                print(f"Retrying in {delay} seconds...")
            time.sleep(delay)

def fetch_all_players(season, debug=False):
    all_players_data = fetch_with_retry(commonallplayers.CommonAllPlayers, season=season, debug=debug)
    all_players = {}
    if all_players_data is not None:
        for _, row in all_players_data.iterrows():
            player_name = row['DISPLAY_FIRST_LAST'].strip().lower()
            player_id = row['PERSON_ID']
            team_id = row['TEAM_ID']
            all_players[player_name] = {
                'player_id': player_id,
                'team_id': team_id
            }
    if debug:
        print(f"Fetched {len(all_players)} players for season {season}")
    return all_players

def fetch_player_info(player_id, debug=False):
    return fetch_with_retry(commonplayerinfo.CommonPlayerInfo, player_id=player_id, debug=debug)

def fetch_career_stats(player_id, debug=False):
    return fetch_with_retry(playercareerstats.PlayerCareerStats, player_id=player_id, debug=debug)

def fetch_league_standings(season, debug=False):
    return fetch_with_retry(leaguestandings.LeagueStandings, season=season, debug=debug)

if __name__ == "__main__":
    # Example usage
    debug = True
    season = "2022-23"
    
    # Fetch all players
    all_players = fetch_all_players(season, debug=debug)
    print(f"Total players fetched: {len(all_players)}")
    
    # Fetch player info for a sample player
    sample_player_id = list(all_players.values())[0]['player_id']
    player_info = fetch_player_info(sample_player_id, debug=debug)
    print("Sample player info:")
    print(player_info)
    
    # Fetch career stats for the sample player
    career_stats = fetch_career_stats(sample_player_id, debug=debug)
    print("Sample player career stats:")
    print(career_stats)
    
    # Fetch league standings
    standings = fetch_league_standings(season, debug=debug)
    print("League standings:")
    print(standings)
# Out:
# Fetching data using CommonAllPlayers (Attempt 1) with parameters: {'season': '2022-23'}
# Fetched 4971 players for season 2022-23
# Total players fetched: 4971
# Fetching data using CommonPlayerInfo (Attempt 1) with parameters: {'player_id': 76001}
# Sample player info:
#    PERSON_ID FIRST_NAME  LAST_NAME DISPLAY_FIRST_LAST  \
# 0      76001       Alaa  Abdelnaby     Alaa Abdelnaby
#
#   DISPLAY_LAST_COMMA_FIRST DISPLAY_FI_LAST     PLAYER_SLUG  \
# 0          Abdelnaby, Alaa    A. Abdelnaby  alaa-abdelnaby
#
#              BIRTHDATE SCHOOL COUNTRY  ...              PLAYERCODE FROM_YEAR  \
# 0  1968-06-24T00:00:00   Duke     USA  ...  HISTADD_alaa_abdelnaby      1990
#
#   TO_YEAR  DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG DRAFT_YEAR DRAFT_ROUND  \
# 0    1994             N        Y                 Y       1990           1
#
#    DRAFT_NUMBER GREATEST_75_FLAG
# 0            25                N
#
# [1 rows x 33 columns]
# Fetching data using PlayerCareerStats (Attempt 1) with parameters: {'player_id': 76001}
# Sample player career stats:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0      76001   1990-91        00  1610612757               POR        23.0
# 1      76001   1991-92        00  1610612757               POR        24.0
# 2      76001   1992-93        00  1610612749               MIL        25.0
# 3      76001   1992-93        00  1610612738               BOS        25.0
# 4      76001   1992-93        00           0               TOT        25.0
# 5      76001   1993-94        00  1610612738               BOS        26.0
# 6      76001   1994-95        00  1610612758               SAC        27.0
# 7      76001   1994-95        00  1610612755               PHL        27.0
# 8      76001   1994-95        00           0               TOT        27.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  43   0   290.0   55  ...   0.568    27    62   89   12    4   12   22   39
# 1  71   1   934.0  178  ...   0.752    81   179  260   30   25   16   66  132
# 2  12   0   159.0   26  ...   0.750    12    25   37   10    6    4   13   24
# 3  63  52  1152.0  219  ...   0.760   114   186  300   17   19   22   84  165
# 4  75  52  1311.0  245  ...   0.759   126   211  337   27   25   26   97  189
# 5  13   0   159.0   24  ...   0.640    12    34   46    3    2    3   17   20
# 6  51   0   476.0  117  ...   0.571    34    72  106   13   15   12   40  102
# 7   3   0    30.0    1  ...   0.000     3     5    8    0    0    0    5    2
# 8  54   0   506.0  118  ...   0.571    37    77  114   13   15   12   45  104
#
#    PTS
# 0  135
# 1  432
# 2   64
# 3  514
# 4  578
# 5   64
# 6  254
# 7    2
# 8  256
#
# [9 rows x 27 columns]
# Fetching data using LeagueStandings (Attempt 1) with parameters: {'season': '2022-23'}
# League standings:
#    LeagueID SeasonID      TeamID       TeamCity       TeamName Conference  \
# 0        00    22022  1610612743         Denver        Nuggets       West
# 1        00    22022  1610612749      Milwaukee          Bucks       East
# 2        00    22022  1610612763        Memphis      Grizzlies       West
# 3        00    22022  1610612738         Boston        Celtics       East
# 4        00    22022  1610612755   Philadelphia          76ers       East
# 5        00    22022  1610612758     Sacramento          Kings       West
# 6        00    22022  1610612739      Cleveland      Cavaliers       East
# 7        00    22022  1610612756        Phoenix           Suns       West
# 8        00    22022  1610612752       New York         Knicks       East
# 9        00    22022  1610612746             LA       Clippers       West
# 10       00    22022  1610612751       Brooklyn           Nets       East
# 11       00    22022  1610612744   Golden State       Warriors       West
# 12       00    22022  1610612747    Los Angeles         Lakers       West
# 13       00    22022  1610612748          Miami           Heat       East
# 14       00    22022  1610612737        Atlanta          Hawks       East
# 15       00    22022  1610612750      Minnesota   Timberwolves       West
# 16       00    22022  1610612761        Toronto        Raptors       East
# 17       00    22022  1610612740    New Orleans       Pelicans       West
# 18       00    22022  1610612741        Chicago          Bulls       East
# 19       00    22022  1610612760  Oklahoma City        Thunder       West
# 20       00    22022  1610612754        Indiana         Pacers       East
# 21       00    22022  1610612742         Dallas      Mavericks       West
# 22       00    22022  1610612762           Utah           Jazz       West
# 23       00    22022  1610612764     Washington        Wizards       East
# 24       00    22022  1610612757       Portland  Trail Blazers       West
# 25       00    22022  1610612753        Orlando          Magic       East
# 26       00    22022  1610612745        Houston        Rockets       West
# 27       00    22022  1610612766      Charlotte        Hornets       East
# 28       00    22022  1610612759    San Antonio          Spurs       West
# 29       00    22022  1610612765        Detroit        Pistons       East
#
#    ConferenceRecord  PlayoffRank ClinchIndicator   Division  ...   May   Jun  \
# 0             34-18            1             - w  Northwest  ...  None  None
# 1             35-17            1             - e    Central  ...  None  None
# 2             30-22            2            - sw  Southwest  ...  None  None
# 3             34-18            2             - a   Atlantic  ...  None  None
# 4             34-18            3             - x   Atlantic  ...  None  None
# 5             32-20            3             - p    Pacific  ...  None  None
# 6             34-18            4             - x    Central  ...  None  None
# 7             30-22            4             - x    Pacific  ...  None  None
# 8             32-20            5             - x   Atlantic  ...  None  None
# 9             27-25            5             - x    Pacific  ...  None  None
# 10            30-22            6             - x   Atlantic  ...  None  None
# 11            30-22            6             - x    Pacific  ...  None  None
# 12            27-25            7                    Pacific  ...  None  None
# 13            24-28            7            - se  Southeast  ...  None  None
# 14            26-26            8                  Southeast  ...  None  None
# 15            29-23            8                  Northwest  ...  None  None
# 16            26-26            9                   Atlantic  ...  None  None
# 17            29-23            9                  Southwest  ...  None  None
# 18            27-25           10                    Central  ...  None  None
# 19            25-27           10                  Northwest  ...  None  None
# 20            24-28           11             - o    Central  ...  None  None
# 21            28-24           11             - o  Southwest  ...  None  None
# 22            24-28           12             - o  Northwest  ...  None  None
# 23            21-31           12             - o  Southeast  ...  None  None
# 24            23-29           13             - o  Northwest  ...  None  None
# 25            20-32           13             - o  Southeast  ...  None  None
# 26            12-40           14             - o  Southwest  ...  None  None
# 27            15-37           14             - o  Southeast  ...  None  None
# 28            10-42           15             - o  Southwest  ...  None  None
# 29             8-44           15             - o    Central  ...  None  None
#
#      Jul   Aug   Sep  Oct   Nov   Dec  PreAS PostAS
# 0   None  None  None  4-3  10-4   9-5  41-18  12-11
# 1   None  None  None  6-0   9-5   8-7  41-17   17-7
# 2   None  None  None  4-3   8-6  10-4  35-22   16-9
# 3   None  None  None  4-2  14-2   8-6  42-17   15-8
# 4   None  None  None  4-4   8-6   9-4  38-19   16-9
# 5   None  None  None  2-4   9-5   8-6  32-25   16-9
# 6   None  None  None  5-1   9-7   9-6  38-23   13-8
# 7   None  None  None  5-1  10-5  5-11  32-28   13-9
# 8   None  None  None  3-3   7-9   9-6  33-27   14-8
# 9   None  None  None  3-4  10-6   8-7  33-28  11-10
# 10  None  None  None  2-5  10-6  12-1  34-24  11-13
# 11  None  None  None  3-4   8-7   8-7  29-29   15-9
# 12  None  None  None  1-5   7-7   7-9  27-32   16-7
# 13  None  None  None  2-5   8-7   9-6  32-27  12-11
# 14  None  None  None  4-3   8-7   5-9  29-30  12-11
# 15  None  None  None  4-3   7-8  5-10  31-30  11-10
# 16  None  None  None  4-3   7-7  5-10  28-31  13-10
# 17  None  None  None  4-2   9-6  10-5  30-29  12-11
# 18  None  None  None  3-4   6-8   7-8  26-33   14-9
# 19  None  None  None  3-3  6-10   6-8  28-29  12-13
# 20  None  None  None  3-5   9-4   8-8  26-34   9-13
# 21  None  None  None  3-3   7-7  11-6  31-29   7-15
# 22  None  None  None  6-2   7-9   6-9  29-31   8-14
# 23  None  None  None  3-4   8-7  5-10  28-30   7-17
# 24  None  None  None  5-1  6-10   7-6  28-30   5-19
# 25  None  None  None  1-6  4-11   8-7  24-35  10-13
# 26  None  None  None  1-7   4-9  5-10  13-45   9-15
# 27  None  None  None  3-4  3-11  4-12  17-43  10-12
# 28  None  None  None  5-2  1-14   6-8  14-45   8-15
# 29  None  None  None  2-6  3-12  5-11  15-44   2-21
#
# [30 rows x 81 columns]

# %%
# scrape_utils.py
import pandas as pd
import requests
from bs4 import BeautifulSoup

def scrape_salary_cap_history():
    url = "https://basketball.realgm.com/nba/info/salary_cap"
    try:
        response = requests.get(url)
        response.raise_for_status()
        soup = BeautifulSoup(response.text, 'html.parser')
        table = soup.find('table', class_='basketball compact')
        
        if not table:
            print("Could not find the salary cap table on the page.")
            return None

        data = []
        headers = [th.text.strip() for th in table.find('thead').find_all('th')]
        for row in table.find('tbody').find_all('tr'):
            cols = row.find_all('td')
            if cols:
                row_data = [col.text.strip() for col in cols]
                data.append(row_data)

        df = pd.DataFrame(data, columns=headers)
        
        # Clean up the data
        df['Season'] = df['Season'].str.extract(r'(\d{4}-\d{4})')
        df['Salary Cap'] = df['Salary Cap'].str.replace('$', '').str.replace(',', '').astype(float)
        
        # Convert other columns to float, handling non-numeric values
        for col in df.columns:
            if col not in ['Season', 'Salary Cap']:
                df[col] = pd.to_numeric(df[col].str.replace('$', '').str.replace(',', ''), errors='coerce')
        
        return df
    except Exception as e:
        print(f"Error scraping salary cap history: {str(e)}")
        return None

def scrape_player_salary_data(start_season, end_season, player_filter=None):
    all_data = []
    
    for season in range(start_season, end_season + 1):
        season_str = f"{season}-{str(season+1)[-2:]}"
        url = f"https://hoopshype.com/salaries/players/{season}-{season+1}/"
        print(f"Scraping data for {season_str} from URL: {url}")
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        table = soup.find('table', class_='hh-salaries-ranking-table')
        
        if table:
            rows = table.find_all('tr')[1:]
            for row in rows:
                cols = row.find_all('td')
                if len(cols) >= 3:
                    player = cols[1].get_text(strip=True)
                    if player_filter is None or player_filter.lower() == 'all' or player.lower() == player_filter.lower():
                        salary_text = cols[2].get_text(strip=True)
                        salary = int(salary_text.replace('$', '').replace(',', ''))
                        all_data.append({'Player': player, 'Salary': salary, 'Season': season_str})
        else:
            print(f"No salary data found for season {season_str}")
        
        time.sleep(2)  # Delay between requests to avoid hitting rate limits
    
    df = pd.DataFrame(all_data)
    print(f"Scraped salary data for {'all players' if player_filter is None or player_filter.lower() == 'all' else player_filter} from seasons {start_season}-{end_season}:")
    print(df.head())
    return df


def scrape_team_salary_data(season):
    url = f"https://hoopshype.com/salaries/{season}/"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    table = soup.find('table', class_='hh-salaries-ranking-table')
    rows = table.find_all('tr')[1:]
    data = []
    for row in rows:
        cols = row.find_all('td')
        team = cols[1].get_text(strip=True)
        salary = int(cols[2].get_text(strip=True).replace('$', '').replace(',', ''))
        data.append({'Team': team, 'Team_Salary': salary, 'Season': season})
    return pd.DataFrame(data)

# %%
# player_utils.py
import pandas as pd
from io import StringIO
import requests
from bs4 import BeautifulSoup
# from fetch_utils import fetch_player_info, fetch_career_stats, fetch_league_standings

# Function to get the player URL from the search results
def get_player_url(player_name):
    search_url = f"https://www.basketball-reference.com/search/search.fcgi?search={player_name.replace(' ', '+')}"
    response = requests.get(search_url)
    soup = BeautifulSoup(response.content, 'html.parser')
    
    search_results = soup.find('div', {'class': 'search-results'})
    if search_results:
        for item in search_results.find_all('div', {'class': 'search-item'}):
            link = item.find('a')
            if link and 'players' in link['href']:
                return f"https://www.basketball-reference.com{link['href']}"
    
    raise ValueError(f"Player URL not found for {player_name}")

# General function to scrape data from a specific section of the player's page
def scrape_player_data(player_name, section_id, season_end_year):
    player_url = get_player_url(player_name)
    response = requests.get(player_url)
    soup = BeautifulSoup(response.content, 'html.parser')

    data = {}
    table = soup.find('table', {'id': section_id})
    if table:
        df = pd.read_html(StringIO(str(table)))[0]
        if isinstance(df.columns, pd.MultiIndex):
            df.columns = df.columns.droplevel()  # Drop the multi-index level
        df = df[df['Season'].str.contains(season_end_year)]
        
        if not df.empty:
            row = df.iloc[0]
            for col in df.columns:
                if col not in ['Season', 'Age', 'Tm', 'Lg', 'Pos', 'G', 'GS']:
                    try:
                        data[col] = float(row[col])
                    except ValueError:
                        data[col] = row[col]
        else:
            raise ValueError(f"No data found for season {season_end_year}")
    else:
        raise ValueError(f"Section {section_id} not found for {player_name}")
    
    return data

def process_player_data(player, season, all_players):
    if player.lower() not in all_players:
        print(f"No player ID found for {player}")
        return None

    player_id = all_players[player.lower()]['player_id']
    team_id = all_players[player.lower()]['team_id']
    
    player_info = fetch_player_info(player_id)
    career_stats = fetch_career_stats(player_id)
    league_standings = fetch_league_standings(season)
    
    # Scrape advanced metrics from Basketball Reference
    advanced_metrics = scrape_advanced_metrics(player, season)

    if player_info is None or career_stats is None or career_stats.empty:
        print(f"Unable to fetch complete data for {player}")
        return None

    season_stats = career_stats[career_stats['SEASON_ID'].str.contains(season.split('-')[0], na=False)]
    if season_stats.empty:
        print(f"No stats found for {player} in season {season}")
        return None

    latest_season_stats = season_stats.iloc[0]
    
    try:
        draft_year = int(player_info['DRAFT_YEAR'].iloc[0])
    except ValueError:
        draft_year = int(player_info['FROM_YEAR'].iloc[0])

    current_season_year = int(season.split('-')[0])
    years_of_service = max(0, current_season_year - draft_year)

    # Handle missing league standings gracefully
    if league_standings is not None and not league_standings.empty:
        player_stats = calculate_player_stats(latest_season_stats, player_info, years_of_service, team_id, league_standings, advanced_metrics)
    else:
        player_stats = calculate_player_stats(latest_season_stats, player_info, years_of_service, team_id, pd.DataFrame(), advanced_metrics)

    player_stats.update({'Player': player, 'Season': season})

    print(f"Processed data for {player} in season {season}: {player_stats}")
    return player_stats


def calculate_player_stats(stats, player_info, years_of_service, team_id, league_standings, advanced_metrics):
    fg = stats.get('FGM', 0) or 0
    fga = stats.get('FGA', 0) or 0
    fg3 = stats.get('FG3M', 0) or 0
    fg3a = stats.get('FG3A', 0) or 0
    efg = (fg + 0.5 * fg3) / fga if fga != 0 else 0
    fg2 = fg - fg3
    fg2a = fga - fg3a
    fg2_pct = (fg2 / fg2a) if fg2a != 0 else 0

    player_stats = {
        'Position': player_info.iloc[0]['POSITION'],
        'Age': stats.get('PLAYER_AGE', None),
        'Team': stats.get('TEAM_ABBREVIATION', None),
        'TeamID': team_id,
        'Years of Service': years_of_service,
        'GP': stats.get('GP', None),
        'GS': stats.get('GS', None),
        'MP': stats.get('MIN', None),
        'FG': fg,
        'FGA': fga,
        'FG%': stats.get('FG_PCT', None),
        '3P': fg3,
        '3PA': fg3a,
        '3P%': stats.get('FG3_PCT', None),
        '2P': fg2,
        '2PA': fg2a,
        '2P%': fg2_pct,
        'eFG%': efg,
        'FT': stats.get('FTM', None),
        'FTA': stats.get('FTA', None),
        'FT%': stats.get('FT_PCT', None),
        'ORB': stats.get('OREB', None),
        'DRB': stats.get('DREB', None),
        'TRB': stats.get('REB', None),
        'AST': stats.get('AST', None),
        'STL': stats.get('STL', None),
        'BLK': stats.get('BLK', None),
        'TOV': stats.get('TOV', None),
        'PF': stats.get('PF', None),
        'PTS': stats.get('PTS', None),
    }
    
    # Add advanced metrics
    advanced_metrics_to_add = [
        'PER', 'TS%', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'
    ]
    for metric in advanced_metrics_to_add:
        player_stats[metric] = advanced_metrics.get(metric, None)

    if league_standings is not None and team_id is not None:
        team_standings = league_standings[league_standings['TeamID'] == team_id]
        if not team_standings.empty:
            player_stats.update({
                'Wins': team_standings['WINS'].values[0],
                'Losses': team_standings['LOSSES'].values[0]
            })

    return player_stats


def scrape_advanced_metrics(player_name, season):
    try:
        search_url = f"https://www.basketball-reference.com/search/search.fcgi?search={player_name.replace(' ', '+')}"
        response = requests.get(search_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        search_results = soup.find('div', {'class': 'search-results'})
        if search_results:
            for item in search_results.find_all('div', {'class': 'search-item'}):
                link = item.find('a')
                if link and 'players' in link['href']:
                    player_url = f"https://www.basketball-reference.com{link['href']}"
                    break
            else:
                return {}
        else:
            return {}

        response = requests.get(player_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        table = soup.find('table', {'id': 'advanced'})
        if table:
            df = pd.read_html(StringIO(str(table)))[0]
            if isinstance(df.columns, pd.MultiIndex):
                df.columns = df.columns.droplevel()
            df['Season'] = df['Season'].astype(str)
            df = df[df['Season'].str.contains(season.split('-')[0], na=False)]
            if not df.empty:
                row = df.iloc[0]
                metrics = ['PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']
                return {col: row[col] for col in metrics if col in row.index}
    except Exception as e:
        print(f"Error scraping advanced metrics for {player_name}: {e}")
    return {}

# %%
import pandas as pd
import numpy as np
import cpi
from datetime import datetime
# from fetch_utils import fetch_all_players
# from scrape_utils import scrape_player_salary_data, scrape_team_salary_data, scrape_salary_cap_history
# from player_utils import process_player_data

def inflate_value(value, year_str):
    try:
        year = int(year_str[:4])
        current_year = datetime.now().year
       
        if year >= current_year:
            return value  # Return the original value for future years
        # Adjust to 2022 dollars to match the original data
        return cpi.inflate(value, year, to=2022)
    except ValueError:
        print(f"Invalid year format: {year_str}")
        return value
    except cpi.errors.CPIObjectDoesNotExist:
        # If data for the specific year is not available, use the earliest available year
        earliest_year = min(cpi.SURVEYS['CPI-U'].indexes['annual'].keys()).year
        return cpi.inflate(value, earliest_year, to=2022)
    except Exception as e:
        print(f"Error inflating value for year {year_str}: {e}")
        return value

def load_existing_data(file_path):
    expected_columns = [
        'Season', 'Player', 'Salary', 'GP', 'PTS', 'TRB', 'AST', 'Injured', 'Injury_Periods',
        'Position', 'Age', 'Team', 'TeamID', 'Years of Service', 'GS', 'MP', 'FG', 'FGA', 'FG%',
        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'STL',
        'BLK', 'TOV', 'PF', 'Wins', 'Losses', 'Team_Salary',
        'Mid-Level Exception', 'Salary Cap', 'Luxury Tax', '1st Apron', '2nd Apron', 'BAE',
        'Standard /Non-Taxpayer', 'Taxpayer', 'Team Room /Under Cap', 'Salary_Cap_Inflated',
        'PER', 'TS%', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%',
        'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP'
    ]

    try:
        data = pd.read_csv(file_path)
        
        # Ensure the DataFrame has the expected columns
        for column in expected_columns:
            if column not in data.columns:
                data[column] = pd.Series(dtype='object')
        
        # Remove any unexpected columns
        data = data[expected_columns]
        
        return data
    except FileNotFoundError:
        print(f"No existing data found at {file_path}. Starting with an empty DataFrame.")
        return pd.DataFrame(columns=expected_columns)


def merge_salary_cap_data(player_data, salary_cap_data):
    player_data['Season_Year'] = player_data['Season'].str[:4].astype(int)
    salary_cap_data['Season_Year'] = salary_cap_data['Season'].str[:4].astype(int)
    
    # Add inflation-adjusted salary cap
    salary_cap_data['Salary_Cap_Inflated'] = salary_cap_data.apply(
        lambda row: inflate_value(row['Salary Cap'], row['Season']),
        axis=1
    )
    
    # Merge salary cap data
    merged_data = pd.merge(player_data, salary_cap_data, on='Season_Year', how='left', suffixes=('', '_cap'))
    
    # Update salary cap columns
    cap_columns = ['Mid-Level Exception', 'Salary Cap', 'Luxury Tax', '1st Apron', '2nd Apron', 'BAE',
                   'Standard /Non-Taxpayer', 'Taxpayer', 'Team Room /Under Cap', 'Salary_Cap_Inflated']
    for col in cap_columns:
        if f'{col}_cap' in merged_data.columns:
            merged_data[col] = merged_data[col].fillna(merged_data[f'{col}_cap'])
            merged_data.drop(columns=[f'{col}_cap'], inplace=True)
    
    # Clean up temporary columns
    merged_data.drop(columns=['Season_Year'], inplace=True)
    
    return merged_data

def load_injury_data(file_path='../data/processed/NBA Player Injury Stats(1951 - 2023).csv'):
    try:
        injury_data = pd.read_csv(file_path)
        injury_data['Date'] = pd.to_datetime(injury_data['Date'])
        injury_data['Season'] = injury_data['Date'].apply(lambda x: f"{x.year}-{str(x.year+1)[-2:]}" if x.month >= 10 else f"{x.year-1}-{str(x.year)[-2:]}")
        print("Injury data loaded successfully")
        return injury_data
    except FileNotFoundError:
        print("Injury data file not found. Proceeding without injury data.")
        return None

def merge_injury_data(merged_data, injury_data, season):
    if injury_data is None:
        return merged_data
    
    season_injury_data = injury_data[injury_data['Season'] == season]
    all_players_df = pd.DataFrame({'Player': merged_data['Player'].unique()})
    all_players_df['Season'] = season
    all_players_df['Injured'] = False
    all_players_df['Injury_Periods'] = ''

    for player in all_players_df['Player']:
        player_injuries = season_injury_data[season_injury_data['Relinquished'].str.contains(player, case=False, na=False)]
        if not player_injuries.empty:
            periods = []
            for i in range(0, len(player_injuries), 2):
                try:
                    start_date = player_injuries.iloc[i]['Date'].strftime('%Y-%m-%d')
                    end_date = player_injuries.iloc[i+1]['Date'].strftime('%Y-%m-%d')
                    periods.append(f"{start_date} - {end_date}")
                except IndexError:
                    periods.append(f"{start_date} - ongoing")
            all_players_df.loc[all_players_df['Player'] == player, 'Injured'] = True
            all_players_df.loc[all_players_df['Player'] == player, 'Injury_Periods'] = '; '.join(periods)

    merged_data = pd.merge(merged_data, all_players_df, on=['Player', 'Season'], how='left')
    return merged_data

def calculate_percentages(df):
    df['FG%'] = df['FG'] / df['FGA'].replace(0, np.nan)
    df['3P%'] = df['3P'] / df['3PA'].replace(0, np.nan)
    df['2P%'] = df['2P'] / df['2PA'].replace(0, np.nan)
    df['FT%'] = df['FT'] / df['FTA'].replace(0, np.nan)
    df['eFG%'] = (df['FG'] + 0.5 * df['3P']) / df['FGA'].replace(0, np.nan)
    return df


def update_data(existing_data, start_year, end_year, player_filter=None, min_avg_minutes=None):
    all_data = existing_data.copy()
    injury_data = load_injury_data()

    salary_data = scrape_player_salary_data(start_year, end_year)
    print(f"Fetched salary data with shape: {salary_data.shape}")

    for year in range(start_year, end_year + 1):
        season = f"{year}-{str(year+1)[-2:]}"
        
        # Remove existing data for the specified season and player filter
        if player_filter and player_filter.lower() != 'all':
            all_data = all_data[~((all_data['Season'] == season) & (all_data['Player'].str.lower() == player_filter.lower()))]
        else:
            all_data = all_data[all_data['Season'] != season]
        
        print(f"Processing data for season {season}")
        
        team_salary_data = scrape_team_salary_data(season)
        all_players = fetch_all_players(season=season)
        
        season_salary_data = salary_data[salary_data['Season'] == season]
        
        if player_filter and player_filter.lower() != 'all':
            season_salary_data = season_salary_data[season_salary_data['Player'].str.lower() == player_filter.lower()]

        additional_stats = []

        for _, salary_row in season_salary_data.iterrows():
            player_name = salary_row['Player']
            player_name_lower = player_name.lower()
            
            if player_name_lower in all_players:
                player_stats = process_player_data(player_name, season, all_players)
                if player_stats:
                    player_stats['Salary'] = salary_row['Salary']
                    additional_stats.append(player_stats)

        additional_stats_df = pd.DataFrame(additional_stats)

        if additional_stats_df.empty or 'Team' not in additional_stats_df.columns:
            print(f"Warning: No valid player stats data for season {season}")
            continue

        # Merge team salary data
        merged_data = pd.merge(additional_stats_df, team_salary_data, on=['Team', 'Season'], how='left')

        if injury_data is not None:
            merged_data = merge_injury_data(merged_data, injury_data, season)

        # Apply minimum average minutes filter if specified
        if min_avg_minutes is not None:
            merged_data = merged_data[merged_data['MP'] >= min_avg_minutes]

        # Calculate percentages
        merged_data = calculate_percentages(merged_data)

        all_data = pd.concat([all_data, merged_data], ignore_index=True)

    # Sort the final data by season and player
    all_data.sort_values(by=['Season', 'Player'], inplace=True)

    # Ensure only expected columns are present and remove any empty columns
    expected_columns = load_existing_data(file_path='').columns.tolist()
    all_data = all_data[expected_columns]
    all_data = all_data.dropna(axis=1, how='all')

    print(f"Updated data with shape: {all_data.shape}")
    return all_data

def main():
    start_year = 2022
    end_year = 2023
    processed_file_path = '../data/processed/nba_player_data_final_inflated.csv'
    salary_cap_file_path = '../data/processed/salary_cap_history_inflated.csv'

    player_filter = input("Enter player name or 'all' for all players: ").strip()
    min_avg_minutes = None
    if player_filter.lower() == 'all':
        min_avg_minutes = float(input("Enter the minimum average minutes per game (default 25 mins): ") or 25)

    existing_data = load_existing_data(processed_file_path)
    print(f"Loaded existing data with shape: {existing_data.shape}")

    try:
        print(f"Updating data for years {start_year} to {end_year}")
        updated_data = update_data(existing_data, start_year, end_year, player_filter, min_avg_minutes)

        if not updated_data.empty:
            print("New data retrieved. Processing and saving...")

            print("Fetching salary cap data...")
            salary_cap_data = scrape_salary_cap_history()

            if salary_cap_data is not None:
                print("Salary cap data successfully retrieved.")
                
                # Add inflation-adjusted salary cap to salary cap data
                salary_cap_data['Salary_Cap_Inflated'] = salary_cap_data.apply(
                    lambda row: inflate_value(row['Salary Cap'], row['Season']),
                    axis=1
                )
                
                salary_cap_data.to_csv(salary_cap_file_path, index=False)
                print(f"Salary cap data saved to {salary_cap_file_path}")

                print("Merging salary cap data with player data...")
                updated_data = merge_salary_cap_data(updated_data, salary_cap_data)

                print("Final data shape:", updated_data.shape)
                print("Final data columns:", updated_data.columns)
            else:
                print("Warning: Failed to retrieve salary cap data. Skipping merge.")

            # Ensure all expected columns are present before saving
            expected_columns = load_existing_data(processed_file_path).columns.tolist()
            for column in expected_columns:
                if column not in updated_data.columns:
                    updated_data[column] = pd.NA

            # Remove any remaining empty columns
            updated_data = updated_data.dropna(axis=1, how='all')

            # Save the updated data
            updated_data.to_csv(processed_file_path, index=False)
            print(f"Updated and cleaned data saved to {processed_file_path}")

            # Print summary of the data
            summary_columns = ['Season', 'Player', 'Salary', 'GP', 'PTS', 'TRB', 'AST', 'PER', 'WS', 'VORP', 'Injured', 'Injury_Periods', 'FG%', '3P%', 'FT%', 'Team_Salary', 'Salary Cap', 'Salary_Cap_Inflated']
            available_columns = [col for col in summary_columns if col in updated_data.columns]
            print("\nData summary")
            print(updated_data[available_columns].head().to_string(index=False))
        else:
            print("No new data to save. The dataset is empty.")


    except Exception as e:
        print(f"An error occurred: {str(e)}")
        print("Traceback:")
        import traceback
        traceback.print_exc()

if __name__ == "__main__":
    main()
# Out:
# Loaded existing data with shape: (480, 66)
# Updating data for years 2022 to 2023
# Injury data loaded successfully
# Scraping data for 2022-23 from URL: https://hoopshype.com/salaries/players/2022-2023/
# Scraping data for 2023-24 from URL: https://hoopshype.com/salaries/players/2023-2024/
# Scraped salary data for all players from seasons 2022-2023:
#               Player    Salary   Season
# 0      Stephen Curry  48070014  2022-23
# 1          John Wall  47345760  2022-23
# 2  Russell Westbrook  47080179  2022-23
# 3       LeBron James  44474988  2022-23
# 4       Kevin Durant  44119845  2022-23
# Fetched salary data with shape: (1186, 3)
# Processing data for season 2022-23
# Processed data for Stephen Curry in season 2022-23: {'Position': 'Guard', 'Age': 35.0, 'Team': 'GSW', 'TeamID': 1610612744, 'Years of Service': 13, 'GP': 56, 'GS': 56, 'MP': 1941.0, 'FG': 559, 'FGA': 1133, 'FG%': 0.493, '3P': 273, '3PA': 639, '3P%': 0.427, '2P': 286, '2PA': 494, '2P%': 0.5789473684210527, 'eFG%': 0.6138570167696381, 'FT': 257, 'FTA': 281, 'FT%': 0.915, 'ORB': 39, 'DRB': 302, 'TRB': 341, 'AST': 352, 'STL': 52, 'BLK': 20, 'TOV': 179, 'PF': 117, 'PTS': 1648, 'PER': 24.1, 'TS%': 0.656, 'ORB%': 2.3, 'DRB%': 16.8, 'TRB%': 9.7, 'AST%': 30.0, 'STL%': 1.3, 'BLK%': 0.9, 'TOV%': 12.5, 'USG%': 31.0, 'OWS': 5.8, 'DWS': 2.0, 'WS': 7.8, 'WS/48': 0.192, 'OBPM': 7.5, 'DBPM': 0.1, 'BPM': 7.5, 'VORP': 4.7, 'Wins': 44, 'Losses': 38, 'Player': 'Stephen Curry', 'Season': '2022-23'}
# Processed data for John Wall in season 2022-23: {'Position': 'Guard', 'Age': 32.0, 'Team': 'LAC', 'TeamID': 0, 'Years of Service': 12, 'GP': 34, 'GS': 3, 'MP': 755.0, 'FG': 138, 'FGA': 338, 'FG%': 0.408, '3P': 33, '3PA': 109, '3P%': 0.303, '2P': 105, '2PA': 229, '2P%': 0.4585152838427948, 'eFG%': 0.45710059171597633, 'FT': 77, 'FTA': 113, 'FT%': 0.681, 'ORB': 14, 'DRB': 78, 'TRB': 92, 'AST': 178, 'STL': 27, 'BLK': 12, 'TOV': 80, 'PF': 59, 'PTS': 386, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'John Wall', 'Season': '2022-23'}
# Processed data for Russell Westbrook in season 2022-23: {'Position': 'Guard', 'Age': 34.0, 'Team': 'LAL', 'TeamID': 1610612746, 'Years of Service': 14, 'GP': 52, 'GS': 3, 'MP': 1491.0, 'FG': 304, 'FGA': 729, 'FG%': 0.417, '3P': 63, '3PA': 213, '3P%': 0.296, '2P': 241, '2PA': 516, '2P%': 0.46705426356589147, 'eFG%': 0.46021947873799723, 'FT': 156, 'FTA': 238, 'FT%': 0.655, 'ORB': 59, 'DRB': 262, 'TRB': 321, 'AST': 391, 'STL': 53, 'BLK': 23, 'TOV': 184, 'PF': 121, 'PTS': 827, 'PER': 16.1, 'TS%': 0.513, 'ORB%': 4.7, 'DRB%': 16.5, 'TRB%': 10.8, 'AST%': 38.6, 'STL%': 1.7, 'BLK%': 1.3, 'TOV%': 18.4, 'USG%': 27.7, 'OWS': -0.6, 'DWS': 2.6, 'WS': 1.9, 'WS/48': 0.044, 'OBPM': 0.3, 'DBPM': -0.1, 'BPM': 0.2, 'VORP': 1.2, 'Wins': 44, 'Losses': 38, 'Player': 'Russell Westbrook', 'Season': '2022-23'}
# Processed data for LeBron James in season 2022-23: {'Position': 'Forward', 'Age': 38.0, 'Team': 'LAL', 'TeamID': 1610612747, 'Years of Service': 19, 'GP': 55, 'GS': 54, 'MP': 1954.0, 'FG': 609, 'FGA': 1219, 'FG%': 0.5, '3P': 121, '3PA': 377, '3P%': 0.321, '2P': 488, '2PA': 842, '2P%': 0.5795724465558195, 'eFG%': 0.5492206726825266, 'FT': 251, 'FTA': 327, 'FT%': 0.768, 'ORB': 65, 'DRB': 392, 'TRB': 457, 'AST': 375, 'STL': 50, 'BLK': 32, 'TOV': 178, 'PF': 88, 'PTS': 1590, 'PER': 23.9, 'TS%': 0.583, 'ORB%': 3.7, 'DRB%': 20.8, 'TRB%': 12.5, 'AST%': 33.5, 'STL%': 1.2, 'BLK%': 1.4, 'TOV%': 11.6, 'USG%': 33.3, 'OWS': 3.2, 'DWS': 2.4, 'WS': 5.6, 'WS/48': 0.138, 'OBPM': 5.5, 'DBPM': 0.6, 'BPM': 6.1, 'VORP': 4.0, 'Wins': 43, 'Losses': 39, 'Player': 'LeBron James', 'Season': '2022-23'}
# Processed data for Kevin Durant in season 2022-23: {'Position': 'Forward', 'Age': 34.0, 'Team': 'BKN', 'TeamID': 1610612756, 'Years of Service': 15, 'GP': 39, 'GS': 39, 'MP': 1403.0, 'FG': 410, 'FGA': 734, 'FG%': 0.559, '3P': 71, '3PA': 189, '3P%': 0.376, '2P': 339, '2PA': 545, '2P%': 0.6220183486238532, 'eFG%': 0.6069482288828338, 'FT': 267, 'FTA': 286, 'FT%': 0.934, 'ORB': 14, 'DRB': 248, 'TRB': 262, 'AST': 207, 'STL': 32, 'BLK': 57, 'TOV': 136, 'PF': 92, 'PTS': 1158, 'PER': 25.9, 'TS%': 0.677, 'ORB%': 1.2, 'DRB%': 19.5, 'TRB%': 10.5, 'AST%': 24.5, 'STL%': 1.0, 'BLK%': 3.4, 'TOV%': 13.4, 'USG%': 30.7, 'OWS': 4.7, 'DWS': 2.1, 'WS': 6.8, 'WS/48': 0.194, 'OBPM': 6.0, 'DBPM': 1.2, 'BPM': 7.1, 'VORP': 3.9, 'Wins': 45, 'Losses': 37, 'Player': 'Kevin Durant', 'Season': '2022-23'}
# Processed data for Bradley Beal in season 2022-23: {'Position': 'Guard', 'Age': 30.0, 'Team': 'WAS', 'TeamID': 1610612764, 'Years of Service': 10, 'GP': 50, 'GS': 50, 'MP': 1673.0, 'FG': 444, 'FGA': 878, 'FG%': 0.506, '3P': 80, '3PA': 219, '3P%': 0.365, '2P': 364, '2PA': 659, '2P%': 0.5523520485584219, 'eFG%': 0.55125284738041, 'FT': 192, 'FTA': 228, 'FT%': 0.842, 'ORB': 41, 'DRB': 155, 'TRB': 196, 'AST': 271, 'STL': 45, 'BLK': 33, 'TOV': 145, 'PF': 107, 'PTS': 1160, 'PER': 19.7, 'TS%': 0.593, 'ORB%': 2.8, 'DRB%': 9.9, 'TRB%': 6.5, 'AST%': 26.6, 'STL%': 1.3, 'BLK%': 1.7, 'TOV%': 12.9, 'USG%': 29.2, 'OWS': 2.2, 'DWS': 1.2, 'WS': 3.4, 'WS/48': 0.099, 'OBPM': 2.9, 'DBPM': -1.2, 'BPM': 1.8, 'VORP': 1.6, 'Wins': 35, 'Losses': 47, 'Player': 'Bradley Beal', 'Season': '2022-23'}
# Processed data for Kawhi Leonard in season 2022-23: {'Position': 'Forward', 'Age': 32.0, 'Team': 'LAC', 'TeamID': 1610612746, 'Years of Service': 11, 'GP': 52, 'GS': 50, 'MP': 1748.0, 'FG': 446, 'FGA': 871, 'FG%': 0.512, '3P': 104, '3PA': 250, '3P%': 0.416, '2P': 342, '2PA': 621, '2P%': 0.5507246376811594, 'eFG%': 0.5717566016073479, 'FT': 243, 'FTA': 279, 'FT%': 0.871, 'ORB': 57, 'DRB': 281, 'TRB': 338, 'AST': 204, 'STL': 72, 'BLK': 28, 'TOV': 88, 'PF': 84, 'PTS': 1239, 'PER': 23.9, 'TS%': 0.623, 'ORB%': 3.7, 'DRB%': 17.8, 'TRB%': 10.8, 'AST%': 19.6, 'STL%': 2.0, 'BLK%': 1.4, 'TOV%': 8.1, 'USG%': 27.0, 'OWS': 4.9, 'DWS': 2.2, 'WS': 7.1, 'WS/48': 0.194, 'OBPM': 5.1, 'DBPM': 0.9, 'BPM': 6.1, 'VORP': 3.5, 'Wins': 44, 'Losses': 38, 'Player': 'Kawhi Leonard', 'Season': '2022-23'}
# Processed data for Paul George in season 2022-23: {'Position': 'Forward', 'Age': 33.0, 'Team': 'LAC', 'TeamID': 1610612746, 'Years of Service': 12, 'GP': 56, 'GS': 56, 'MP': 1939.0, 'FG': 459, 'FGA': 1004, 'FG%': 0.457, '3P': 158, '3PA': 426, '3P%': 0.371, '2P': 301, '2PA': 578, '2P%': 0.5207612456747405, 'eFG%': 0.5358565737051793, 'FT': 256, 'FTA': 294, 'FT%': 0.871, 'ORB': 45, 'DRB': 297, 'TRB': 342, 'AST': 288, 'STL': 83, 'BLK': 20, 'TOV': 176, 'PF': 159, 'PTS': 1332, 'PER': 19.6, 'TS%': 0.588, 'ORB%': 2.6, 'DRB%': 17.0, 'TRB%': 9.9, 'AST%': 24.2, 'STL%': 2.1, 'BLK%': 0.9, 'TOV%': 13.4, 'USG%': 29.5, 'OWS': 2.3, 'DWS': 2.3, 'WS': 4.6, 'WS/48': 0.114, 'OBPM': 2.4, 'DBPM': 0.3, 'BPM': 2.8, 'VORP': 2.3, 'Wins': 44, 'Losses': 38, 'Player': 'Paul George', 'Season': '2022-23'}
# Processed data for Giannis Antetokounmpo in season 2022-23: {'Position': 'Forward', 'Age': 28.0, 'Team': 'MIL', 'TeamID': 1610612749, 'Years of Service': 9, 'GP': 63, 'GS': 63, 'MP': 2024.0, 'FG': 707, 'FGA': 1278, 'FG%': 0.553, '3P': 47, '3PA': 171, '3P%': 0.275, '2P': 660, '2PA': 1107, '2P%': 0.5962059620596206, 'eFG%': 0.5715962441314554, 'FT': 498, 'FTA': 772, 'FT%': 0.645, 'ORB': 137, 'DRB': 605, 'TRB': 742, 'AST': 359, 'STL': 52, 'BLK': 51, 'TOV': 246, 'PF': 197, 'PTS': 1959, 'PER': 29.0, 'TS%': 0.605, 'ORB%': 7.3, 'DRB%': 30.0, 'TRB%': 19.1, 'AST%': 33.2, 'STL%': 1.2, 'BLK%': 2.1, 'TOV%': 13.2, 'USG%': 38.8, 'OWS': 4.9, 'DWS': 3.7, 'WS': 8.6, 'WS/48': 0.204, 'OBPM': 5.8, 'DBPM': 2.7, 'BPM': 8.5, 'VORP': 5.4, 'Wins': 58, 'Losses': 24, 'Player': 'Giannis Antetokounmpo', 'Season': '2022-23'}
# Processed data for Damian Lillard in season 2022-23: {'Position': 'Guard', 'Age': 32.0, 'Team': 'POR', 'TeamID': 1610612757, 'Years of Service': 10, 'GP': 58, 'GS': 58, 'MP': 2107.0, 'FG': 556, 'FGA': 1202, 'FG%': 0.463, '3P': 244, '3PA': 658, '3P%': 0.371, '2P': 312, '2PA': 544, '2P%': 0.5735294117647058, 'eFG%': 0.5640599001663894, 'FT': 510, 'FTA': 558, 'FT%': 0.914, 'ORB': 44, 'DRB': 233, 'TRB': 277, 'AST': 425, 'STL': 50, 'BLK': 18, 'TOV': 191, 'PF': 109, 'PTS': 1866, 'PER': 26.7, 'TS%': 0.645, 'ORB%': 2.4, 'DRB%': 12.8, 'TRB%': 7.6, 'AST%': 35.0, 'STL%': 1.2, 'BLK%': 0.8, 'TOV%': 11.7, 'USG%': 33.8, 'OWS': 8.2, 'DWS': 0.8, 'WS': 9.0, 'WS/48': 0.205, 'OBPM': 8.3, 'DBPM': -1.2, 'BPM': 7.1, 'VORP': 4.9, 'Wins': 33, 'Losses': 49, 'Player': 'Damian Lillard', 'Season': '2022-23'}
# Processed data for Klay Thompson in season 2022-23: {'Position': 'Guard', 'Age': 33.0, 'Team': 'GSW', 'TeamID': 1610612744, 'Years of Service': 11, 'GP': 69, 'GS': 69, 'MP': 2279.0, 'FG': 546, 'FGA': 1252, 'FG%': 0.436, '3P': 301, '3PA': 731, '3P%': 0.412, '2P': 245, '2PA': 521, '2P%': 0.47024952015355087, 'eFG%': 0.5563099041533547, 'FT': 116, 'FTA': 132, 'FT%': 0.879, 'ORB': 39, 'DRB': 247, 'TRB': 286, 'AST': 163, 'STL': 49, 'BLK': 29, 'TOV': 123, 'PF': 130, 'PTS': 1509, 'PER': 14.7, 'TS%': 0.576, 'ORB%': 1.9, 'DRB%': 11.7, 'TRB%': 6.9, 'AST%': 11.0, 'STL%': 1.0, 'BLK%': 1.1, 'TOV%': 8.6, 'USG%': 26.4, 'OWS': 1.2, 'DWS': 1.9, 'WS': 3.1, 'WS/48': 0.066, 'OBPM': 1.5, 'DBPM': -1.7, 'BPM': -0.3, 'VORP': 1.0, 'Wins': 44, 'Losses': 38, 'Player': 'Klay Thompson', 'Season': '2022-23'}
# Processed data for Kyrie Irving in season 2022-23: {'Position': 'Guard', 'Age': 31.0, 'Team': 'BKN', 'TeamID': 1610612742, 'Years of Service': 11, 'GP': 40, 'GS': 40, 'MP': 1478.0, 'FG': 398, 'FGA': 819, 'FG%': 0.486, '3P': 130, '3PA': 348, '3P%': 0.374, '2P': 268, '2PA': 471, '2P%': 0.5690021231422505, 'eFG%': 0.5653235653235653, 'FT': 158, 'FTA': 179, 'FT%': 0.883, 'ORB': 38, 'DRB': 166, 'TRB': 204, 'AST': 211, 'STL': 41, 'BLK': 33, 'TOV': 91, 'PF': 109, 'PTS': 1084, 'PER': 22.4, 'TS%': 0.613, 'ORB%': 3.0, 'DRB%': 12.3, 'TRB%': 7.7, 'AST%': 25.4, 'STL%': 1.4, 'BLK%': 1.7, 'TOV%': 8.8, 'USG%': 28.9, 'OWS': 5.4, 'DWS': 2.0, 'WS': 7.4, 'WS/48': 0.159, 'OBPM': 4.8, 'DBPM': -0.7, 'BPM': 4.1, 'VORP': 3.5, 'Wins': 38, 'Losses': 44, 'Player': 'Kyrie Irving', 'Season': '2022-23'}
# Processed data for Rudy Gobert in season 2022-23: {'Position': 'Center', 'Age': 31.0, 'Team': 'MIN', 'TeamID': 1610612750, 'Years of Service': 9, 'GP': 70, 'GS': 70, 'MP': 2148.0, 'FG': 360, 'FGA': 546, 'FG%': 0.659, '3P': 0, '3PA': 3, '3P%': 0.0, '2P': 360, '2PA': 543, '2P%': 0.6629834254143646, 'eFG%': 0.6593406593406593, 'FT': 219, 'FTA': 340, 'FT%': 0.644, 'ORB': 231, 'DRB': 583, 'TRB': 814, 'AST': 87, 'STL': 56, 'BLK': 95, 'TOV': 122, 'PF': 210, 'PTS': 939, 'PER': 18.9, 'TS%': 0.675, 'ORB%': 12.2, 'DRB%': 29.8, 'TRB%': 21.2, 'AST%': 5.6, 'STL%': 1.2, 'BLK%': 3.9, 'TOV%': 14.9, 'USG%': 16.3, 'OWS': 4.3, 'DWS': 3.5, 'WS': 7.8, 'WS/48': 0.174, 'OBPM': 0.0, 'DBPM': 0.7, 'BPM': 0.7, 'VORP': 1.4, 'Wins': 42, 'Losses': 40, 'Player': 'Rudy Gobert', 'Season': '2022-23'}
# Processed data for Khris Middleton in season 2022-23: {'Position': 'Forward', 'Age': 31.0, 'Team': 'MIL', 'TeamID': 1610612749, 'Years of Service': 10, 'GP': 33, 'GS': 19, 'MP': 801.0, 'FG': 177, 'FGA': 406, 'FG%': 0.436, '3P': 51, '3PA': 162, '3P%': 0.315, '2P': 126, '2PA': 244, '2P%': 0.5163934426229508, 'eFG%': 0.4987684729064039, 'FT': 92, 'FTA': 102, 'FT%': 0.902, 'ORB': 28, 'DRB': 112, 'TRB': 140, 'AST': 163, 'STL': 23, 'BLK': 5, 'TOV': 71, 'PF': 68, 'PTS': 497, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 58, 'Losses': 24, 'Player': 'Khris Middleton', 'Season': '2022-23'}
# Processed data for Anthony Davis in season 2022-23: {'Position': 'Forward-Center', 'Age': 30.0, 'Team': 'LAL', 'TeamID': 1610612747, 'Years of Service': 10, 'GP': 56, 'GS': 54, 'MP': 1905.0, 'FG': 542, 'FGA': 962, 'FG%': 0.563, '3P': 19, '3PA': 74, '3P%': 0.257, '2P': 523, '2PA': 888, '2P%': 0.588963963963964, 'eFG%': 0.5732848232848233, 'FT': 348, 'FTA': 444, 'FT%': 0.784, 'ORB': 195, 'DRB': 507, 'TRB': 702, 'AST': 148, 'STL': 59, 'BLK': 114, 'TOV': 122, 'PF': 146, 'PTS': 1451, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 43, 'Losses': 39, 'Player': 'Anthony Davis', 'Season': '2022-23'}
# Processed data for Jimmy Butler in season 2022-23: {'Position': 'Forward', 'Age': 33.0, 'Team': 'MIA', 'TeamID': 1610612748, 'Years of Service': 11, 'GP': 64, 'GS': 64, 'MP': 2138.0, 'FG': 479, 'FGA': 888, 'FG%': 0.539, '3P': 36, '3PA': 103, '3P%': 0.35, '2P': 443, '2PA': 785, '2P%': 0.5643312101910828, 'eFG%': 0.5596846846846847, 'FT': 472, 'FTA': 555, 'FT%': 0.85, 'ORB': 141, 'DRB': 234, 'TRB': 375, 'AST': 340, 'STL': 117, 'BLK': 21, 'TOV': 101, 'PF': 80, 'PTS': 1466, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 44, 'Losses': 38, 'Player': 'Jimmy Butler', 'Season': '2022-23'}
# Processed data for Tobias Harris in season 2022-23: {'Position': 'Forward', 'Age': 30.0, 'Team': 'PHI', 'TeamID': 1610612755, 'Years of Service': 11, 'GP': 74, 'GS': 74, 'MP': 2436.0, 'FG': 423, 'FGA': 845, 'FG%': 0.501, '3P': 126, '3PA': 324, '3P%': 0.389, '2P': 297, '2PA': 521, '2P%': 0.5700575815738963, 'eFG%': 0.5751479289940828, 'FT': 113, 'FTA': 129, 'FT%': 0.876, 'ORB': 67, 'DRB': 357, 'TRB': 424, 'AST': 186, 'STL': 68, 'BLK': 40, 'TOV': 89, 'PF': 149, 'PTS': 1085, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 54, 'Losses': 28, 'Player': 'Tobias Harris', 'Season': '2022-23'}
# Processed data for Kemba Walker in season 2022-23: {'Position': 'Guard', 'Age': 33.0, 'Team': 'DAL', 'TeamID': 0, 'Years of Service': 11, 'GP': 9, 'GS': 1, 'MP': 144.0, 'FG': 24, 'FGA': 57, 'FG%': 0.421, '3P': 7, '3PA': 28, '3P%': 0.25, '2P': 17, '2PA': 29, '2P%': 0.5862068965517241, 'eFG%': 0.4824561403508772, 'FT': 17, 'FTA': 21, 'FT%': 0.81, 'ORB': 3, 'DRB': 13, 'TRB': 16, 'AST': 19, 'STL': 2, 'BLK': 2, 'TOV': 4, 'PF': 11, 'PTS': 72, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Kemba Walker', 'Season': '2022-23'}
# Processed data for Trae Young in season 2022-23: {'Position': 'Guard', 'Age': 24.0, 'Team': 'ATL', 'TeamID': 1610612737, 'Years of Service': 4, 'GP': 73, 'GS': 73, 'MP': 2541.0, 'FG': 597, 'FGA': 1390, 'FG%': 0.429, '3P': 154, '3PA': 460, '3P%': 0.335, '2P': 443, '2PA': 930, '2P%': 0.47634408602150535, 'eFG%': 0.4848920863309353, 'FT': 566, 'FTA': 639, 'FT%': 0.886, 'ORB': 56, 'DRB': 161, 'TRB': 217, 'AST': 741, 'STL': 80, 'BLK': 9, 'TOV': 300, 'PF': 104, 'PTS': 1914, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 41, 'Losses': 41, 'Player': 'Trae Young', 'Season': '2022-23'}
# Processed data for Zach LaVine in season 2022-23: {'Position': 'Guard', 'Age': 28.0, 'Team': 'CHI', 'TeamID': 1610612741, 'Years of Service': 8, 'GP': 77, 'GS': 77, 'MP': 2768.0, 'FG': 673, 'FGA': 1388, 'FG%': 0.485, '3P': 204, '3PA': 544, '3P%': 0.375, '2P': 469, '2PA': 844, '2P%': 0.5556872037914692, 'eFG%': 0.55835734870317, 'FT': 363, 'FTA': 428, 'FT%': 0.848, 'ORB': 42, 'DRB': 303, 'TRB': 345, 'AST': 327, 'STL': 69, 'BLK': 18, 'TOV': 194, 'PF': 159, 'PTS': 1913, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 40, 'Losses': 42, 'Player': 'Zach LaVine', 'Season': '2022-23'}
# Processed data for Luka Doncic in season 2022-23: {'Position': 'Forward-Guard', 'Age': 24.0, 'Team': 'DAL', 'TeamID': 1610612742, 'Years of Service': 4, 'GP': 66, 'GS': 66, 'MP': 2391.0, 'FG': 719, 'FGA': 1449, 'FG%': 0.496, '3P': 185, '3PA': 541, '3P%': 0.342, '2P': 534, '2PA': 908, '2P%': 0.5881057268722467, 'eFG%': 0.5600414078674948, 'FT': 515, 'FTA': 694, 'FT%': 0.742, 'ORB': 54, 'DRB': 515, 'TRB': 569, 'AST': 529, 'STL': 90, 'BLK': 33, 'TOV': 236, 'PF': 166, 'PTS': 2138, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 38, 'Losses': 44, 'Player': 'Luka Doncic', 'Season': '2022-23'}
# Processed data for Ben Simmons in season 2022-23: {'Position': 'Guard-Forward', 'Age': 26.0, 'Team': 'BKN', 'TeamID': 1610612751, 'Years of Service': 6, 'GP': 42, 'GS': 33, 'MP': 1105.0, 'FG': 133, 'FGA': 235, 'FG%': 0.566, '3P': 0, '3PA': 2, '3P%': 0.0, '2P': 133, '2PA': 233, '2P%': 0.5708154506437768, 'eFG%': 0.5659574468085107, 'FT': 25, 'FTA': 57, 'FT%': 0.439, 'ORB': 40, 'DRB': 223, 'TRB': 263, 'AST': 256, 'STL': 54, 'BLK': 24, 'TOV': 97, 'PF': 139, 'PTS': 291, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 45, 'Losses': 37, 'Player': 'Ben Simmons', 'Season': '2022-23'}
# Processed data for Pascal Siakam in season 2022-23: {'Position': 'Forward', 'Age': 29.0, 'Team': 'TOR', 'TeamID': 1610612761, 'Years of Service': 6, 'GP': 71, 'GS': 71, 'MP': 2652.0, 'FG': 630, 'FGA': 1313, 'FG%': 0.48, '3P': 93, '3PA': 287, '3P%': 0.324, '2P': 537, '2PA': 1026, '2P%': 0.5233918128654971, 'eFG%': 0.5152322924600152, 'FT': 367, 'FTA': 474, 'FT%': 0.774, 'ORB': 131, 'DRB': 425, 'TRB': 556, 'AST': 415, 'STL': 65, 'BLK': 36, 'TOV': 169, 'PF': 228, 'PTS': 1720, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 41, 'Losses': 41, 'Player': 'Pascal Siakam', 'Season': '2022-23'}
# Processed data for Myles Turner in season 2022-23: {'Position': 'Center-Forward', 'Age': 27.0, 'Team': 'IND', 'TeamID': 1610612754, 'Years of Service': 7, 'GP': 62, 'GS': 62, 'MP': 1825.0, 'FG': 402, 'FGA': 733, 'FG%': 0.548, '3P': 93, '3PA': 249, '3P%': 0.373, '2P': 309, '2PA': 484, '2P%': 0.6384297520661157, 'eFG%': 0.611869031377899, 'FT': 216, 'FTA': 276, 'FT%': 0.783, 'ORB': 88, 'DRB': 378, 'TRB': 466, 'AST': 89, 'STL': 36, 'BLK': 140, 'TOV': 103, 'PF': 215, 'PTS': 1113, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 35, 'Losses': 47, 'Player': 'Myles Turner', 'Season': '2022-23'}
# Processed data for Jrue Holiday in season 2022-23: {'Position': 'Guard', 'Age': 33.0, 'Team': 'MIL', 'TeamID': 1610612749, 'Years of Service': 13, 'GP': 67, 'GS': 65, 'MP': 2183.0, 'FG': 490, 'FGA': 1023, 'FG%': 0.479, '3P': 158, '3PA': 411, '3P%': 0.384, '2P': 332, '2PA': 612, '2P%': 0.5424836601307189, 'eFG%': 0.5562072336265884, 'FT': 152, 'FTA': 177, 'FT%': 0.859, 'ORB': 79, 'DRB': 262, 'TRB': 341, 'AST': 495, 'STL': 79, 'BLK': 25, 'TOV': 197, 'PF': 116, 'PTS': 1290, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 58, 'Losses': 24, 'Player': 'Jrue Holiday', 'Season': '2022-23'}
# Processed data for Karl-Anthony Towns in season 2022-23: {'Position': 'Center-Forward', 'Age': 27.0, 'Team': 'MIN', 'TeamID': 1610612750, 'Years of Service': 7, 'GP': 29, 'GS': 29, 'MP': 957.0, 'FG': 212, 'FGA': 428, 'FG%': 0.495, '3P': 60, '3PA': 164, '3P%': 0.366, '2P': 152, '2PA': 264, '2P%': 0.5757575757575758, 'eFG%': 0.5654205607476636, 'FT': 118, 'FTA': 135, 'FT%': 0.874, 'ORB': 48, 'DRB': 188, 'TRB': 236, 'AST': 140, 'STL': 20, 'BLK': 17, 'TOV': 86, 'PF': 111, 'PTS': 602, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 42, 'Losses': 40, 'Player': 'Karl-Anthony Towns', 'Season': '2022-23'}
# Processed data for Devin Booker in season 2022-23: {'Position': 'Guard', 'Age': 26.0, 'Team': 'PHX', 'TeamID': 1610612756, 'Years of Service': 7, 'GP': 53, 'GS': 53, 'MP': 1835.0, 'FG': 527, 'FGA': 1067, 'FG%': 0.494, '3P': 111, '3PA': 316, '3P%': 0.351, '2P': 416, '2PA': 751, '2P%': 0.5539280958721704, 'eFG%': 0.5459231490159325, 'FT': 306, 'FTA': 358, 'FT%': 0.855, 'ORB': 46, 'DRB': 194, 'TRB': 240, 'AST': 293, 'STL': 51, 'BLK': 18, 'TOV': 145, 'PF': 159, 'PTS': 1471, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 45, 'Losses': 37, 'Player': 'Devin Booker', 'Season': '2022-23'}
# Processed data for Kristaps Porzingis in season 2022-23: {'Position': 'Forward-Center', 'Age': 27.0, 'Team': 'WAS', 'TeamID': 1610612764, 'Years of Service': 7, 'GP': 65, 'GS': 65, 'MP': 2120.0, 'FG': 507, 'FGA': 1018, 'FG%': 0.498, '3P': 137, '3PA': 356, '3P%': 0.385, '2P': 370, '2PA': 662, '2P%': 0.5589123867069486, 'eFG%': 0.5653241650294696, 'FT': 354, 'FTA': 416, 'FT%': 0.851, 'ORB': 114, 'DRB': 432, 'TRB': 546, 'AST': 174, 'STL': 58, 'BLK': 100, 'TOV': 137, 'PF': 196, 'PTS': 1505, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 35, 'Losses': 47, 'Player': 'Kristaps Porzingis', 'Season': '2022-23'}
# Processed data for Andrew Wiggins in season 2022-23: {'Position': 'Forward', 'Age': 28.0, 'Team': 'GSW', 'TeamID': 1610612744, 'Years of Service': 8, 'GP': 37, 'GS': 37, 'MP': 1190.0, 'FG': 250, 'FGA': 529, 'FG%': 0.473, '3P': 89, '3PA': 225, '3P%': 0.396, '2P': 161, '2PA': 304, '2P%': 0.5296052631578947, 'eFG%': 0.556710775047259, 'FT': 44, 'FTA': 72, 'FT%': 0.611, 'ORB': 61, 'DRB': 125, 'TRB': 186, 'AST': 85, 'STL': 45, 'BLK': 28, 'TOV': 48, 'PF': 107, 'PTS': 633, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 44, 'Losses': 38, 'Player': 'Andrew Wiggins', 'Season': '2022-23'}
# Processed data for Joel Embiid in season 2022-23: {'Position': 'Center-Forward', 'Age': 29.0, 'Team': 'PHI', 'TeamID': 1610612755, 'Years of Service': 8, 'GP': 66, 'GS': 66, 'MP': 2284.0, 'FG': 728, 'FGA': 1328, 'FG%': 0.548, '3P': 66, '3PA': 200, '3P%': 0.33, '2P': 662, '2PA': 1128, '2P%': 0.5868794326241135, 'eFG%': 0.5730421686746988, 'FT': 661, 'FTA': 771, 'FT%': 0.857, 'ORB': 113, 'DRB': 557, 'TRB': 670, 'AST': 274, 'STL': 66, 'BLK': 112, 'TOV': 226, 'PF': 205, 'PTS': 2183, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 54, 'Losses': 28, 'Player': 'Joel Embiid', 'Season': '2022-23'}
# Processed data for CJ McCollum in season 2022-23: {'Position': 'Guard', 'Age': 31.0, 'Team': 'NOP', 'TeamID': 1610612740, 'Years of Service': 9, 'GP': 75, 'GS': 75, 'MP': 2649.0, 'FG': 587, 'FGA': 1344, 'FG%': 0.437, '3P': 211, '3PA': 543, '3P%': 0.389, '2P': 376, '2PA': 801, '2P%': 0.46941323345817726, 'eFG%': 0.5152529761904762, 'FT': 183, 'FTA': 238, 'FT%': 0.769, 'ORB': 55, 'DRB': 273, 'TRB': 328, 'AST': 429, 'STL': 70, 'BLK': 38, 'TOV': 183, 'PF': 153, 'PTS': 1568, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 42, 'Losses': 40, 'Player': 'CJ McCollum', 'Season': '2022-23'}
# Processed data for Nikola Jokic in season 2022-23: {'Position': 'Center', 'Age': 28.0, 'Team': 'DEN', 'TeamID': 1610612743, 'Years of Service': 8, 'GP': 69, 'GS': 69, 'MP': 2323.0, 'FG': 646, 'FGA': 1022, 'FG%': 0.632, '3P': 57, '3PA': 149, '3P%': 0.383, '2P': 589, '2PA': 873, '2P%': 0.6746849942726232, 'eFG%': 0.6599804305283757, 'FT': 341, 'FTA': 415, 'FT%': 0.822, 'ORB': 167, 'DRB': 650, 'TRB': 817, 'AST': 678, 'STL': 87, 'BLK': 47, 'TOV': 247, 'PF': 174, 'PTS': 1690, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 53, 'Losses': 29, 'Player': 'Nikola Jokic', 'Season': '2022-23'}
# Processed data for James Harden in season 2022-23: {'Position': 'Guard', 'Age': 33.0, 'Team': 'PHI', 'TeamID': 1610612755, 'Years of Service': 13, 'GP': 58, 'GS': 58, 'MP': 2135.0, 'FG': 371, 'FGA': 842, 'FG%': 0.441, '3P': 161, '3PA': 418, '3P%': 0.385, '2P': 210, '2PA': 424, '2P%': 0.49528301886792453, 'eFG%': 0.5362232779097387, 'FT': 313, 'FTA': 361, 'FT%': 0.867, 'ORB': 40, 'DRB': 314, 'TRB': 354, 'AST': 618, 'STL': 71, 'BLK': 31, 'TOV': 195, 'PF': 112, 'PTS': 1216, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 54, 'Losses': 28, 'Player': 'James Harden', 'Season': '2022-23'}
# Processed data for Jamal Murray in season 2022-23: {'Position': 'Guard', 'Age': 26.0, 'Team': 'DEN', 'TeamID': 1610612743, 'Years of Service': 6, 'GP': 65, 'GS': 65, 'MP': 2133.0, 'FG': 473, 'FGA': 1041, 'FG%': 0.454, '3P': 172, '3PA': 432, '3P%': 0.398, '2P': 301, '2PA': 609, '2P%': 0.4942528735632184, 'eFG%': 0.5369836695485111, 'FT': 180, 'FTA': 216, 'FT%': 0.833, 'ORB': 48, 'DRB': 209, 'TRB': 257, 'AST': 400, 'STL': 66, 'BLK': 16, 'TOV': 145, 'PF': 103, 'PTS': 1298, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 53, 'Losses': 29, 'Player': 'Jamal Murray', 'Season': '2022-23'}
# Processed data for Brandon Ingram in season 2022-23: {'Position': 'Forward', 'Age': 25.0, 'Team': 'NOP', 'TeamID': 1610612740, 'Years of Service': 6, 'GP': 45, 'GS': 45, 'MP': 1538.0, 'FG': 404, 'FGA': 835, 'FG%': 0.484, '3P': 64, '3PA': 164, '3P%': 0.39, '2P': 340, '2PA': 671, '2P%': 0.5067064083457526, 'eFG%': 0.5221556886227545, 'FT': 240, 'FTA': 272, 'FT%': 0.882, 'ORB': 23, 'DRB': 223, 'TRB': 246, 'AST': 262, 'STL': 32, 'BLK': 19, 'TOV': 148, 'PF': 116, 'PTS': 1112, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 42, 'Losses': 40, 'Player': 'Brandon Ingram', 'Season': '2022-23'}
# Processed data for D'Angelo Russell in season 2022-23: {'Position': 'Guard', 'Age': 27.0, 'Team': 'MIN', 'TeamID': 1610612747, 'Years of Service': 7, 'GP': 54, 'GS': 54, 'MP': 1778.0, 'FG': 338, 'FGA': 727, 'FG%': 0.465, '3P': 148, '3PA': 379, '3P%': 0.391, '2P': 190, '2PA': 348, '2P%': 0.5459770114942529, 'eFG%': 0.5667125171939478, 'FT': 143, 'FTA': 167, 'FT%': 0.856, 'ORB': 28, 'DRB': 137, 'TRB': 165, 'AST': 334, 'STL': 60, 'BLK': 21, 'TOV': 147, 'PF': 117, 'PTS': 967, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 43, 'Losses': 39, 'Player': "D'Angelo Russell", 'Season': '2022-23'}
# Processed data for Donovan Mitchell in season 2022-23: {'Position': 'Guard', 'Age': 26.0, 'Team': 'CLE', 'TeamID': 1610612739, 'Years of Service': 5, 'GP': 68, 'GS': 68, 'MP': 2432.0, 'FG': 679, 'FGA': 1402, 'FG%': 0.484, '3P': 245, '3PA': 635, '3P%': 0.386, '2P': 434, '2PA': 767, '2P%': 0.5658409387222947, 'eFG%': 0.5716833095577746, 'FT': 319, 'FTA': 368, 'FT%': 0.867, 'ORB': 63, 'DRB': 226, 'TRB': 289, 'AST': 301, 'STL': 99, 'BLK': 27, 'TOV': 180, 'PF': 168, 'PTS': 1922, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 51, 'Losses': 31, 'Player': 'Donovan Mitchell', 'Season': '2022-23'}
# Processed data for Shai Gilgeous-Alexander in season 2022-23: {'Position': 'Guard', 'Age': 24.0, 'Team': 'OKC', 'TeamID': 1610612760, 'Years of Service': 4, 'GP': 68, 'GS': 68, 'MP': 2416.0, 'FG': 704, 'FGA': 1381, 'FG%': 0.51, '3P': 58, '3PA': 168, '3P%': 0.345, '2P': 646, '2PA': 1213, '2P%': 0.5325638911788954, 'eFG%': 0.5307748008689356, 'FT': 669, 'FTA': 739, 'FT%': 0.905, 'ORB': 59, 'DRB': 270, 'TRB': 329, 'AST': 371, 'STL': 112, 'BLK': 65, 'TOV': 192, 'PF': 192, 'PTS': 2135, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 40, 'Losses': 42, 'Player': 'Shai Gilgeous-Alexander', 'Season': '2022-23'}
# Processed data for Deandre Ayton in season 2022-23: {'Position': 'Center', 'Age': 24.0, 'Team': 'PHX', 'TeamID': 1610612756, 'Years of Service': 4, 'GP': 67, 'GS': 67, 'MP': 2035.0, 'FG': 522, 'FGA': 887, 'FG%': 0.589, '3P': 7, '3PA': 24, '3P%': 0.292, '2P': 515, '2PA': 863, '2P%': 0.59675550405562, 'eFG%': 0.5924464487034949, 'FT': 152, 'FTA': 200, 'FT%': 0.76, 'ORB': 172, 'DRB': 495, 'TRB': 667, 'AST': 115, 'STL': 37, 'BLK': 53, 'TOV': 120, 'PF': 190, 'PTS': 1203, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 45, 'Losses': 37, 'Player': 'Deandre Ayton', 'Season': '2022-23'}
# Processed data for Kevin Love in season 2022-23: {'Position': 'Forward-Center', 'Age': 34.0, 'Team': 'CLE', 'TeamID': 1610612748, 'Years of Service': 14, 'GP': 41, 'GS': 3, 'MP': 821.0, 'FG': 111, 'FGA': 285, 'FG%': 0.389, '3P': 69, '3PA': 195, '3P%': 0.354, '2P': 42, '2PA': 90, '2P%': 0.4666666666666667, 'eFG%': 0.5105263157894737, 'FT': 56, 'FTA': 63, 'FT%': 0.889, 'ORB': 42, 'DRB': 238, 'TRB': 280, 'AST': 76, 'STL': 7, 'BLK': 7, 'TOV': 47, 'PF': 65, 'PTS': 347, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 44, 'Losses': 38, 'Player': 'Kevin Love', 'Season': '2022-23'}
# Processed data for Jayson Tatum in season 2022-23: {'Position': 'Forward-Guard', 'Age': 25.0, 'Team': 'BOS', 'TeamID': 1610612738, 'Years of Service': 5, 'GP': 74, 'GS': 74, 'MP': 2732.0, 'FG': 727, 'FGA': 1559, 'FG%': 0.466, '3P': 240, '3PA': 686, '3P%': 0.35, '2P': 487, '2PA': 873, '2P%': 0.5578465063001146, 'eFG%': 0.5432969852469531, 'FT': 531, 'FTA': 622, 'FT%': 0.854, 'ORB': 78, 'DRB': 571, 'TRB': 649, 'AST': 342, 'STL': 78, 'BLK': 51, 'TOV': 213, 'PF': 160, 'PTS': 2225, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 57, 'Losses': 25, 'Player': 'Jayson Tatum', 'Season': '2022-23'}
# Processed data for Bam Adebayo in season 2022-23: {'Position': 'Center-Forward', 'Age': 25.0, 'Team': 'MIA', 'TeamID': 1610612748, 'Years of Service': 5, 'GP': 75, 'GS': 75, 'MP': 2598.0, 'FG': 602, 'FGA': 1114, 'FG%': 0.54, '3P': 1, '3PA': 12, '3P%': 0.083, '2P': 601, '2PA': 1102, '2P%': 0.5453720508166969, 'eFG%': 0.5408438061041293, 'FT': 324, 'FTA': 402, 'FT%': 0.806, 'ORB': 184, 'DRB': 504, 'TRB': 688, 'AST': 240, 'STL': 88, 'BLK': 61, 'TOV': 187, 'PF': 208, 'PTS': 1529, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 44, 'Losses': 38, 'Player': 'Bam Adebayo', 'Season': '2022-23'}
# Processed data for De'Aaron Fox in season 2022-23: {'Position': 'Guard', 'Age': 25.0, 'Team': 'SAC', 'TeamID': 1610612758, 'Years of Service': 5, 'GP': 73, 'GS': 73, 'MP': 2435.0, 'FG': 682, 'FGA': 1331, 'FG%': 0.512, '3P': 119, '3PA': 367, '3P%': 0.324, '2P': 563, '2PA': 964, '2P%': 0.5840248962655602, 'eFG%': 0.5570999248685199, 'FT': 343, 'FTA': 440, 'FT%': 0.78, 'ORB': 40, 'DRB': 266, 'TRB': 306, 'AST': 447, 'STL': 83, 'BLK': 23, 'TOV': 181, 'PF': 172, 'PTS': 1826, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 48, 'Losses': 34, 'Player': "De'Aaron Fox", 'Season': '2022-23'}
# Processed data for Gordon Hayward in season 2022-23: {'Position': 'Forward', 'Age': 33.0, 'Team': 'CHA', 'TeamID': 1610612766, 'Years of Service': 12, 'GP': 50, 'GS': 50, 'MP': 1577.0, 'FG': 276, 'FGA': 581, 'FG%': 0.475, '3P': 52, '3PA': 160, '3P%': 0.325, '2P': 224, '2PA': 421, '2P%': 0.5320665083135392, 'eFG%': 0.5197934595524957, 'FT': 129, 'FTA': 159, 'FT%': 0.811, 'ORB': 33, 'DRB': 182, 'TRB': 215, 'AST': 206, 'STL': 42, 'BLK': 12, 'TOV': 99, 'PF': 70, 'PTS': 733, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 27, 'Losses': 55, 'Player': 'Gordon Hayward', 'Season': '2022-23'}
# Processed data for Jaylen Brown in season 2022-23: {'Position': 'Guard-Forward', 'Age': 26.0, 'Team': 'BOS', 'TeamID': 1610612738, 'Years of Service': 6, 'GP': 67, 'GS': 67, 'MP': 2405.0, 'FG': 679, 'FGA': 1383, 'FG%': 0.491, '3P': 163, '3PA': 487, '3P%': 0.335, '2P': 516, '2PA': 896, '2P%': 0.5758928571428571, 'eFG%': 0.5498915401301518, 'FT': 263, 'FTA': 344, 'FT%': 0.765, 'ORB': 78, 'DRB': 381, 'TRB': 459, 'AST': 232, 'STL': 75, 'BLK': 26, 'TOV': 197, 'PF': 172, 'PTS': 1784, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 57, 'Losses': 25, 'Player': 'Jaylen Brown', 'Season': '2022-23'}
# Processed data for Chris Paul in season 2022-23: {'Position': 'Guard', 'Age': 38.0, 'Team': 'PHX', 'TeamID': 1610612756, 'Years of Service': 17, 'GP': 59, 'GS': 59, 'MP': 1889.0, 'FG': 294, 'FGA': 668, 'FG%': 0.44, '3P': 98, '3PA': 261, '3P%': 0.375, '2P': 196, '2PA': 407, '2P%': 0.48157248157248156, 'eFG%': 0.5134730538922155, 'FT': 133, 'FTA': 160, 'FT%': 0.831, 'ORB': 27, 'DRB': 224, 'TRB': 251, 'AST': 524, 'STL': 91, 'BLK': 22, 'TOV': 114, 'PF': 126, 'PTS': 819, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 45, 'Losses': 37, 'Player': 'Chris Paul', 'Season': '2022-23'}
# Processed data for Kyle Lowry in season 2022-23: {'Position': 'Guard', 'Age': 37.0, 'Team': 'MIA', 'TeamID': 1610612748, 'Years of Service': 16, 'GP': 55, 'GS': 44, 'MP': 1718.0, 'FG': 196, 'FGA': 485, 'FG%': 0.404, '3P': 107, '3PA': 310, '3P%': 0.345, '2P': 89, '2PA': 175, '2P%': 0.5085714285714286, 'eFG%': 0.5144329896907216, 'FT': 116, 'FTA': 135, 'FT%': 0.859, 'ORB': 43, 'DRB': 182, 'TRB': 225, 'AST': 281, 'STL': 57, 'BLK': 21, 'TOV': 103, 'PF': 143, 'PTS': 615, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 44, 'Losses': 38, 'Player': 'Kyle Lowry', 'Season': '2022-23'}
# Processed data for Jalen Brunson in season 2022-23: {'Position': 'Guard', 'Age': 26.0, 'Team': 'NYK', 'TeamID': 1610612752, 'Years of Service': 4, 'GP': 68, 'GS': 68, 'MP': 2379.0, 'FG': 587, 'FGA': 1195, 'FG%': 0.491, '3P': 134, '3PA': 322, '3P%': 0.416, '2P': 453, '2PA': 873, '2P%': 0.5189003436426117, 'eFG%': 0.5472803347280335, 'FT': 325, 'FTA': 392, 'FT%': 0.829, 'ORB': 40, 'DRB': 201, 'TRB': 241, 'AST': 421, 'STL': 61, 'BLK': 15, 'TOV': 142, 'PF': 152, 'PTS': 1633, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 47, 'Losses': 35, 'Player': 'Jalen Brunson', 'Season': '2022-23'}
# Processed data for DeMar DeRozan in season 2022-23: {'Position': 'Guard-Forward', 'Age': 33.0, 'Team': 'CHI', 'TeamID': 1610612741, 'Years of Service': 13, 'GP': 74, 'GS': 74, 'MP': 2682.0, 'FG': 657, 'FGA': 1303, 'FG%': 0.504, '3P': 46, '3PA': 142, '3P%': 0.324, '2P': 611, '2PA': 1161, '2P%': 0.5262704565030146, 'eFG%': 0.5218726016884113, 'FT': 456, 'FTA': 523, 'FT%': 0.872, 'ORB': 34, 'DRB': 309, 'TRB': 343, 'AST': 377, 'STL': 83, 'BLK': 36, 'TOV': 153, 'PF': 186, 'PTS': 1816, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 40, 'Losses': 42, 'Player': 'DeMar DeRozan', 'Season': '2022-23'}
# Processed data for Al Horford in season 2022-23: {'Position': 'Center-Forward', 'Age': 37.0, 'Team': 'BOS', 'TeamID': 1610612738, 'Years of Service': 15, 'GP': 63, 'GS': 63, 'MP': 1921.0, 'FG': 228, 'FGA': 479, 'FG%': 0.476, '3P': 145, '3PA': 325, '3P%': 0.446, '2P': 83, '2PA': 154, '2P%': 0.538961038961039, 'eFG%': 0.627348643006263, 'FT': 15, 'FTA': 21, 'FT%': 0.714, 'ORB': 73, 'DRB': 317, 'TRB': 390, 'AST': 189, 'STL': 30, 'BLK': 61, 'TOV': 37, 'PF': 121, 'PTS': 616, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 57, 'Losses': 25, 'Player': 'Al Horford', 'Season': '2022-23'}
# Processed data for Draymond Green in season 2022-23: {'Position': 'Forward', 'Age': 33.0, 'Team': 'GSW', 'TeamID': 1610612744, 'Years of Service': 10, 'GP': 73, 'GS': 73, 'MP': 2298.0, 'FG': 250, 'FGA': 474, 'FG%': 0.527, '3P': 40, '3PA': 131, '3P%': 0.305, '2P': 210, '2PA': 343, '2P%': 0.6122448979591837, 'eFG%': 0.569620253164557, 'FT': 77, 'FTA': 108, 'FT%': 0.713, 'ORB': 66, 'DRB': 459, 'TRB': 525, 'AST': 500, 'STL': 74, 'BLK': 60, 'TOV': 204, 'PF': 229, 'PTS': 617, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 44, 'Losses': 38, 'Player': 'Draymond Green', 'Season': '2022-23'}
# Processed data for Julius Randle in season 2022-23: {'Position': 'Forward-Center', 'Age': 28.0, 'Team': 'NYK', 'TeamID': 1610612752, 'Years of Service': 8, 'GP': 77, 'GS': 77, 'MP': 2737.0, 'FG': 658, 'FGA': 1432, 'FG%': 0.459, '3P': 218, '3PA': 636, '3P%': 0.343, '2P': 440, '2PA': 796, '2P%': 0.5527638190954773, 'eFG%': 0.5356145251396648, 'FT': 402, 'FTA': 531, 'FT%': 0.757, 'ORB': 141, 'DRB': 626, 'TRB': 767, 'AST': 316, 'STL': 49, 'BLK': 21, 'TOV': 216, 'PF': 233, 'PTS': 1936, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 47, 'Losses': 35, 'Player': 'Julius Randle', 'Season': '2022-23'}
# Processed data for John Collins in season 2022-23: {'Position': 'Forward-Center', 'Age': 25.0, 'Team': 'ATL', 'TeamID': 1610612737, 'Years of Service': 5, 'GP': 71, 'GS': 71, 'MP': 2130.0, 'FG': 359, 'FGA': 707, 'FG%': 0.508, '3P': 70, '3PA': 240, '3P%': 0.292, '2P': 289, '2PA': 467, '2P%': 0.6188436830835118, 'eFG%': 0.5572842998585573, 'FT': 143, 'FTA': 178, 'FT%': 0.803, 'ORB': 77, 'DRB': 385, 'TRB': 462, 'AST': 85, 'STL': 42, 'BLK': 73, 'TOV': 79, 'PF': 220, 'PTS': 931, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 41, 'Losses': 41, 'Player': 'John Collins', 'Season': '2022-23'}
# Processed data for Mike Conley in season 2022-23: {'Position': 'Guard', 'Age': 35.0, 'Team': 'UTA', 'TeamID': 1610612750, 'Years of Service': 15, 'GP': 43, 'GS': 42, 'MP': 1275.0, 'FG': 153, 'FGA': 375, 'FG%': 0.408, '3P': 77, '3PA': 213, '3P%': 0.362, '2P': 76, '2PA': 162, '2P%': 0.4691358024691358, 'eFG%': 0.5106666666666667, 'FT': 78, 'FTA': 96, 'FT%': 0.813, 'ORB': 17, 'DRB': 90, 'TRB': 107, 'AST': 330, 'STL': 44, 'BLK': 10, 'TOV': 74, 'PF': 94, 'PTS': 461, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 42, 'Losses': 40, 'Player': 'Mike Conley', 'Season': '2022-23'}
# Processed data for Malcolm Brogdon in season 2022-23: {'Position': 'Guard', 'Age': 30.0, 'Team': 'BOS', 'TeamID': 1610612738, 'Years of Service': 6, 'GP': 67, 'GS': 0, 'MP': 1744.0, 'FG': 354, 'FGA': 732, 'FG%': 0.484, '3P': 132, '3PA': 297, '3P%': 0.444, '2P': 222, '2PA': 435, '2P%': 0.5103448275862069, 'eFG%': 0.5737704918032787, 'FT': 160, 'FTA': 184, 'FT%': 0.87, 'ORB': 42, 'DRB': 238, 'TRB': 280, 'AST': 248, 'STL': 45, 'BLK': 18, 'TOV': 98, 'PF': 109, 'PTS': 1000, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 57, 'Losses': 25, 'Player': 'Malcolm Brogdon', 'Season': '2022-23'}
# Processed data for Anfernee Simons in season 2022-23: {'Position': 'Guard', 'Age': 24.0, 'Team': 'POR', 'TeamID': 1610612757, 'Years of Service': 4, 'GP': 62, 'GS': 62, 'MP': 2171.0, 'FG': 467, 'FGA': 1045, 'FG%': 0.447, '3P': 212, '3PA': 562, '3P%': 0.377, '2P': 255, '2PA': 483, '2P%': 0.5279503105590062, 'eFG%': 0.5483253588516747, 'FT': 160, 'FTA': 179, 'FT%': 0.894, 'ORB': 18, 'DRB': 143, 'TRB': 161, 'AST': 253, 'STL': 42, 'BLK': 14, 'TOV': 128, 'PF': 142, 'PTS': 1306, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 33, 'Losses': 49, 'Player': 'Anfernee Simons', 'Season': '2022-23'}
# Processed data for Nikola Vucevic in season 2022-23: {'Position': 'Center', 'Age': 32.0, 'Team': 'CHI', 'TeamID': 1610612741, 'Years of Service': 11, 'GP': 82, 'GS': 82, 'MP': 2746.0, 'FG': 597, 'FGA': 1148, 'FG%': 0.52, '3P': 121, '3PA': 347, '3P%': 0.349, '2P': 476, '2PA': 801, '2P%': 0.5942571785268415, 'eFG%': 0.5727351916376306, 'FT': 132, 'FTA': 158, 'FT%': 0.835, 'ORB': 159, 'DRB': 744, 'TRB': 903, 'AST': 265, 'STL': 60, 'BLK': 57, 'TOV': 139, 'PF': 179, 'PTS': 1447, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 40, 'Losses': 42, 'Player': 'Nikola Vucevic', 'Season': '2022-23'}
# Processed data for Terry Rozier in season 2022-23: {'Position': 'Guard', 'Age': 29.0, 'Team': 'CHA', 'TeamID': 1610612766, 'Years of Service': 7, 'GP': 63, 'GS': 63, 'MP': 2221.0, 'FG': 493, 'FGA': 1188, 'FG%': 0.415, '3P': 165, '3PA': 505, '3P%': 0.327, '2P': 328, '2PA': 683, '2P%': 0.4802342606149341, 'eFG%': 0.48442760942760943, 'FT': 178, 'FTA': 220, 'FT%': 0.809, 'ORB': 51, 'DRB': 208, 'TRB': 259, 'AST': 319, 'STL': 74, 'BLK': 16, 'TOV': 134, 'PF': 119, 'PTS': 1329, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 27, 'Losses': 55, 'Player': 'Terry Rozier', 'Season': '2022-23'}
# Processed data for Fred VanVleet in season 2022-23: {'Position': 'Guard', 'Age': 29.0, 'Team': 'TOR', 'TeamID': 1610612761, 'Years of Service': 6, 'GP': 69, 'GS': 69, 'MP': 2535.0, 'FG': 437, 'FGA': 1112, 'FG%': 0.393, '3P': 207, '3PA': 606, '3P%': 0.342, '2P': 230, '2PA': 506, '2P%': 0.45454545454545453, 'eFG%': 0.48606115107913667, 'FT': 254, 'FTA': 283, 'FT%': 0.898, 'ORB': 30, 'DRB': 250, 'TRB': 280, 'AST': 495, 'STL': 123, 'BLK': 38, 'TOV': 140, 'PF': 193, 'PTS': 1335, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 41, 'Losses': 41, 'Player': 'Fred VanVleet', 'Season': '2022-23'}
# ...
# Unable to fetch complete data for Justin Lewis
# Processed data for Jamaree Bouyea in season 2023-24: {'Position': 'Guard', 'Age': 25.0, 'Team': 'POR', 'TeamID': 1610612759, 'Years of Service': 1, 'GP': 6, 'GS': 0, 'MP': 57.0, 'FG': 5, 'FGA': 21, 'FG%': 0.238, '3P': 0, '3PA': 8, '3P%': 0.0, '2P': 5, '2PA': 13, '2P%': 0.38461538461538464, 'eFG%': 0.23809523809523808, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 2, 'DRB': 8, 'TRB': 10, 'AST': 8, 'STL': 0, 'BLK': 0, 'TOV': 8, 'PF': 3, 'PTS': 10, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 22, 'Losses': 60, 'Player': 'Jamaree Bouyea', 'Season': '2023-24'}
# Processed data for Pat Spencer in season 2023-24: {'Position': 'Guard', 'Age': 27.0, 'Team': 'GSW', 'TeamID': 1610612744, 'Years of Service': 0, 'GP': 6, 'GS': 0, 'MP': 26.0, 'FG': 2, 'FGA': 4, 'FG%': 0.5, '3P': 0, '3PA': 2, '3P%': 0.0, '2P': 2, '2PA': 2, '2P%': 1.0, 'eFG%': 0.5, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 2, 'DRB': 2, 'TRB': 4, 'AST': 5, 'STL': 0, 'BLK': 0, 'TOV': 1, 'PF': 1, 'PTS': 4, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 46, 'Losses': 36, 'Player': 'Pat Spencer', 'Season': '2023-24'}
# Processed data for Buddy Boeheim in season 2023-24: {'Position': 'Forward', 'Age': 24.0, 'Team': 'DET', 'TeamID': 1610612765, 'Years of Service': 1, 'GP': 10, 'GS': 0, 'MP': 84.0, 'FG': 9, 'FGA': 29, 'FG%': 0.31, '3P': 8, '3PA': 25, '3P%': 0.32, '2P': 1, '2PA': 4, '2P%': 0.25, 'eFG%': 0.4482758620689655, 'FT': 8, 'FTA': 10, 'FT%': 0.8, 'ORB': 3, 'DRB': 7, 'TRB': 10, 'AST': 3, 'STL': 0, 'BLK': 1, 'TOV': 0, 'PF': 5, 'PTS': 34, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 14, 'Losses': 68, 'Player': 'Buddy Boeheim', 'Season': '2023-24'}
# No stats found for Justise Winslow in season 2023-24
# No stats found for Nathan Knight in season 2023-24
# Processed data for Andrew Funk in season 2023-24: {'Position': 'Guard', 'Age': 24.0, 'Team': 'CHI', 'TeamID': 1610612741, 'Years of Service': 0, 'GP': 5, 'GS': 0, 'MP': 13.0, 'FG': 0, 'FGA': 4, 'FG%': 0.0, '3P': 0, '3PA': 3, '3P%': 0.0, '2P': 0, '2PA': 1, '2P%': 0.0, 'eFG%': 0.0, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 0, 'DRB': 0, 'TRB': 0, 'AST': 0, 'STL': 1, 'BLK': 1, 'TOV': 0, 'PF': 0, 'PTS': 0, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 39, 'Losses': 43, 'Player': 'Andrew Funk', 'Season': '2023-24'}
# Processed data for Shaquille Harrison in season 2023-24: {'Position': 'Guard', 'Age': 30.0, 'Team': 'MEM', 'TeamID': 0, 'Years of Service': 6, 'GP': 3, 'GS': 0, 'MP': 6.0, 'FG': 1, 'FGA': 2, 'FG%': 0.5, '3P': 0, '3PA': 0, '3P%': 0.0, '2P': 1, '2PA': 2, '2P%': 0.5, 'eFG%': 0.5, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 0, 'DRB': 2, 'TRB': 2, 'AST': 0, 'STL': 0, 'BLK': 1, 'TOV': 0, 'PF': 0, 'PTS': 2, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Shaquille Harrison', 'Season': '2023-24'}
# Processed data for Justin Jackson in season 2023-24: {'Position': 'Forward', 'Age': 29.0, 'Team': 'MIN', 'TeamID': 0, 'Years of Service': 6, 'GP': 2, 'GS': 0, 'MP': 1.0, 'FG': 0, 'FGA': 0, 'FG%': 0.0, '3P': 0, '3PA': 0, '3P%': 0.0, '2P': 0, '2PA': 0, '2P%': 0, 'eFG%': 0, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 0, 'DRB': 0, 'TRB': 0, 'AST': 0, 'STL': 0, 'BLK': 0, 'TOV': 0, 'PF': 0, 'PTS': 0, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Justin Jackson', 'Season': '2023-24'}
# Unable to fetch complete data for Jaylin Galloway
# Processed data for RaiQuan Gray in season 2023-24: {'Position': 'Forward', 'Age': 24.0, 'Team': 'SAS', 'TeamID': 1610612759, 'Years of Service': 2, 'GP': 3, 'GS': 0, 'MP': 39.0, 'FG': 10, 'FGA': 17, 'FG%': 0.588, '3P': 3, '3PA': 7, '3P%': 0.429, '2P': 7, '2PA': 10, '2P%': 0.7, 'eFG%': 0.6764705882352942, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 2, 'DRB': 5, 'TRB': 7, 'AST': 6, 'STL': 1, 'BLK': 1, 'TOV': 1, 'PF': 0, 'PTS': 23, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 22, 'Losses': 60, 'Player': 'RaiQuan Gray', 'Season': '2023-24'}
# Processed data for Quenton Jackson in season 2023-24: {'Position': 'Guard', 'Age': 25.0, 'Team': 'IND', 'TeamID': 1610612754, 'Years of Service': 1, 'GP': 3, 'GS': 0, 'MP': 11.0, 'FG': 0, 'FGA': 1, 'FG%': 0.0, '3P': 0, '3PA': 0, '3P%': 0.0, '2P': 0, '2PA': 1, '2P%': 0.0, 'eFG%': 0.0, 'FT': 2, 'FTA': 2, 'FT%': 1.0, 'ORB': 0, 'DRB': 4, 'TRB': 4, 'AST': 2, 'STL': 1, 'BLK': 0, 'TOV': 0, 'PF': 1, 'PTS': 2, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 47, 'Losses': 35, 'Player': 'Quenton Jackson', 'Season': '2023-24'}
# Processed data for Hamidou Diallo in season 2023-24: {'Position': 'Guard', 'Age': 25.0, 'Team': 'WAS', 'TeamID': 0, 'Years of Service': 5, 'GP': 2, 'GS': 0, 'MP': 5.0, 'FG': 1, 'FGA': 2, 'FG%': 0.5, '3P': 0, '3PA': 0, '3P%': 0.0, '2P': 1, '2PA': 2, '2P%': 0.5, 'eFG%': 0.5, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 2, 'DRB': 0, 'TRB': 2, 'AST': 1, 'STL': 2, 'BLK': 0, 'TOV': 1, 'PF': 1, 'PTS': 2, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Hamidou Diallo', 'Season': '2023-24'}
# Processed data for Maozinha Pereira in season 2023-24: {'Position': 'Forward', 'Age': 23.0, 'Team': 'MEM', 'TeamID': 0, 'Years of Service': 0, 'GP': 7, 'GS': 1, 'MP': 122.0, 'FG': 18, 'FGA': 35, 'FG%': 0.514, '3P': 5, '3PA': 13, '3P%': 0.385, '2P': 13, '2PA': 22, '2P%': 0.5909090909090909, 'eFG%': 0.5857142857142857, 'FT': 7, 'FTA': 10, 'FT%': 0.7, 'ORB': 11, 'DRB': 26, 'TRB': 37, 'AST': 2, 'STL': 6, 'BLK': 4, 'TOV': 5, 'PF': 10, 'PTS': 48, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Maozinha Pereira', 'Season': '2023-24'}
# Processed data for Wenyen Gabriel in season 2023-24: {'Position': 'Forward', 'Age': 27.0, 'Team': 'MEM', 'TeamID': 0, 'Years of Service': 5, 'GP': 5, 'GS': 0, 'MP': 81.0, 'FG': 8, 'FGA': 22, 'FG%': 0.364, '3P': 1, '3PA': 6, '3P%': 0.167, '2P': 7, '2PA': 16, '2P%': 0.4375, 'eFG%': 0.38636363636363635, 'FT': 0, 'FTA': 5, 'FT%': 0.0, 'ORB': 7, 'DRB': 18, 'TRB': 25, 'AST': 3, 'STL': 2, 'BLK': 2, 'TOV': 8, 'PF': 10, 'PTS': 17, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Wenyen Gabriel', 'Season': '2023-24'}
# Processed data for Kobi Simmons in season 2023-24: {'Position': 'Guard', 'Age': 26.0, 'Team': 'TOR', 'TeamID': 0, 'Years of Service': 6, 'GP': 4, 'GS': 0, 'MP': 67.0, 'FG': 9, 'FGA': 21, 'FG%': 0.429, '3P': 2, '3PA': 8, '3P%': 0.25, '2P': 7, '2PA': 13, '2P%': 0.5384615384615384, 'eFG%': 0.47619047619047616, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 1, 'DRB': 6, 'TRB': 7, 'AST': 12, 'STL': 6, 'BLK': 2, 'TOV': 1, 'PF': 5, 'PTS': 20, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Kobi Simmons', 'Season': '2023-24'}
# No stats found for Zhaire Smith in season 2023-24
# No stats found for Sharife Cooper in season 2023-24
# No stats found for Demetrius Jackson in season 2023-24
# Processed data for Malik Williams in season 2023-24: {'Position': 'Center', 'Age': 25.0, 'Team': 'TOR', 'TeamID': 1610612761, 'Years of Service': 0, 'GP': 7, 'GS': 2, 'MP': 107.0, 'FG': 9, 'FGA': 34, 'FG%': 0.265, '3P': 1, '3PA': 5, '3P%': 0.2, '2P': 8, '2PA': 29, '2P%': 0.27586206896551724, 'eFG%': 0.27941176470588236, 'FT': 0, 'FTA': 2, 'FT%': 0.0, 'ORB': 15, 'DRB': 23, 'TRB': 38, 'AST': 2, 'STL': 3, 'BLK': 4, 'TOV': 3, 'PF': 15, 'PTS': 19, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Wins': 25, 'Losses': 57, 'Player': 'Malik Williams', 'Season': '2023-24'}
# Processed data for Taze Moore in season 2023-24: {'Position': 'Guard', 'Age': 26.0, 'Team': 'POR', 'TeamID': 0, 'Years of Service': 0, 'GP': 4, 'GS': 0, 'MP': 40.0, 'FG': 8, 'FGA': 19, 'FG%': 0.421, '3P': 1, '3PA': 7, '3P%': 0.143, '2P': 7, '2PA': 12, '2P%': 0.5833333333333334, 'eFG%': 0.4473684210526316, 'FT': 1, 'FTA': 2, 'FT%': 0.5, 'ORB': 4, 'DRB': 4, 'TRB': 8, 'AST': 5, 'STL': 2, 'BLK': 0, 'TOV': 3, 'PF': 4, 'PTS': 18, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Taze Moore', 'Season': '2023-24'}
# Processed data for Timmy Allen in season 2023-24: {'Position': 'Forward', 'Age': 24.0, 'Team': 'MEM', 'TeamID': 0, 'Years of Service': 0, 'GP': 5, 'GS': 0, 'MP': 125.0, 'FG': 6, 'FGA': 23, 'FG%': 0.261, '3P': 0, '3PA': 7, '3P%': 0.0, '2P': 6, '2PA': 16, '2P%': 0.375, 'eFG%': 0.2608695652173913, 'FT': 1, 'FTA': 2, 'FT%': 0.5, 'ORB': 4, 'DRB': 13, 'TRB': 17, 'AST': 5, 'STL': 4, 'BLK': 0, 'TOV': 2, 'PF': 18, 'PTS': 13, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Timmy Allen', 'Season': '2023-24'}
# Processed data for Jalen Crutcher in season 2023-24: {'Position': 'Guard', 'Age': 24.0, 'Team': 'NOP', 'TeamID': 0, 'Years of Service': 0, 'GP': 1, 'GS': 0, 'MP': 3.0, 'FG': 0, 'FGA': 1, 'FG%': 0.0, '3P': 0, '3PA': 0, '3P%': 0.0, '2P': 0, '2PA': 1, '2P%': 0.0, 'eFG%': 0.0, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 0, 'DRB': 0, 'TRB': 0, 'AST': 0, 'STL': 0, 'BLK': 0, 'TOV': 0, 'PF': 0, 'PTS': 0, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Jalen Crutcher', 'Season': '2023-24'}
# Processed data for Izaiah Brockington in season 2023-24: {'Position': 'Guard', 'Age': 24.0, 'Team': 'NOP', 'TeamID': 0, 'Years of Service': 0, 'GP': 1, 'GS': 0, 'MP': 3.0, 'FG': 2, 'FGA': 5, 'FG%': 0.4, '3P': 0, '3PA': 1, '3P%': 0.0, '2P': 2, '2PA': 4, '2P%': 0.5, 'eFG%': 0.4, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 1, 'DRB': 1, 'TRB': 2, 'AST': 0, 'STL': 0, 'BLK': 0, 'TOV': 0, 'PF': 0, 'PTS': 4, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Izaiah Brockington', 'Season': '2023-24'}
# Unable to fetch complete data for Taevion Kinsey
# No stats found for Edmond Sumner in season 2023-24
# Processed data for Kaiser Gates in season 2023-24: {'Position': 'Forward', 'Age': 27.0, 'Team': 'NOP', 'TeamID': 0, 'Years of Service': 5, 'GP': 1, 'GS': 0, 'MP': 7.0, 'FG': 0, 'FGA': 4, 'FG%': 0.0, '3P': 0, '3PA': 2, '3P%': 0.0, '2P': 0, '2PA': 2, '2P%': 0.0, 'eFG%': 0.0, 'FT': 0, 'FTA': 0, 'FT%': 0.0, 'ORB': 0, 'DRB': 1, 'TRB': 1, 'AST': 0, 'STL': 0, 'BLK': 0, 'TOV': 0, 'PF': 0, 'PTS': 0, 'PER': None, 'TS%': None, 'ORB%': None, 'DRB%': None, 'TRB%': None, 'AST%': None, 'STL%': None, 'BLK%': None, 'TOV%': None, 'USG%': None, 'OWS': None, 'DWS': None, 'WS': None, 'WS/48': None, 'OBPM': None, 'DBPM': None, 'BPM': None, 'VORP': None, 'Player': 'Kaiser Gates', 'Season': '2023-24'}
# No existing data found at . Starting with an empty DataFrame.
# Updated data with shape: (931, 63)
# New data retrieved. Processing and saving...
# Fetching salary cap data...
# Salary cap data successfully retrieved.
# Salary cap data saved to ../data/processed/salary_cap_history_inflated.csv
# Merging salary cap data with player data...
# Final data shape: (931, 67)
# Final data columns: Index(['Season', 'Player', 'Salary', 'GP', 'PTS', 'TRB', 'AST', 'Injured',
#        'Injury_Periods', 'Position', 'Age', 'Team', 'TeamID',
#        'Years of Service', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%',
#        '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'STL',
#        'BLK', 'TOV', 'PF', 'Wins', 'Losses', 'Salary Cap', 'Luxury Tax',
#        '1st Apron', 'BAE', 'Standard /Non-Taxpayer', 'Taxpayer',
#        'Team Room /Under Cap', 'Salary_Cap_Inflated', 'PER', 'TS%', 'ORB%',
#        'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS',
#        'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP', '', 'Mid-Level Exception',
#        'Season_cap', '2nd Apron'],
#       dtype='object')
# Updated and cleaned data saved to ../data/processed/nba_player_data_final_inflated.csv
#
# Data summary
#  Season        Player   Salary  GP  PTS  TRB  AST  PER  WS  VORP  Injured                                                            Injury_Periods      FG%      3P%      FT%  Salary Cap  Salary_Cap_Inflated
# 2019-20  LeBron James 37436858  67 1698  525  684 25.5 9.8   6.1     True                          2019-12-22 - 2020-01-11; 2020-02-27 - 2020-08-06 0.493477 0.348235 0.692913 109140000.0         1.249345e+08
# 2019-20 Stephen Curry 40231758   5  104   26   33 21.7 0.3   0.2     True                                                   2019-11-01 - 2020-03-07 0.402439 0.244898 1.000000 109140000.0         1.249345e+08
# 2020-21  LeBron James 39219566  45 1126  346  350 24.2 5.6   3.8     True                             2021-03-03 - 2021-03-21; 2021-05-03 - ongoing 0.512758 0.364912 0.698039 109140000.0         1.234119e+08
# 2020-21 Stephen Curry 43006362  63 2015  345  363 26.3 9.0   5.8     True                                                      2021-03-23 - ongoing 0.482051 0.420724 0.916456 109140000.0         1.234119e+08
# 2021-22  LeBron James 41180544  56 1695  459  349 26.2 7.5   5.1     True 2021-11-04 - 2021-11-30; 2022-01-27 - 2022-03-23; 2022-03-29 - 2022-04-03 0.524161 0.359375 0.755952 112414000.0         1.214102e+08
