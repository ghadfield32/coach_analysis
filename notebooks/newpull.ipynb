# %%
# %%writefile ../src/utils/fetch_utils.py

import time
import pandas as pd
from nba_api.stats.endpoints import commonallplayers, commonplayerinfo, leaguedashplayerstats, leaguestandings, playercareerstats
from requests.exceptions import RequestException
from json.decoder import JSONDecodeError

# Define constants for rate limiting
MAX_REQUESTS_PER_MINUTE = 30
DELAY_BETWEEN_REQUESTS = 2  # in seconds

def fetch_with_retry(endpoint, max_retries=3, delay=5, timeout=60, **kwargs):
    """
    Fetch data from an NBA API endpoint with retries in case of failures.
    """
    for attempt in range(max_retries):
        try:
            print(f"Attempting to fetch data using {endpoint.__name__} (Attempt {attempt + 1}) with parameters {kwargs}")
            data = endpoint(**kwargs, timeout=timeout).get_data_frames()
            return data
        except (RequestException, JSONDecodeError, KeyError) as e:
            print(f"Error occurred: {e}")
            if attempt == max_retries - 1:
                print(f"Failed to fetch data after {max_retries} attempts: {str(e)}")
                return None
            print(f"Attempt {attempt + 1} failed. Retrying in {delay} seconds...")
            time.sleep(delay)

def fetch_all_players(season, player_filter=None):
    """
    Fetch all players' IDs, team IDs, and years of service for a given season.
    If player_filter is provided, fetch data only for that player.
    """
    print(f"Fetching all players for season: {season} with filter: {player_filter}")
    all_players_data = fetch_with_retry(commonallplayers.CommonAllPlayers, season=season, is_only_current_season=1)
    all_players = {}
    if all_players_data:
        print(f"Fetched {len(all_players_data[0])} players")
        for _, row in all_players_data[0].iterrows():
            player_name = row['DISPLAY_FIRST_LAST'].strip().lower()
            if player_filter and player_filter.lower() not in player_name:
                continue
            
            player_id = row['PERSON_ID']
            team_id = row['TEAM_ID']
            print(f"Processing player: {player_name}, ID: {player_id}, Team ID: {team_id}")
            
            # Fetch player info to get years of service
            player_info = fetch_with_retry(commonplayerinfo.CommonPlayerInfo, player_id=player_id)
            years_of_service = 0
            if player_info:
                years_of_service = player_info[0]['SEASON_EXP'].iloc[0]
                print(f"Years of service for player {player_name}: {years_of_service}")
            
            all_players[player_name] = {
                'player_id': player_id,
                'team_id': team_id,
                'years_of_service': years_of_service
            }
    
    return all_players

def fetch_league_standings(season):
    """
    Fetch league standings for a given season.
    """
    standings_data = fetch_with_retry(leaguestandings.LeagueStandings, season=season)
    if standings_data is None or not standings_data:
        return pd.DataFrame()  # Return an empty DataFrame if fetching fails
    return standings_data[0]

def fetch_player_stats(season):
    """
    Fetch player statistics for a given season.
    """
    player_stats = fetch_with_retry(leaguedashplayerstats.LeagueDashPlayerStats, season=season, season_type_all_star='Regular Season', per_mode_detailed='PerGame')
    return player_stats[0] if player_stats else None

# %%
# Sample script to fetch and display data from NBA API endpoints

from nba_api.stats.endpoints import commonallplayers, commonplayerinfo, leaguedashplayerstats, leaguestandings, playercareerstats
import pandas as pd

def fetch_with_retry(endpoint, max_retries=3, delay=5, timeout=60, **kwargs):
    """
    Fetch data from an NBA API endpoint with retries in case of failures.
    """
    for attempt in range(max_retries):
        try:
            print(f"Attempting to fetch data using {endpoint.__name__} (Attempt {attempt + 1}) with parameters {kwargs}")
            data = endpoint(**kwargs, timeout=timeout).get_data_frames()
            return data
        except (RequestException, JSONDecodeError, KeyError) as e:
            print(f"Error occurred: {e}")
            if attempt == max_retries - 1:
                print(f"Failed to fetch data after {max_retries} attempts: {str(e)}")
                return None
            print(f"Attempt {attempt + 1} failed. Retrying in {delay} seconds...")
            time.sleep(delay)

# Fetch all players
season = '2022-23'
all_players_data = fetch_with_retry(commonallplayers.CommonAllPlayers, season=season, is_only_current_season=1)
if all_players_data:
    print("Sample data from CommonAllPlayers:")
    print(all_players_data[0].head())

# Fetch player info for a specific player
player_id = 1628977  # Example player ID (Hamidou Diallo)
player_info = fetch_with_retry(commonplayerinfo.CommonPlayerInfo, player_id=player_id)
if player_info:
    print("Sample data from CommonPlayerInfo:")
    print(player_info[0].head())

# Fetch player statistics for the season
player_stats = fetch_with_retry(leaguedashplayerstats.LeagueDashPlayerStats, season=season, season_type_all_star='Regular Season', per_mode_detailed='PerGame')
if player_stats:
    print("Sample data from LeagueDashPlayerStats:")
    print(player_stats[0].head())

# Fetch league standings for the season
league_standings = fetch_with_retry(leaguestandings.LeagueStandings, season=season)
if league_standings:
    print("Sample data from LeagueStandings:")
    print(league_standings[0].head())

# Fetch career stats for a specific player
career_stats = fetch_with_retry(playercareerstats.PlayerCareerStats, player_id=player_id)
if career_stats:
    print("Sample data from PlayerCareerStats:")
    print(career_stats[0].head())
# Out:
# Attempting to fetch data using CommonAllPlayers (Attempt 1) with parameters {'season': '2022-23', 'is_only_current_season': 1}
# Sample data from CommonAllPlayers:
#    PERSON_ID DISPLAY_LAST_COMMA_FIRST DISPLAY_FIRST_LAST  ROSTERSTATUS  \
# 0     203500            Adams, Steven       Steven Adams             1
# 1     201571           Augustin, D.J.      D.J. Augustin             1
# 2     203115             Barton, Will        Will Barton             1
# 3     203920              Birch, Khem         Khem Birch             1
# 4    1630195         Bolmaro, Leandro    Leandro Bolmaro             0
#
#   FROM_YEAR TO_YEAR       PLAYERCODE      PLAYER_SLUG     TEAM_ID  \
# 0      2013    2024     steven_adams     steven_adams  1610612763
# 1      2008    2022    d.j._augustin      dj_augustin  1610612745
# 2      2012    2022      will_barton      will_barton  1610612761
# 3      2017    2022       khem_birch       khem_birch  1610612759
# 4      2021    2022  leandro_bolmaro  leandro_bolmaro           0
#
#      TEAM_CITY  TEAM_NAME TEAM_ABBREVIATION  TEAM_SLUG  TEAM_CODE  \
# 0      Memphis  Grizzlies               MEM  grizzlies  grizzlies
# 1      Houston    Rockets               HOU    rockets    rockets
# 2      Toronto    Raptors               TOR    raptors    raptors
# 3  San Antonio      Spurs               SAS      spurs      spurs
# 4                                                 None
#
#   GAMES_PLAYED_FLAG OTHERLEAGUE_EXPERIENCE_CH
# 0                 Y                        00
# 1                 Y                        00
# 2                 Y                        01
# 3                 Y                        01
# 4                 Y                        11
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628977}
# Sample data from CommonPlayerInfo:
#    PERSON_ID FIRST_NAME LAST_NAME DISPLAY_FIRST_LAST DISPLAY_LAST_COMMA_FIRST  \
# 0    1628977    Hamidou    Diallo     Hamidou Diallo          Diallo, Hamidou
#
#   DISPLAY_FI_LAST     PLAYER_SLUG            BIRTHDATE    SCHOOL COUNTRY  ...  \
# 0       H. Diallo  hamidou-diallo  1998-07-31T00:00:00  Kentucky     USA  ...
#
#        PLAYERCODE FROM_YEAR TO_YEAR  DLEAGUE_FLAG NBA_FLAG GAMES_PLAYED_FLAG  \
# 0  hamidou_diallo      2018    2023             Y        Y                 Y
#
#   DRAFT_YEAR DRAFT_ROUND  DRAFT_NUMBER GREATEST_75_FLAG
# 0       2018           2            45                N
#
# [1 rows x 33 columns]
# Attempting to fetch data using LeagueDashPlayerStats (Attempt 1) with parameters {'season': '2022-23', 'season_type_all_star': 'Regular Season', 'per_mode_detailed': 'PerGame'}
# Sample data from LeagueDashPlayerStats:
#    PLAYER_ID    PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  GP  \
# 0    1631260       AJ Green       AJ  1610612749               MIL  23.0  35
# 1    1631100     AJ Griffin       AJ  1610612737               ATL  19.0  72
# 2    1630639      AJ Lawson       AJ  1610612742               DAL  22.0  15
# 3     203932   Aaron Gordon    Aaron  1610612743               DEN  27.0  68
# 4    1628988  Aaron Holiday    Aaron  1610612737               ATL  26.0  63
#
#     W   L  W_PCT  ...  BLK_RANK  BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  \
# 0  27   8  0.771  ...       491        498      454       518       392
# 1  34  38  0.472  ...       372        268      394       422       217
# 2   5  10  0.333  ...       491        358      475       457       429
# 3  45  23  0.662  ...        65         32      205        58        82
# 4  32  31  0.508  ...       345        315      377       356       415
#
#    PLUS_MINUS_RANK  NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  \
# 0              309                   455       253        39
# 1              169                   287       253        39
# 2              462                   482       253        39
# 3                4                    77        56        39
# 4              212                   413       253        39
#
#    WNBA_FANTASY_PTS_RANK
# 0                    436
# 1                    273
# 2                    466
# 3                     89
# 4                    416
#
# [5 rows x 66 columns]
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2022-23'}
# Sample data from LeagueStandings:
#   LeagueID SeasonID      TeamID      TeamCity   TeamName Conference  \
# 0       00    22022  1610612743        Denver    Nuggets       West
# 1       00    22022  1610612749     Milwaukee      Bucks       East
# 2       00    22022  1610612763       Memphis  Grizzlies       West
# 3       00    22022  1610612738        Boston    Celtics       East
# 4       00    22022  1610612755  Philadelphia      76ers       East
#
#   ConferenceRecord  PlayoffRank ClinchIndicator   Division  ...   May   Jun  \
# 0            34-18            1             - w  Northwest  ...  None  None
# 1            35-17            1             - e    Central  ...  None  None
# 2            30-22            2            - sw  Southwest  ...  None  None
# 3            34-18            2             - a   Atlantic  ...  None  None
# 4            34-18            3             - x   Atlantic  ...  None  None
#
#     Jul   Aug   Sep  Oct   Nov   Dec  PreAS PostAS
# 0  None  None  None  4-3  10-4   9-5  41-18  12-11
# 1  None  None  None  6-0   9-5   8-7  41-17   17-7
# 2  None  None  None  4-3   8-6  10-4  35-22   16-9
# 3  None  None  None  4-2  14-2   8-6  42-17   15-8
# 4  None  None  None  4-4   8-6   9-4  38-19   16-9
#
# [5 rows x 81 columns]
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628977}
# Sample data from PlayerCareerStats:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0    1628977   2018-19        00  1610612760               OKC        20.0
# 1    1628977   2019-20        00  1610612760               OKC        21.0
# 2    1628977   2020-21        00  1610612760               OKC        22.0
# 3    1628977   2020-21        00  1610612765               DET        22.0
# 4    1628977   2020-21        00           0               TOT        22.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  51   3   526.0   75  ...   0.610    38    59   97   17   21   10   23   77
# 1  46   3   896.0  132  ...   0.603    44   123  167   36   37    9   51  101
# 2  32   5   761.0  143  ...   0.629    37   128  165   77   31   12   49   83
# 3  20   4   465.0   81  ...   0.662    22    85  107   24   10   12   27   51
# 4  52   9  1226.0  224  ...   0.640    59   213  272  101   41   24   76  134
#
#    PTS
# 0  190
# 1  318
# 2  381
# 3  223
# 4  604
#
# [5 rows x 27 columns]

# %%
# %%writefile ../src/utils/scrape_utils.py

import requests
from bs4 import BeautifulSoup

def filter_players_by_avg_minutes(player_stats, min_avg_minutes):
    """
    Filter players by their average minutes per game.
    """
    return player_stats[player_stats['MIN'] >= min_avg_minutes]

def get_player_url(player_name):
    search_url = f"https://www.basketball-reference.com/search/search.fcgi?search={player_name.replace(' ', '+')}"
    response = requests.get(search_url)
    soup = BeautifulSoup(response.content, 'html.parser')
   
    search_results = soup.find('div', {'class': 'search-results'})
    if search_results:
        for item in search_results.find_all('div', {'class': 'search-item'}):
            link = item.find('a')
            if link and 'players' in link['href']:
                return f"https://www.basketball-reference.com{link['href']}"
   
    raise ValueError(f"Player URL not found for {player_name}")

def scrape_advanced_metrics(player_name, season):
    try:
        player_url = get_player_url(player_name)
        response = requests.get(player_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        data = {}
        table = soup.find('table', {'id': 'advanced'})
        if table:
            df = pd.read_html(StringIO(str(table)))[0]
            if isinstance(df.columns, pd.MultiIndex):
                df.columns = df.columns.droplevel()
            df = df[df['Season'].str.contains(season.split('-')[0])]
           
            if not df.empty:
                row = df.iloc[0]
                important_columns = ['PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']
                for col in important_columns:
                    if col in row.index:
                        try:
                            data[col] = float(row[col])
                        except ValueError:
                            data[col] = row[col]
            else:
                print(f"No advanced metrics found for {player_name} in season {season}")
        else:
            print(f"Advanced metrics table not found for {player_name}")
    except Exception as e:
        print(f"Error scraping advanced metrics for {player_name}: {e}")
        data = {}
    
    return data

# %%
# %%writefile ../src/processing/load_data.py


import pandas as pd

def load_salary_data(file_path):
    """
    Load salary data from the pre-existing CSV file and format the season column.
    """
    try:
        salary_data = pd.read_csv(file_path)
        # Convert season format from "2023-2024" to "2023-24"
        salary_data['Season'] = salary_data['Season'].apply(lambda x: f"{str(x)[:4]}-{str(x)[-2:]}")
        print("Loaded salary data:")
        print(salary_data.head())
        return salary_data
    except Exception as e:
        print(f"Error loading salary data: {e}")
        return pd.DataFrame()

# %%
# %%writefile ../src/processing/add_nba_stats.py

import time
import pandas as pd
from nba_api.stats.endpoints import commonplayerinfo, playercareerstats, leaguestandings
# from src.utils.fetch_utils import fetch_with_retry, fetch_player_stats, fetch_league_standings
# from src.utils.scrape_utils import filter_players_by_avg_minutes, scrape_advanced_metrics

MAX_REQUESTS_PER_MINUTE = 30
DELAY_BETWEEN_REQUESTS = 2  # in seconds

def add_nba_stats(salary_data, all_players, player_filter=None, min_avg_minutes=None):
    """
    Add NBA statistics to the salary data for the filtered players.
    """
    additional_stats = []
    request_count = 0  # Track number of requests made

    if player_filter == 'all' and min_avg_minutes is not None:
        season = salary_data['Season'].iloc[0]
        player_stats = fetch_player_stats(season)
        if player_stats is not None and not player_stats.empty:
            filtered_players = filter_players_by_avg_minutes(player_stats, min_avg_minutes)
            player_list = filtered_players['PLAYER_NAME'].tolist()
        else:
            player_list = []
    else:
        player_list = [player_filter]

    for player in salary_data['Player']:
        if player_filter != 'all' and player.lower() != player_filter.lower():
            continue

        if player_filter == 'all' and player.lower() not in [p.lower() for p in player_list]:
            continue

        if player.lower() not in all_players:
            print(f"No player ID found for {player}")
            continue

        print(f"Fetching data for {player}...")
        player_id = all_players[player.lower()]['player_id']
        team_id = all_players[player.lower()]['team_id']
        
        # Fetch player info
        player_info = fetch_with_retry(commonplayerinfo.CommonPlayerInfo, player_id=player_id)
        request_count += 1
        time.sleep(DELAY_BETWEEN_REQUESTS)  # Delay between requests
        
        # Check request count and delay if necessary
        if request_count >= MAX_REQUESTS_PER_MINUTE:
            print("Rate limit reached. Waiting for a minute before continuing...")
            time.sleep(60)  # Wait for a minute
            request_count = 0

        # Fetch career stats
        career_stats = fetch_with_retry(playercareerstats.PlayerCareerStats, player_id=player_id)
        request_count += 1
        time.sleep(DELAY_BETWEEN_REQUESTS)  # Delay between requests

        # Check request count and delay if necessary
        if request_count >= MAX_REQUESTS_PER_MINUTE:
            print("Rate limit reached. Waiting for a minute before continuing...")
            time.sleep(60)  # Wait for a minute
            request_count = 0

        season = salary_data.loc[salary_data['Player'] == player, 'Season'].values[0]
        league_standings = fetch_league_standings(season)
        request_count += 1
        time.sleep(DELAY_BETWEEN_REQUESTS)  # Delay between requests
        
        # Check request count and delay if necessary
        if request_count >= MAX_REQUESTS_PER_MINUTE:
            print("Rate limit reached. Waiting for a minute before continuing...")
            time.sleep(60)  # Wait for a minute
            request_count = 0

        # Fetch advanced metrics
        advanced_metrics = scrape_advanced_metrics(player, season)

        if player_info and career_stats and not career_stats[0].empty:
            season_stats = career_stats[0][career_stats[0]['SEASON_ID'].str.contains(season.split('-')[0])]
            if not season_stats.empty:
                latest_season_stats = season_stats.iloc[0]

                # Calculate years of service for the current season
                draft_year = player_info[0]['DRAFT_YEAR'].iloc[0]
                current_season_year = int(season.split('-')[0])
                if draft_year == 'Undrafted':
                    years_of_service = 0  # or you could set this to the number of years since the player entered the league
                else:
                    years_of_service = max(0, current_season_year - int(draft_year))


                current_season_year = int(season.split('-')[0])
                years_of_service = max(0, current_season_year - draft_year)

                fg = latest_season_stats.get('FGM', 0) or 0
                fga = latest_season_stats.get('FGA', 0) or 0
                fg3 = latest_season_stats.get('FG3M', 0) or 0
                fg3a = latest_season_stats.get('FG3A', 0) or 0
                efg = (fg + 0.5 * fg3) / fga if fga != 0 else 0
                fg2 = fg - fg3
                fg2a = fga - fg3a
                fg2_pct = (fg2 / fg2a) if fg2a != 0 else 0

                player_stats = {
                    'Player': player,
                    'Position': player_info[0].iloc[0]['POSITION'],
                    'Age': latest_season_stats.get('PLAYER_AGE', None),
                    'Team': latest_season_stats.get('TEAM_ABBREVIATION', None),
                    'TeamID': team_id,
                    'Years of Service': years_of_service,
                    'GP': latest_season_stats.get('GP', None),
                    'GS': latest_season_stats.get('GS', None),
                    'MP': latest_season_stats.get('MIN', None),
                    'FG': fg,
                    'FGA': fga,
                    'FG%': latest_season_stats.get('FG_PCT', None),
                    '3P': fg3,
                    '3PA': fg3a,
                    '3P%': latest_season_stats.get('FG3_PCT', None),
                    '2P': fg2,
                    '2PA': fg2a,
                    '2P%': fg2_pct,
                    'eFG%': efg,
                    'FT': latest_season_stats.get('FTM', None),
                    'FTA': latest_season_stats.get('FTA', None),
                    'FT%': latest_season_stats.get('FT_PCT', None),
                    'ORB': latest_season_stats.get('OREB', None),
                    'DRB': latest_season_stats.get('DREB', None),
                    'TRB': latest_season_stats.get('REB', None),
                    'AST': latest_season_stats.get('AST', None),
                    'STL': latest_season_stats.get('STL', None),
                    'BLK': latest_season_stats.get('BLK', None),
                    'TOV': latest_season_stats.get('TOV', None),
                    'PF': latest_season_stats.get('PF', None),
                    'PTS': latest_season_stats.get('PTS', None),
                    'Season': season  # Add the season to the player stats
                }

                # Add advanced metrics
                player_stats.update(advanced_metrics)

                if league_standings is not None and team_id is not None:
                    team_standings = league_standings[league_standings['TeamID'] == team_id]
                    if not team_standings.empty:
                        player_stats.update({
                            'Wins': team_standings['WINS'].values[0],
                            'Losses': team_standings['LOSSES'].values[0]
                        })
                    else:
                        print(f"No standings data found for team ID {team_id}")
                else:
                    print(f"No league standings data available for {season} or team ID not found")

                additional_stats.append(player_stats)
            else:
                print(f"No season stats available for {player} in {season}")
        else:
            print(f"No career stats available for {player}")

    additional_stats_df = pd.DataFrame(additional_stats)

    # Debug output to check DataFrames before merging
    print("Salary Data:")
    print(salary_data.head())
    print("Salary Data columns:", salary_data.columns)
    print("Additional Stats Data:")
    print(additional_stats_df.head())
    print("Additional Stats Data columns:", additional_stats_df.columns)

    # Ensure both DataFrames have the 'Player' and 'Season' columns
    if 'Player' in salary_data.columns and 'Season' in salary_data.columns:
        if additional_stats_df.empty:
            print("No additional stats found. Returning salary data as is.")
            return salary_data
        elif 'Player' in additional_stats_df.columns and 'Season' in additional_stats_df.columns:
            merged_data = pd.merge(salary_data, additional_stats_df, on=['Player', 'Season'], how='left')
            print("Merged Data:")
            print(merged_data.head())
            return merged_data
        else:
            print("Missing 'Player' or 'Season' column in additional stats data. Returning salary data as is.")
            return salary_data
    else:
        raise KeyError("'Player' or 'Season' column missing from salary data")

# %%
# %%writefile ../src/processing/add_yos.py

import pandas as pd

def add_yos_to_dataset(merged_data_path, salary_limits_path):
    """
    Add Years of Service (YOS) to the merged dataset using salary limits data.
    """
    # Load the datasets
    salary_limits = pd.read_csv(salary_limits_path)
    player_data = pd.read_csv(merged_data_path)

    # Remove ' YOS' from the 'YOS' column to convert it to integer
    salary_limits['YOS'] = salary_limits['YOS'].str.replace(' YOS', '').astype(int)

    # Merge the dataframes based on 'Season' and 'Years of Service'
    merged_data = pd.merge(player_data, salary_limits, left_on=['Season', 'Years of Service'], right_on=['Season', 'YOS'])

    # Drop the now redundant 'YOS' column from merged_data
    merged_data = merged_data.drop(columns=['YOS'])

    # Display the merged dataframe to verify the structure
    print(merged_data.head())
    return merged_data

# %%
# %%writefile ../src/processing/add_salary_cap.py

import pandas as pd

def add_salary_cap_to_dataset(player_data_path, salary_cap_path):
    """
    Add salary cap information to the dataset based on the season.
    """
    # Load the datasets
    player_data = pd.read_csv(player_data_path)
    salary_cap = pd.read_csv(salary_cap_path)

    # Merge the dataframes based on 'Season' and 'Year'
    merged_data = pd.merge(player_data, salary_cap, left_on='Season', right_on='Year', how='left')

    # Drop the now redundant 'Year' column from merged_data
    merged_data = merged_data.drop(columns=['Year'])

    # Display the merged dataframe to verify the structure
    print(merged_data.head())
    return merged_data

# %%
# %%writefile ../src/main.py

import os
import pandas as pd
# from src.processing.load_data import load_salary_data
# from src.processing.add_nba_stats import add_nba_stats
# from src.processing.add_yos import add_yos_to_dataset
# from src.processing.add_salary_cap import add_salary_cap_to_dataset
# from src.utils.fetch_utils import fetch_all_players

def main():
    """
    Main function to process and save NBA player salary and stats data.
    """
    start_year = 2023
    end_year = 2021
    player_filter = input("Enter player name or 'all' for all players: ").strip().lower()
    min_avg_minutes = None
    if player_filter == 'all':
        min_avg_minutes = float(input("Enter the minimum average minutes per game: "))

    # Load existing salary data
    salary_file_path = '../data/processed/salary_data.csv'
    salary_data = load_salary_data(salary_file_path)
    if salary_data.empty:
        print("Failed to load salary data. Exiting.")
        return

    # Load existing processed data if available
    processed_file_path = '../data/processed/salary_data_with_team_info.csv'
    if os.path.exists(processed_file_path):
        existing_data = pd.read_csv(processed_file_path)
    else:
        existing_data = pd.DataFrame()

    all_data = pd.DataFrame()

    for year in range(start_year, end_year-1, -1):
        season = f"{year}-{str(year+1)[-2:]}"
        print(f"Processing data for {season}...")
        season_salary_data = salary_data[salary_data['Season'] == season]
        
        if player_filter != 'all':
            season_salary_data = season_salary_data[season_salary_data['Player'].str.contains(player_filter, case=False)]
        
        print(f"Salary data for {season}:")
        print(season_salary_data.head())
        
        if season_salary_data.empty:
            print(f"No salary data found for {season}. Skipping this season.")
            continue
        
        # Fetch player data with filter for this specific season
        all_players = fetch_all_players(season=season, player_filter=player_filter)
        
        try:
            season_data = add_nba_stats(season_salary_data, all_players, player_filter, min_avg_minutes)
        except Exception as e:
            print(f"Error processing data for {season}: {e}")
            continue
        
        # Debug output to check data before concatenating
        print(f"Processed data for {season}:")
        print(season_data.head())
        
        # Concatenate all data
        all_data = pd.concat([all_data, season_data], ignore_index=True)
        
    # Filter rows with no data in 'PTS'
    all_data = all_data[all_data['PTS'].notna()]

    # Debug output to check final data
    print("Final processed data:")
    print(all_data.head())

    if not all_data.empty:
        os.makedirs('../data/processed', exist_ok=True)
        all_data.to_csv(processed_file_path, index=False)
        print(f"Data saved to {processed_file_path}")
    else:
        print("No data to save. Please check the input and processing steps.")

    # Add YOS to the final dataset
    final_data_path = '../data/processed/final_salary_data_with_yos.csv'
    salary_limits_path = '../data/raw/nba_salary_limits.csv'
    final_data = add_yos_to_dataset(processed_file_path, salary_limits_path)
    final_data.to_csv(final_data_path, index=False)
    print(f"Final data with YOS saved to {final_data_path}")

    # Add salary cap to the final dataset
    final_data_with_cap_path = '../data/processed/final_salary_data_with_yos_and_cap.csv'
    salary_cap_path = '../data/raw/salary_cap_history.csv'
    final_data_with_cap = add_salary_cap_to_dataset(final_data_path, salary_cap_path)
    final_data_with_cap.to_csv(final_data_with_cap_path, index=False)
    print(f"Final data with salary cap saved to {final_data_with_cap_path}")

if __name__ == "__main__":
    main()
# Out:
# Loaded salary data:
#           Player    Salary   Season
# 0  Stephen Curry  51915615  2023-24
# 1   Kevin Durant  47649433  2023-24
# 2   Nikola Jokic  47607350  2023-24
# 3   LeBron James  47607350  2023-24
# 4    Joel Embiid  47607350  2023-24
# Processing data for 2023-24...
# Salary data for 2023-24:
#           Player    Salary   Season
# 0  Stephen Curry  51915615  2023-24
# 1   Kevin Durant  47649433  2023-24
# 2   Nikola Jokic  47607350  2023-24
# 3   LeBron James  47607350  2023-24
# 4    Joel Embiid  47607350  2023-24
# Fetching all players for season: 2023-24 with filter:
# Attempting to fetch data using CommonAllPlayers (Attempt 1) with parameters {'season': '2023-24', 'is_only_current_season': 1}
# Fetched 572 players
# Processing player: precious achiuwa, ID: 1630173, Team ID: 1610612752
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630173}
# Years of service for player precious achiuwa: 4
# Processing player: bam adebayo, ID: 1628389, Team ID: 1610612748
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628389}
# Years of service for player bam adebayo: 7
# Processing player: ochai agbaji, ID: 1630534, Team ID: 1610612761
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630534}
# Years of service for player ochai agbaji: 2
# Processing player: santi aldama, ID: 1630583, Team ID: 1610612763
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630583}
# Years of service for player santi aldama: 3
# Processing player: nickeil alexander-walker, ID: 1629638, Team ID: 1610612750
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629638}
# Years of service for player nickeil alexander-walker: 5
# Processing player: grayson allen, ID: 1628960, Team ID: 1610612756
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628960}
# Years of service for player grayson allen: 6
# Processing player: jarrett allen, ID: 1628386, Team ID: 1610612739
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628386}
# Years of service for player jarrett allen: 7
# Processing player: timmy allen, ID: 1641851, Team ID: 0
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641851}
# Years of service for player timmy allen: 1
# Processing player: jose alvarado, ID: 1630631, Team ID: 1610612740
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630631}
# Years of service for player jose alvarado: 3
# Processing player: kyle anderson, ID: 203937, Team ID: 1610612750
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203937}
# Years of service for player kyle anderson: 10
# Processing player: giannis antetokounmpo, ID: 203507, Team ID: 1610612749
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203507}
# Years of service for player giannis antetokounmpo: 11
# Processing player: thanasis antetokounmpo, ID: 203648, Team ID: 1610612749
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203648}
# Years of service for player thanasis antetokounmpo: 6
# Processing player: cole anthony, ID: 1630175, Team ID: 1610612753
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630175}
# Years of service for player cole anthony: 4
# Processing player: og anunoby, ID: 1628384, Team ID: 1610612752
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628384}
# Years of service for player og anunoby: 7
# Processing player: ryan arcidiacono, ID: 1627853, Team ID: 0
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627853}
# Years of service for player ryan arcidiacono: 7
# Processing player: deni avdija, ID: 1630166, Team ID: 1610612764
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630166}
# Years of service for player deni avdija: 4
# Processing player: deandre ayton, ID: 1629028, Team ID: 1610612757
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629028}
# Years of service for player deandre ayton: 6
# Processing player: udoka azubuike, ID: 1628962, Team ID: 1610612756
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628962}
# Years of service for player udoka azubuike: 4
# Processing player: ibou badji, ID: 1630641, Team ID: 1610612757
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630641}
# Years of service for player ibou badji: 1
# Processing player: marvin bagley iii, ID: 1628963, Team ID: 1610612764
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628963}
# Years of service for player marvin bagley iii: 6
# Processing player: amari bailey, ID: 1641735, Team ID: 1610612766
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641735}
# Years of service for player amari bailey: 2
# Processing player: patrick baldwin jr., ID: 1631116, Team ID: 1610612764
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631116}
# Years of service for player patrick baldwin jr.: 2
# Processing player: lamelo ball, ID: 1630163, Team ID: 1610612766
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630163}
# Years of service for player lamelo ball: 4
# Processing player: mo bamba, ID: 1628964, Team ID: 1610612755
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628964}
# Years of service for player mo bamba: 6
# Processing player: paolo banchero, ID: 1631094, Team ID: 1610612753
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631094}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[78], line 98
#      95     print(f"Final data with salary cap saved to {final_data_with_cap_path}")
#      97 if __name__ == "__main__":
# ---> 98     main()
#
# Cell In[78], line 54, in main()
#      51     continue
#      53 # Fetch player data with filter for this specific season
# ---> 54 all_players = fetch_all_players(season=season, player_filter=player_filter)
#      56 try:
#      57     season_data = add_nba_stats(season_salary_data, all_players, player_filter, min_avg_minutes)
#
# Cell In[71], line 50, in fetch_all_players(season, player_filter)
#      47 print(f"Processing player: {player_name}, ID: {player_id}, Team ID: {team_id}")
#      49 # Fetch player info to get years of service
# ---> 50 player_info = fetch_with_retry(commonplayerinfo.CommonPlayerInfo, player_id=player_id)
#      51 years_of_service = 0
#      52 if player_info:
#
# Cell In[72], line 13, in fetch_with_retry(endpoint, max_retries, delay, timeout, **kwargs)
#      11 try:
#      12     print(f"Attempting to fetch data using {endpoint.__name__} (Attempt {attempt + 1}) with parameters {kwargs}")
# ---> 13     data = endpoint(**kwargs, timeout=timeout).get_data_frames()
#      14     return data
#      15 except (RequestException, JSONDecodeError, KeyError) as e:
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/nba_api/stats/endpoints/commonplayerinfo.py:75, in CommonPlayerInfo.__init__(self, player_id, league_id_nullable, proxy, headers, timeout, get_request)
#      73 self.parameters = {"PlayerID": player_id, "LeagueID": league_id_nullable}
#      74 if get_request:
# ---> 75     self.get_request()
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/nba_api/stats/endpoints/commonplayerinfo.py:78, in CommonPlayerInfo.get_request(self)
#      77 def get_request(self):
# ---> 78     self.nba_response = NBAStatsHTTP().send_api_request(
#      79         endpoint=self.endpoint,
#      80         parameters=self.parameters,
#      81         proxy=self.proxy,
#      82         headers=self.headers,
#      83         timeout=self.timeout,
#      84     )
#      85     self.load_response()
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/nba_api/library/http.py:146, in NBAHTTP.send_api_request(self, endpoint, parameters, referer, proxy, headers, timeout, raise_exception_on_error)
#     143         print("loading from file...")
#     145 if not contents:
# --> 146     response = requests.get(
#     147         url=base_url,
#     148         params=parameters,
#     149         headers=request_headers,
#     150         proxies=proxies,
#     151         timeout=timeout,
#     152     )
#     153     url = response.url
#     154     status_code = response.status_code
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/conda/envs/data_science/lib/python3.10/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File /opt/conda/envs/data_science/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File /opt/conda/envs/data_science/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/conda/envs/data_science/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/conda/envs/data_science/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File /opt/conda/envs/data_science/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/envs/data_science/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
import pandas as pd
import time
import requests
from bs4 import BeautifulSoup
from io import StringIO
from nba_api.stats.endpoints import commonallplayers, commonplayerinfo, playercareerstats, leaguestandings, leaguedashplayerstats
from requests.exceptions import RequestException
from json.decoder import JSONDecodeError

# Define constants for rate limiting
MAX_REQUESTS_PER_MINUTE = 30
DELAY_BETWEEN_REQUESTS = 2  # in seconds

def fetch_with_retry(endpoint, max_retries=3, delay=5, **kwargs):
    """
    Fetch data from an NBA API endpoint with retries in case of failures.
    """
    for attempt in range(max_retries):
        try:
            print(f"Attempting to fetch data using {endpoint.__name__} (Attempt {attempt + 1}) with parameters {kwargs}")
            data = endpoint(**kwargs).get_data_frames()
            return data
        except (RequestException, JSONDecodeError, KeyError) as e:
            print(f"Error occurred: {e}")
            if attempt == max_retries - 1:
                print(f"Failed to fetch data after {max_retries} attempts: {str(e)}")
                return None
            print(f"Attempt {attempt + 1} failed. Retrying in {delay} seconds...")
            time.sleep(delay)

def load_salary_data(file_path):
    """
    Load salary data from the pre-existing CSV file and format the season column.
    """
    try:
        salary_data = pd.read_csv(file_path)
        # Convert season format from "2023-2024" to "2023-24"
        salary_data['Season'] = salary_data['Season'].apply(lambda x: f"{str(x)[:4]}-{str(x)[-2:]}")
        print("Loaded salary data:")
        print(salary_data.head())
        return salary_data
    except Exception as e:
        print(f"Error loading salary data: {e}")
        return pd.DataFrame()

def fetch_all_players(season):
    """
    Fetch all players' IDs and team IDs for a given season.
    """
    all_players_data = fetch_with_retry(commonallplayers.CommonAllPlayers, season=season)
    all_players = {}
    if all_players_data:
        for _, row in all_players_data[0].iterrows():
            player_name = row['DISPLAY_FIRST_LAST'].strip().lower()
            player_id = row['PERSON_ID']
            team_id = row['TEAM_ID']
            all_players[player_name] = {
                'player_id': player_id,
                'team_id': team_id
            }
    return all_players

def fetch_player_info(player_id):
    """
    Fetch basic information about a player given their player ID.
    """
    return fetch_with_retry(commonplayerinfo.CommonPlayerInfo, player_id=player_id)

def fetch_career_stats(player_id):
    """
    Fetch career statistics for a player given their player ID.
    """
    return fetch_with_retry(playercareerstats.PlayerCareerStats, player_id=player_id)

def fetch_league_standings(season):
    """
    Fetch league standings for a given season.
    """
    standings_data = fetch_with_retry(leaguestandings.LeagueStandings, season=season)
    if standings_data is None or not standings_data:
        return pd.DataFrame()  # Return an empty DataFrame if fetching fails
    return standings_data[0]

def fetch_player_stats(season):
    """
    Fetch player statistics for a given season.
    """
    player_stats = fetch_with_retry(leaguedashplayerstats.LeagueDashPlayerStats, season=season, season_type_all_star='Regular Season', per_mode_detailed='PerGame')
    return player_stats[0] if player_stats else None

def filter_players_by_avg_minutes(player_stats, min_avg_minutes):
    """
    Filter players by their average minutes per game.
    """
    return player_stats[player_stats['MIN'] >= min_avg_minutes]

def get_player_url(player_name):
    search_url = f"https://www.basketball-reference.com/search/search.fcgi?search={player_name.replace(' ', '+')}"
    response = requests.get(search_url)
    soup = BeautifulSoup(response.content, 'html.parser')
   
    search_results = soup.find('div', {'class': 'search-results'})
    if search_results:
        for item in search_results.find_all('div', {'class': 'search-item'}):
            link = item.find('a')
            if link and 'players' in link['href']:
                return f"https://www.basketball-reference.com{link['href']}"
   
    raise ValueError(f"Player URL not found for {player_name}")

def scrape_advanced_metrics(player_name, season):
    try:
        player_url = get_player_url(player_name)
        response = requests.get(player_url)
        soup = BeautifulSoup(response.content, 'html.parser')
        data = {}
        table = soup.find('table', {'id': 'advanced'})
        if table:
            df = pd.read_html(StringIO(str(table)))[0]
            if isinstance(df.columns, pd.MultiIndex):
                df.columns = df.columns.droplevel()
            df = df[df['Season'].str.contains(season.split('-')[0], na=False)]
           
            if not df.empty:
                row = df.iloc[0]
                important_columns = ['PER', 'TS%', '3PAr', 'FTr', 'ORB%', 'DRB%', 'TRB%', 'AST%', 'STL%', 'BLK%', 'TOV%', 'USG%', 'OWS', 'DWS', 'WS', 'WS/48', 'OBPM', 'DBPM', 'BPM', 'VORP']
                for col in important_columns:
                    if col in row.index:
                        try:
                            data[col] = float(row[col]) if pd.notna(row[col]) else None
                        except ValueError:
                            data[col] = None
            else:
                print(f"No advanced metrics found for {player_name} in season {season}")
        else:
            print(f"Advanced metrics table not found for {player_name}")
    except Exception as e:
        print(f"Error scraping advanced metrics for {player_name}: {e}")
        data = {}
    
    return data


def add_nba_stats(salary_data, all_players):
    """
    Add NBA statistics to the salary data for all players with a salary.
    """
    additional_stats = []
    request_count = 0

    # Create a set of players from the salary dataset for quick lookup
    salary_players = set(salary_data['Player'].str.lower())

    for _, row in salary_data.iterrows():
        player = row['Player']
        season = row['Season']

        if player.lower() not in all_players:
            print(f"No player ID found for {player}")
            continue

        print(f"Fetching data for {player}...")
        player_id = all_players[player.lower()]['player_id']
        team_id = all_players[player.lower()]['team_id']
        
        # Fetch player info
        player_info = fetch_with_retry(commonplayerinfo.CommonPlayerInfo, player_id=player_id)
        request_count += 1
        time.sleep(DELAY_BETWEEN_REQUESTS)
        
        # Rate limiting check
        if request_count >= MAX_REQUESTS_PER_MINUTE:
            print("Rate limit reached. Waiting for a minute before continuing...")
            time.sleep(60)
            request_count = 0

        # Fetch career stats
        career_stats = fetch_with_retry(playercareerstats.PlayerCareerStats, player_id=player_id)
        request_count += 1
        time.sleep(DELAY_BETWEEN_REQUESTS)

        # Rate limiting check
        if request_count >= MAX_REQUESTS_PER_MINUTE:
            print("Rate limit reached. Waiting for a minute before continuing...")
            time.sleep(60)
            request_count = 0

        league_standings = fetch_league_standings(season)
        request_count += 1
        time.sleep(DELAY_BETWEEN_REQUESTS)
        
        # Rate limiting check
        if request_count >= MAX_REQUESTS_PER_MINUTE:
            print("Rate limit reached. Waiting for a minute before continuing...")
            time.sleep(60)
            request_count = 0

        # Fetch advanced metrics
        advanced_metrics = scrape_advanced_metrics(player, season)

        if player_info is not None and career_stats is not None and not career_stats[0].empty:
            season_stats = career_stats[0][career_stats[0]['SEASON_ID'].str.contains(season.split('-')[0])]
            if not season_stats.empty:
                latest_season_stats = season_stats.iloc[0]

                # Calculate years of service for the current season
                draft_year = player_info[0]['DRAFT_YEAR'].iloc[0]
                current_season_year = int(season.split('-')[0])
                if draft_year == 'Undrafted':
                    years_of_service = 0  # or some other default value
                else:
                    years_of_service = max(0, current_season_year - int(draft_year))

                fg = latest_season_stats.get('FGM', 0) or 0
                fga = latest_season_stats.get('FGA', 0) or 0
                fg3 = latest_season_stats.get('FG3M', 0) or 0
                fg3a = latest_season_stats.get('FG3A', 0) or 0
                efg = (fg + 0.5 * fg3) / fga if fga != 0 else 0
                fg2 = fg - fg3
                fg2a = fga - fg3a
                fg2_pct = (fg2 / fg2a) if fg2a != 0 else 0

                player_stats = {
                    'Player': player,
                    'Position': player_info[0].iloc[0]['POSITION'],
                    'Age': latest_season_stats.get('PLAYER_AGE', None),
                    'Team': latest_season_stats.get('TEAM_ABBREVIATION', None),
                    'TeamID': team_id,
                    'Years of Service': years_of_service,
                    'GP': latest_season_stats.get('GP', None),
                    'GS': latest_season_stats.get('GS', None),
                    'MP': latest_season_stats.get('MIN', None),
                    'FG': fg,
                    'FGA': fga,
                    'FG%': latest_season_stats.get('FG_PCT', None),
                    '3P': fg3,
                    '3PA': fg3a,
                    '3P%': latest_season_stats.get('FG3_PCT', None),
                    '2P': fg2,
                    '2PA': fg2a,
                    '2P%': fg2_pct,
                    'eFG%': efg,
                    'FT': latest_season_stats.get('FTM', None),
                    'FTA': latest_season_stats.get('FTA', None),
                    'FT%': latest_season_stats.get('FT_PCT', None),
                    'ORB': latest_season_stats.get('OREB', None),
                    'DRB': latest_season_stats.get('DREB', None),
                    'TRB': latest_season_stats.get('REB', None),
                    'AST': latest_season_stats.get('AST', None),
                    'STL': latest_season_stats.get('STL', None),
                    'BLK': latest_season_stats.get('BLK', None),
                    'TOV': latest_season_stats.get('TOV', None),
                    'PF': latest_season_stats.get('PF', None),
                    'PTS': latest_season_stats.get('PTS', None),
                    'Season': season  # Add the season to the player stats
                }

                # Add advanced metrics
                player_stats.update(advanced_metrics)

                if league_standings is not None and team_id is not None and team_id != 0:
                    team_standings = league_standings[league_standings['TeamID'] == team_id]
                    if not team_standings.empty:
                        player_stats.update({
                            'Wins': team_standings['WINS'].values[0],
                            'Losses': team_standings['LOSSES'].values[0]
                        })
                    else:
                        print(f"No standings data found for team ID {team_id}")
                        player_stats.update({
                            'Wins': None,
                            'Losses': None
                        })
                else:
                    print(f"No league standings data available for {season} or player not on a team")
                    player_stats.update({
                        'Wins': None,
                        'Losses': None
                    })

                additional_stats.append(player_stats)
            else:
                print(f"No season stats available for {player} in {season}")
        else:
            print(f"No career stats available for {player}")

    additional_stats_df = pd.DataFrame(additional_stats)
    print(f"Additional stats DataFrame shape: {additional_stats_df.shape}")
    print(f"Additional stats columns: {additional_stats_df.columns}")
    merged_data = pd.merge(salary_data, additional_stats_df, on=['Player', 'Season'], how='left')
    print(f"Merged data shape: {merged_data.shape}")
    print(f"Merged data columns: {merged_data.columns}")
    return merged_data


def add_yos_to_dataset(merged_data_path, salary_limits_path):
    """
    Add Years of Service (YOS) to the merged dataset using salary limits data.
    """
    # Load the datasets
    salary_limits = pd.read_csv(salary_limits_path)
    player_data = pd.read_csv(merged_data_path)

    # Remove ' YOS' from the 'YOS' column to convert it to integer
    salary_limits['YOS'] = salary_limits['YOS'].str.replace(' YOS', '').astype(int)

    # Merge the dataframes based on 'Season' and 'Years of Service'
    merged_data = pd.merge(player_data, salary_limits, left_on=['Season', 'Years of Service'], right_on=['Season', 'YOS'])

    # Drop the now redundant 'YOS' column from merged_data
    merged_data = merged_data.drop(columns=['YOS'])

    # Display the merged dataframe to verify the structure
    print(merged_data.head())
    return merged_data

def add_salary_cap_to_dataset(player_data_path, salary_cap_path):
    """
    Add salary cap information to the dataset based on the season.
    """
    # Load the datasets
    player_data = pd.read_csv(player_data_path)
    salary_cap = pd.read_csv(salary_cap_path)

    # Merge the dataframes based on 'Season' and 'Year'
    merged_data = pd.merge(player_data, salary_cap, left_on='Season', right_on='Year', how='left')

    # Drop the now redundant 'Year' column from merged_data
    merged_data = merged_data.drop(columns=['Year'])

    # Display the merged dataframe to verify the structure
    print(merged_data.head())
    return merged_data

def main():
    start_year = 2023
    end_year = 2022

    # Load existing salary data
    salary_file_path = '../data/processed/salary_data.csv'
    processed_file_path = '../data/processed/salary_data_with_stats.csv'  # Define this here
    salary_data = load_salary_data(salary_file_path)
    if salary_data.empty:
        print("Failed to load salary data. Exiting.")
        return

    all_data = pd.DataFrame()

    for year in range(start_year, end_year-1, -1):
        season = f"{year}-{str(year+1)[-2:]}"
        print(f"Processing data for {season}...")
        season_salary_data = salary_data[salary_data['Season'] == season]
        
        print(f"Salary data for {season}:")
        print(season_salary_data.head())
        
        if season_salary_data.empty:
            print(f"No salary data found for {season}. Skipping this season.")
            continue
        
        # Fetch player data for this specific season
        all_players = fetch_all_players(season=season)
        
        try:
            season_data = add_nba_stats(season_salary_data, all_players)
        except Exception as e:
            print(f"Error processing data for {season}: {e}")
            continue
        
        # Debug output to check data before concatenating
        print(f"Processed data for {season}:")
        print(season_data.head())
        
        # Concatenate all data
        all_data = pd.concat([all_data, season_data], ignore_index=True)
        
    if 'PTS' in all_data.columns:
        all_data = all_data[all_data['PTS'].notna()]
    else:
        print("Warning: 'PTS' column not found in the data")

    print("Columns in all_data:", all_data.columns)
    print("Sample of all_data:")
    print(all_data.head())

    if not all_data.empty:
        os.makedirs('../data/processed', exist_ok=True)
        all_data.to_csv(processed_file_path, index=False)
        print(f"Data saved to {processed_file_path}")
    else:
        print("No data to save. Please check the input and processing steps.")
        return  # Exit the function if there's no data

    # Check if the file was actually created
    if not os.path.exists(processed_file_path):
        print(f"Error: {processed_file_path} was not created. Exiting.")
        return

    final_data_path = '../data/processed/final_salary_data_with_yos.csv'
    salary_limits_path = '../data/raw/nba_salary_limits.csv'
    final_data = add_yos_to_dataset(processed_file_path, salary_limits_path)
    final_data.to_csv(final_data_path, index=False)
    print(f"Final data with YOS saved to {final_data_path}")

    # Add salary cap to the final dataset
    final_data_with_cap_path = '../data/processed/final_salary_data_with_yos_and_cap.csv'
    salary_cap_path = '../data/raw/salary_cap_history.csv'
    final_data_with_cap = add_salary_cap_to_dataset(final_data_path, salary_cap_path)
    final_data_with_cap.to_csv(final_data_with_cap_path, index=False)
    print(f"Final data with salary cap saved to {final_data_with_cap_path}")

if __name__ == "__main__":
    main()
# Out:
# Loaded salary data:
#           Player    Salary   Season
# 0  Stephen Curry  51915615  2023-24
# 1   Kevin Durant  47649433  2023-24
# 2   Nikola Jokic  47607350  2023-24
# 3   LeBron James  47607350  2023-24
# 4    Joel Embiid  47607350  2023-24
# Processing data for 2023-24...
# Salary data for 2023-24:
#           Player    Salary   Season
# 0  Stephen Curry  51915615  2023-24
# 1   Kevin Durant  47649433  2023-24
# 2   Nikola Jokic  47607350  2023-24
# 3   LeBron James  47607350  2023-24
# 4    Joel Embiid  47607350  2023-24
# Attempting to fetch data using CommonAllPlayers (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Stephen Curry...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 201939}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 201939}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kevin Durant...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 201142}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 201142}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Nikola Jokic...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203999}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203999}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for LeBron James...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 2544}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 2544}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Joel Embiid...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203954}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203954}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Bradley Beal...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203078}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203078}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Paul George...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202331}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202331}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kawhi Leonard...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202695}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202695}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Giannis Antetokounmpo...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203507}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203507}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Damian Lillard...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203081}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203081}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Jimmy Butler...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202710}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202710}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Klay Thompson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202691}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202691}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Rudy Gobert...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203497}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203497}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Fred VanVleet...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627832}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627832}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Anthony Davis...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203076}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203076}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Trae Young...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629027}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629027}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Zach LaVine...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203897}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203897}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Luka Doncic...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629029}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629029}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Tobias Harris...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202699}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202699}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kyrie Irving...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202681}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202681}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Ben Simmons...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627732}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627732}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Pascal Siakam...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627783}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627783}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jrue Holiday...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 201950}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 201950}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kristaps Porzingis...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 204001}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 204001}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Karl-Anthony Towns...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1626157}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1626157}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Devin Booker...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1626164}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1626164}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for CJ McCollum...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203468}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203468}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for James Harden...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 201935}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 201935}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Darius Garland...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629636}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629636}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Ja Morant...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629630}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629630}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Zion Williamson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629627}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629627}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jamal Murray...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627750}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627750}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Brandon Ingram...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627742}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627742}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Michael Porter
# Fetching data for Shai Gilgeous-Alexander...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628983}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628983}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Gordon Hayward...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202330}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202330}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Donovan Mitchell...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628378}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628378}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jayson Tatum...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628369}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628369}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Bam Adebayo...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628389}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628389}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for De'Aaron Fox...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628368}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628368}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Deandre Ayton...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629028}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629028}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Jaylen Brown...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627759}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627759}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Chris Paul...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 101108}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 101108}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kyle Lowry...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 200768}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 200768}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Khris Middleton...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203114}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203114}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Domantas Sabonis...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627734}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627734}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for DeMar DeRozan...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 201942}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 201942}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jordan Poole...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629673}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629673}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jerami Grant...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203924}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203924}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Jaren Jackson Jr
# Fetching data for Tyler Herro...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629639}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629639}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Julius Randle...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203944}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203944}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Jalen Brunson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628973}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628973}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Cameron Johnson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629661}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629661}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kyle Kuzma...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628398}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628398}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for John Collins...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628381}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628381}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Brook Lopez...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 201572}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 201572}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Mike Conley...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 201144}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 201144}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Andrew Wiggins...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203952}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203952}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Anfernee Simons...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629014}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629014}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for RJ Barrett...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629628}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629628}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jordan Clarkson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203903}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203903}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Terry Rozier...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1626179}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1626179}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Dillon Brooks...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628415}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628415}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Malcolm Brogdon...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627763}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627763}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Draymond Green...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203110}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203110}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Bruce Brown...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628971}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628971}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Mikal Bridges...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628969}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628969}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Aaron Gordon...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203932}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203932}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Myles Turner...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1626167}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1626167}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Clint Capela...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203991}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203991}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Lonzo Ball...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628366}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628366}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# No advanced metrics found for Lonzo Ball in season 2023-24
# No season stats available for Lonzo Ball in 2023-24
# Fetching data for Spencer Dinwiddie...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203915}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203915}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for De'Andre Hunter...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629631}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629631}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jarrett Allen...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628386}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628386}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Bojan Bogdanovic...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202711}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202711}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Keldon Johnson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629640}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629640}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Joe Harris...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203925}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203925}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No league standings data available for 2023-24 or player not on a team
# Fetching data for Jakob Poeltl...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627751}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627751}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Error scraping advanced metrics for Jakob Poeltl: Player URL not found for Jakob Poeltl
# Fetching data for Buddy Hield...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627741}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627741}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Derrick White...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628401}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628401}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Evan Fournier...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203095}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203095}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Bogdan Bogdanovic...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203992}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203992}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for OG Anunoby...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628384}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628384}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Marcus Smart...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203935}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203935}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Gary Trent Jr
# Fetching data for Nikola Vucevic...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202696}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202696}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Dejounte Murray...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627749}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627749}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Duncan Robinson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629130}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629130}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Norman Powell...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1626181}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1626181}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Tim Hardaway Jr
# No player ID found for Marcus Morris
# Fetching data for Collin Sexton...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629012}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629012}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jonathan Isaac...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628371}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628371}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for D'Angelo Russell...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1626156}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1626156}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Lauri Markkanen...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628374}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628374}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Davis Bertans...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202722}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202722}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Markelle Fultz...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628365}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628365}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Harrison Barnes...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203084}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203084}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jusuf Nurkic...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203994}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203994}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for PJ Washington
# Fetching data for Kevin Porter...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 77876}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 77876}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No advanced metrics found for Kevin Porter in season 2023-24
# No season stats available for Kevin Porter in 2023-24
# Fetching data for Rui Hachimura...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629060}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629060}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Mitchell Robinson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629011}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629011}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kevin Huerter...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628989}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628989}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jonas Valanciunas...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202685}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202685}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Caris LeVert...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627747}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627747}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Luguentz Dort...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629652}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629652}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Luke Kennard...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628379}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628379}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kentavious Caldwell-Pope...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203484}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203484}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Max Strus...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629622}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629622}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Reggie Bullock
# Fetching data for Doug McDermott...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203926}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203926}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Tyus Jones...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1626145}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1626145}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Dorian Finney-Smith...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627827}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627827}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Anthony Edwards...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630162}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630162}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Wendell Carter
# Fetching data for Gary Harris...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203914}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203914}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Josh Hart...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628404}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628404}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Naz Reid...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629675}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629675}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Steven Adams...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203500}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203500}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No advanced metrics found for Steven Adams in season 2023-24
# No season stats available for Steven Adams in 2023-24
# Fetching data for Brandon Clarke...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629634}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629634}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Marvin Bagley
# No player ID found for Dennis Schroeder
# Fetching data for Grant Williams...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629684}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629684}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Daniel Gafford...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629655}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629655}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kelly Olynyk...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203482}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203482}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Victor Wembanyama...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641705}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641705}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Error scraping advanced metrics for Victor Wembanyama: Player URL not found for Victor Wembanyama
# Fetching data for James Wiseman...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630164}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630164}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Devonte Graham
# Fetching data for Richaun Holmes...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1626158}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1626158}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Austin Reaves...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630559}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630559}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Herb Jones
# Fetching data for Chris Boucher...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628449}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628449}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Bobby Portis...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1626171}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1626171}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Nicolas Batum...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 201587}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 201587}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Robert Covington...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 203496}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 203496}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Paolo Banchero...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631094}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631094}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Robert Williams
# Fetching data for Coby White...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629632}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629632}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Cade Cunningham...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630595}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630595}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Talen Horton-Tucker...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629659}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629659}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for PJ Tucker
# Fetching data for Maxi Kleber...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628467}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628467}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Joe Ingles...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 204060}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 204060}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Ivica Zubac...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1627826}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1627826}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for LaMelo Ball...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630163}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630163}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Donte DiVincenzo...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1628978}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1628978}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Brandon Miller...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641706}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641706}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Terance Mann...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629611}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629611}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Gabe Vincent...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629216}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629216}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Matisse Thybulle...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629680}
# ...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630631}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630631}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Miles McBride...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630540}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630540}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Aaron Wiggins...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630598}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630598}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Isaiah Livers...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630587}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630587}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No league standings data available for 2023-24 or player not on a team
# Fetching data for Jared Butler...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630215}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630215}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Orlando Robinson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631115}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631115}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Dru Smith...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630696}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630696}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No league standings data available for 2023-24 or player not on a team
# No player ID found for EJ Liddell
# Fetching data for Leonard Miller...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631159}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631159}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Bryce McGowens...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631121}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631121}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jaden Hardy...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630702}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630702}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Max Christie...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631108}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631108}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kennedy Chandler...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631113}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631113}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No advanced metrics found for Kennedy Chandler in season 2023-24
# No season stats available for Kennedy Chandler in 2023-24
# Fetching data for Josh Minott...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631169}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631169}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jabari Walker...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631133}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631133}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Christian Koloko...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631132}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631132}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# No advanced metrics found for Christian Koloko in season 2023-24
# No season stats available for Christian Koloko in 2023-24
# Fetching data for Xavier Cooks...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641645}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641645}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No advanced metrics found for Xavier Cooks in season 2023-24
# No season stats available for Xavier Cooks in 2023-24
# Fetching data for Jalen Pickett...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629618}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629618}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Julian Phillips...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641763}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641763}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Craig Porter
# Fetching data for Eugene Omoruyi...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630647}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630647}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Ricky Council
# Fetching data for DaQuan Jeffries...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629610}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629610}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Eric Bledsoe...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 202339}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 202339}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No advanced metrics found for Eric Bledsoe in season 2023-24
# No season stats available for Eric Bledsoe in 2023-24
# Fetching data for Skylar Mays...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630219}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630219}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Mouhamed Gueye...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631243}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631243}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jordan Walsh...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641775}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641775}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Hunter Tyson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641816}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641816}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Trayce Jackson-Davis...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631218}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631218}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Maxwell Lewis...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641721}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641721}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Andre Jackson Jr
# Fetching data for Chris Livingston...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641753}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641753}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Rayan Rupert...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641712}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641712}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Toumani Camara...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1641739}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1641739}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Sidy Cissoko...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631321}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631321}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Dylan Windler...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629685}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629685}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Trent Forrest...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630235}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630235}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Lester Quinones...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631311}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631311}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Kendall Brown...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631112}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631112}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
# Fetching data for Stanley Umude...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630649}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630649}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Gui Santos...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630611}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630611}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Dominick Barlow...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631230}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631230}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for AJ Lawson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630639}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630639}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# No player ID found for Ishmail Wainright
# Fetching data for Neemias Queta...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629674}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629674}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jalen Wilson...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630592}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630592}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Javon Freeman-Liberty...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631241}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631241}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Lindy Waters III...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1630322}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1630322}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Jacob Toppin...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1631210}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1631210}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Fetching data for Mamadi Diakite...
# Attempting to fetch data using CommonPlayerInfo (Attempt 1) with parameters {'player_id': 1629603}
# Attempting to fetch data using PlayerCareerStats (Attempt 1) with parameters {'player_id': 1629603}
# Attempting to fetch data using LeagueStandings (Attempt 1) with parameters {'season': '2023-24'}
# Rate limit reached. Waiting for a minute before continuing...
